# %% [markdown]
# # Discovery and Representation of Open Making Related Terms

# %% [markdown]
# This notebook sketches the initial exercise on discovering the open making related keywords. The input text is harvested via a Web crawler that identifies and crawls semantically related wikipedia articles.

# %%
from utils import tokenizer
import nltk
from nltk import FreqDist
from math import log
import json, csv

# %% [markdown]
# ## 1. Loading a reference English language corpus

# %%
from nltk.corpus import brown
brown.categories()
# Out:
# ['adventure',
#  'belles_lettres',
#  'editorial',
#  'fiction',
#  'government',
#  'hobbies',
#  'humor',
#  'learned',
#  'lore',
#  'mystery',
#  'news',
#  'religion',
#  'reviews',
#  'romance',
#  'science_fiction']

# %% [markdown]
# ## 2. Stop words

# %% [markdown]
# ### 2.1 Standard stop words

# %%
with open("data/stopwords_standard.txt", "r") as f:
    STOP_WORDS_STANDARD = set(f.read().strip().split("\n"))
print(STOP_WORDS_STANDARD)
# Out:
# {"they're", "let's", 'as', "we've", 'itself', 'up', "don't", "he'll", 'about', 'she', 'until', "weren't", 'too', 'at', 'like', 'theirs', "wouldn't", 'yours', "what's", 'most', 'your', 'had', 'there', 'any', 'could', 'it', 'for', "we'll", 'why', 'if', "you'll", 'few', 'whom', "she'll", 'further', 'cannot', 'that', "you've", 'his', 'hers', "wasn't", "i'm", 'those', "she's", 'from', 'an', 'ought', 'during', 'under', 'below', 'me', "haven't", 'he', "they've", 'they', 'not', "it's", 'same', 'having', "you're", 'been', "when's", 'of', 'this', 'on', 'myself', "can't", 'doing', 'r', "we'd", 'before', 'just', 'was', "hadn't", 'in', 'herself', 'to', 'out', 'does', 'so', 'or', "doesn't", 'is', 'after', 'because', 'should', 'down', "she'd", 'then', 'while', 'com', "you'd", 'their', "aren't", 'yourselves', 'over', "they'd", 'them', 'between', 'each', 'our', 'again', "won't", 'you', 'know', "that's", 'off', 'both', "he'd", 'http', 'am', 'nor', 'ourselves', "there's", 'my', 'when', 'who', "couldn't", 'only', "isn't", 'a', 'did', 'its', 'above', 'can', 'and', 'which', 'where', 'into', 'such', 'himself', 'no', 'would', 'all', 'yourself', "i've", 'are', 'very', 'has', "i'd", "mustn't", 'i', 'themselves', 'some', "we're", 'being', "why's", "shouldn't", 'we', 'here', "i'll", 'but', 'other', 'were', "hasn't", 'have', 'what', 'through', 'with', 'ours ', 'do', 'the', "how's", 'more', "where's", 'once', 'get', 'be', "he's", 'her', "shan't", 'how', 'by', 'own', 'than', 'him', 'these', "here's", "they'll", "didn't", 'www', "who's"}

# %% [markdown]
# ### 2.2 Open-making related stop words

# %%
with open("data/stopwords_openmaker.txt", "r") as f:
    STOP_WORDS_OPENMAKER = set(f.read().strip().split("\n"))
print(STOP_WORDS_OPENMAKER)
# Out:
# {'may', 'well', 'one', 'often', 'almost', 'also', 'many'}

# %% [markdown]
# ## 3. Removing stop words from the reference English corpus

# %%
# merging the two list together
STOP_WORDS = STOP_WORDS_STANDARD.union(STOP_WORDS_OPENMAKER)
print(STOP_WORDS)
# Out:
# {'as', 'up', 'she', 'until', "weren't", 'too', "wouldn't", 'yours', "what's", 'most', 'there', 'it', 'for', "we'll", 'whom', "she'll", 'further', 'cannot', 'that', 'his', 'hers', 'from', 'ought', 'under', 'he', 'they', "it's", 'having', "you're", 'been', "when's", 'of', "can't", 'doing', "we'd", 'was', "hadn't", 'often', 'to', 'out', 'does', 'so', "doesn't", 'after', 'because', 'then', 'com', "you'd", 'yourselves', "they'd", 'them', 'each', 'again', "won't", "that's", 'off', 'almost', "he'd", 'http', 'am', 'nor', 'ourselves', "there's", 'my', 'when', 'who', 'only', 'did', 'its', 'above', 'and', 'where', 'into', 'also', 'many', 'such', 'would', 'all', 'well', "i've", 'has', "i'd", 'themselves', 'being', "i'll", 'but', 'other', 'were', "hasn't", 'have', 'what', 'through', 'with', 'do', "how's", 'more', "where's", 'once', 'get', "shan't", 'how', 'by', 'own', 'than', 'him', "here's", 'one', "they're", "let's", "we've", 'itself', "don't", "he'll", 'about', 'at', 'like', 'theirs', 'your', 'had', 'any', 'could', 'why', 'if', "you'll", 'few', "you've", "wasn't", "i'm", 'those', "she's", 'an', 'during', 'below', 'me', "haven't", "they've", 'not', 'same', 'this', 'on', 'myself', 'r', 'before', 'just', 'in', 'herself', 'or', 'is', 'should', 'down', "she'd", 'while', 'their', "aren't", 'over', 'between', 'our', 'you', 'know', 'both', "couldn't", "isn't", 'a', 'can', 'which', 'himself', 'no', 'yourself', 'are', 'very', "mustn't", "we're", 'i', 'some', "why's", "shouldn't", 'we', 'here', 'ours ', 'the', 'be', "he's", 'may', 'her', 'these', "they'll", "didn't", 'www', "who's"}

# %%
# load english words from the Brown corpus removing stop words.
english_freq_dist = FreqDist([w.lower() for w in nltk.corpus.brown.words()
                              if w not in STOP_WORDS])

# %% [markdown]
# ## 4. Removing the rare words.

# %% [markdown]
# Below we remove rare words and get total count. The code below keeps all words with a occurance frequency above 2.

# %%
english_freq_dist = {k:v for k,v in english_freq_dist.items() if v > 2}

# %% [markdown]
# ## 5. Loading the input Open Maker corpus

# %%
# load the harvested text from wikipedia.
with open("data/wikipedia.json", "r") as f: OM_Corpus_text = f.read()
OM_Corpus = json.loads(OM_Corpus_text)

# %%
# The total number of wiki articles used:
print(len(OM_Corpus))
# Out:
# 152

# %%
# Column names of the the corpus.
OM_Corpus[0].keys()
# Out:
# dict_keys(['theme.id', 'title', 'url', 'depth', 'text'])

# %%
def display_pages(tid):
    meme = [page for page in OM_Corpus if page['theme.id'] == tid]
    for m in meme:
        print(m['depth'],m['title'], m['url'])

# %%
display_pages(0)
# Out:
# 0 Do it yourself https://en.wikipedia.org/wiki/Do_it_yourself
# 1 Edupunk https://en.wikipedia.org/wiki/Edupunk
# 1 Prosumer https://en.wikipedia.org/wiki/Prosumer
# 1 How-to https://en.wikipedia.org/wiki/How-to
# 1 Kludge https://en.wikipedia.org/wiki/Kludge
# 1 Bricolage https://en.wikipedia.org/wiki/Bricolage
# 1 Junk box https://en.wikipedia.org/wiki/Junk_box
# 1 Number 8 wire https://en.wikipedia.org/wiki/Number_8_wire
# 1 Ready-to-assemble furniture https://en.wikipedia.org/wiki/Ready-to-assemble_furniture
# 1 Design thinking https://en.wikipedia.org/wiki/Design_thinking
# 1 Role-based collaboration https://en.wikipedia.org/wiki/Role-based_collaboration
# 1 Intranet portal https://en.wikipedia.org/wiki/Intranet_portal
# 1 Critical thinking https://en.wikipedia.org/wiki/Critical_thinking
# 1 Facilitation (business) https://en.wikipedia.org/wiki/Facilitation_(business)
# 1 Collaborative software https://en.wikipedia.org/wiki/Collaborative_software
# 1 Postpartisan https://en.wikipedia.org/wiki/Postpartisan
# 1 Collaborative search engine https://en.wikipedia.org/wiki/Collaborative_search_engine
# 1 Crowdsourcing https://en.wikipedia.org/wiki/Crowdsourcing
# 1 Conference call https://en.wikipedia.org/wiki/Conference_call
# 1 Collaborative leadership https://en.wikipedia.org/wiki/Collaborative_leadership
# 1 Learning circle https://en.wikipedia.org/wiki/Learning_circle
# 1 Unorganisation https://en.wikipedia.org/wiki/Unorganisation
# 1 Digital collaboration https://en.wikipedia.org/wiki/Digital_Collaboration
# 1 Collaborative translation https://en.wikipedia.org/wiki/Collaborative_translation
# 1 Classical music written in collaboration https://en.wikipedia.org/wiki/Classical_music_written_in_collaboration

# %% [markdown]
# ## 6. Analyzing a specific corpus based on a theme

# %%
# Note that theme.id: 0 corresponds to the the Do IT YOURSELF
input_text = " ".join([page['text'] for page in OM_Corpus if page['theme.id'] == 0])

# %%
# Tokenizing the input text:
tokenized = tokenizer.tokenize_words(input_text)
number_of_words = len(tokenized)
print(number_of_words),OM_Corpus[0]['title']
# Out:
# 59758
# (None, 'Do it yourself')

# %% [markdown]
# ### 6.1 Computing frequency distributions of each token, i.e word, term, pancuation, etc.

# %%
input_freq_dist = FreqDist(tokenized)

# %%
input_freq_dist.most_common(20)
# Out:
# [('\n', 5728),
#  ('the', 2809),
#  ('and', 1980),
#  ('of', 1849),
#  ('to', 1509),
#  ('in', 1199),
#  ('a', 1191),
#  ('"', 593),
#  ('is', 587),
#  ('for', 561),
#  ('as', 465),
#  ('that', 454),
#  ('by', 391),
#  ('on', 363),
#  ('or', 343),
#  ('are', 323),
#  ('thinking', 323),
#  ('with', 310),
#  ('design', 295),
#  ('be', 277)]

# %% [markdown]
# ### 6.2 Removing punctuation and stopwords from the input corpus

# %%
for stopword in STOP_WORDS:
    if stopword in input_freq_dist:
        del input_freq_dist[stopword]
        
for punctuation in tokenizer.CHARACTERS_TO_SPLIT:
    if punctuation in input_freq_dist:
        del input_freq_dist[punctuation]

# Re-control most common words after cleaning:
input_freq_dist.most_common(80)
# Out:
# [('thinking', 323),
#  ('design', 295),
#  ('collaborative', 218),
#  ('collaboration', 202),
#  ('crowdsourcing', 172),
#  ('work', 155),
#  ('knowledge', 147),
#  ('community', 138),
#  ('process', 132),
#  ('information', 120),
#  ('critical', 110),
#  ('learning', 109),
#  ('management', 105),
#  ('research', 104),
#  ('used', 89),
#  ('project', 87),
#  ('business', 86),
#  ('people', 86),
#  ('use', 86),
#  ('social', 85),
#  ('new', 85),
#  ('film', 84),
#  ('users', 80),
#  ('first', 75),
#  ('different', 74),
#  ('students', 74),
#  ('telepresence', 74),
#  ('public', 70),
#  ('problems', 70),
#  ('ideas', 68),
#  ('software', 66),
#  ('group', 65),
#  ('development', 65),
#  ('time', 64),
#  ('problem', 61),
#  ('example', 61),
#  ('systems', 61),
#  ('conference', 59),
#  ('projects', 57),
#  ('call', 57),
#  ('methods', 56),
#  ('skills', 55),
#  ('system', 55),
#  ('using', 53),
#  ('participants', 52),
#  ('technology', 51),
#  ('world', 51),
#  ('together', 51),
#  ('online', 51),
#  ('help', 50),
#  ('tools', 50),
#  ('music', 49),
#  ('free', 49),
#  ('leadership', 48),
#  ('include', 48),
#  ('open', 48),
#  ('solutions', 48),
#  ('human', 47),
#  ('allows', 46),
#  ('way', 46),
#  ('examples', 44),
#  ('members', 44),
#  ('form', 43),
#  ('search', 43),
#  ('communication', 42),
#  ('education', 42),
#  ('tasks', 42),
#  ('sharing', 42),
#  ('term', 42),
#  ('practice', 42),
#  ('large', 42),
#  ('number', 42),
#  ('however', 42),
#  ('will', 42),
#  ('issues', 42),
#  ('two', 41),
#  ('share', 41),
#  ('wrote', 41),
#  ('innovation', 41),
#  ('access', 41)]

# %% [markdown]
# ### 6.3 Removing rare words from input distribution

# %%
input_freq_dist = {k:v for k,v in input_freq_dist.items() if v > 1}

# %% [markdown]
# ## 7. Comparing input vs English corpus volumes

# %% [markdown]
# ### 7.1 Total words (after cleaning)

# %%
n_input = sum(input_freq_dist.values())
n_english = sum(english_freq_dist.values())
n_input, n_english
# Out:
# (28583, 679519)

# %% [markdown]
# ### 7.2 Unique words (after cleaning)

# %%
n_unique_word_input = len(input_freq_dist.items())
n_unique_word_brown = len(english_freq_dist.items())
n_unique_word_input, n_unique_word_brown
# Out:
# (3833, 20591)

# %% [markdown]
# ### 7.3 Cleaned set of input words/terms

# %% [markdown]
# List of words in the corpus in case, for a visual inspection. Such inspections will be used both to improve tokenization as well as filtering.

# %%
input_freq_dist
# Out:
# {'collaboration': 202,
#  'uses': 21,
#  'see': 22,
#  'disambiguation': 2,
#  'definition': 18,
#  'music': 49,
#  'two': 41,
#  'artists': 11,
#  'featuring': 2,
#  'purposeful': 5,
#  'relationship': 20,
#  'parties': 14,
#  'strategically': 2,
#  'choose': 5,
#  'cooperate': 4,
#  'order': 38,
#  'achieve': 13,
#  'shared': 33,
#  'overlapping': 3,
#  'objectives': 7,
#  'collaborative': 218,
#  'leadership': 48,
#  'developing': 19,
#  'effective': 19,
#  'partnerships': 11,
#  'communities': 26,
#  'schools': 22,
#  'rubin': 3,
#  'explains': 7,
#  'b': 4,
#  'voluntary': 5,
#  'nature': 15,
#  'success': 14,
#  'depends': 5,
#  "leader's": 2,
#  'ability': 26,
#  'build': 11,
#  'maintain': 5,
#  'relationships': 15,
#  'similar': 20,
#  'closely': 9,
#  'cooperation': 9,
#  'requires': 16,
#  'although': 17,
#  'form': 43,
#  'social': 85,
#  'within': 35,
#  'decentralized': 2,
#  'group': 65,
#  'teams': 14,
#  'work': 155,
#  'collaboratively': 4,
#  'obtain': 8,
#  'greater': 13,
#  'resources': 30,
#  'recognition': 4,
#  'reward': 5,
#  'facing': 4,
#  'competition': 7,
#  'structured': 4,
#  'methods': 56,
#  'encourage': 7,
#  'behavior': 8,
#  'communication': 42,
#  'specifically': 8,
#  'aim': 5,
#  'increase': 11,
#  'engage': 14,
#  'problem': 61,
#  'solving': 23,
#  'forms': 23,
#  'charts': 3,
#  'useful': 13,
#  'situations': 7,
#  'objectively': 2,
#  'document': 20,
#  'personal': 16,
#  'traits': 11,
#  'goal': 21,
#  'improving': 3,
#  'performance': 13,
#  'current': 12,
#  'future': 24,
#  'projects': 57,
#  'present': 18,
#  'opposing': 2,
#  'goals': 12,
#  'notion': 8,
#  'adversarial': 2,
#  'though': 14,
#  'common': 32,
#  'case': 15,
#  'using': 53,
#  'word': 8,
#  'classical': 15,
#  'examples': 44,
#  'trade': 9,
#  'community': 138,
#  'organization': 33,
#  'intentional': 9,
#  'indigenous': 8,
#  'capitalism': 3,
#  'game': 8,
#  'theory': 26,
#  'military-industrial': 3,
#  'complex': 31,
#  'project': 87,
#  'management': 105,
#  'academia': 4,
#  'occupational': 2,
#  'arts': 12,
#  'art': 20,
#  'groups': 38,
#  'ballet': 15,
#  'business': 86,
#  'education': 42,
#  'entertainment': 9,
#  'publishing': 4,
#  'science': 33,
#  'medicine': 7,
#  'technology': 51,
#  'wartime': 2,
#  'reading': 7,
#  'goods': 4,
#  'economic': 15,
#  'activity': 14,
#  'providing': 14,
#  'mutual': 10,
#  'benefit': 11,
#  'originated': 2,
#  'start': 8,
#  'prehistoric': 2,
#  'times': 16,
#  'trading': 2,
#  'main': 15,
#  'people': 86,
#  'services': 38,
#  'thing': 8,
#  'modern': 14,
#  'day': 6,
#  'peter': 10,
#  'dates': 4,
#  'history': 14,
#  'long-distance': 2,
#  'years': 21,
#  'ago': 2,
#  'exists': 8,
#  'reasons': 6,
#  'due': 22,
#  'division': 3,
#  'labor': 10,
#  'concentrate': 3,
#  'small': 17,
#  'aspect': 7,
#  'production': 27,
#  'products': 29,
#  'regions': 3,
#  'different': 74,
#  'comparative': 2,
#  'advantage': 8,
#  'size': 6,
#  'allows': 46,
#  'benefits': 19,
#  'mass': 18,
#  'market': 16,
#  'prices': 3,
#  'locations': 5,
#  'section': 20,
#  'cite': 7,
#  'sources': 23,
#  'please': 18,
#  'help': 50,
#  'improve': 29,
#  'adding': 14,
#  'citations': 17,
#  'reliable': 10,
#  'unsourced': 10,
#  'material': 12,
#  'challenged': 13,
#  'removed': 15,
#  'november': 10,
#  'learn': 29,
#  'remove': 20,
#  'template': 18,
#  'message': 21,
#  'members': 44,
#  'provides': 14,
#  'typically': 22,
#  'hold': 6,
#  'political': 21,
#  'vision': 15,
#  'share': 41,
#  'responsibilities': 5,
#  'include': 48,
#  'land': 5,
#  'kibbutzim': 4,
#  'housing': 2,
#  'new': 85,
#  'selected': 3,
#  'existing': 6,
#  'membership': 6,
#  'rather': 30,
#  'agents': 4,
#  'owned': 2,
#  'austria': 2,
#  'century': 14,
#  'units': 2,
#  'built': 10,
#  'assigned': 5,
#  'individual': 31,
#  'belong': 2,
#  'colony': 2,
#  'little': 9,
#  'property': 4,
#  'taken': 14,
#  'entire': 11,
#  'long': 21,
#  'room': 8,
#  'oneida': 3,
#  'york': 9,
#  'practiced': 2,
#  'sense': 20,
#  'communal': 3,
#  'criticism': 6,
#  'every': 17,
#  'member': 11,
#  'subject': 13,
#  'committee': 3,
#  'whole': 11,
#  'general': 19,
#  'meeting': 37,
#  'eliminate': 2,
#  'bad': 3,
#  'character': 2,
#  'early': 27,
#  'kibbutz': 3,
#  'founded': 10,
#  'near': 2,
#  'collective': 21,
#  'movement': 22,
#  'combines': 4,
#  'zionism': 2,
#  'practical': 13,
#  'time': 64,
#  'independent': 11,
#  'perhaps': 6,
#  'forced': 2,
#  'necessity': 3,
#  'life': 16,
#  'ideology': 3,
#  'developed': 32,
#  'mode': 7,
#  'living': 2,
#  'attracted': 2,
#  'interest': 16,
#  'world': 51,
#  'several': 18,
#  'generations': 4,
#  'utopian': 2,
#  "today's": 4,
#  'capitalist': 2,
#  'enterprises': 3,
#  'regular': 4,
#  'originally': 10,
#  'supposed': 2,
#  'alternatives': 4,
#  'citation': 16,
#  'needed': 23,
#  'particularly': 10,
#  'americas': 2,
#  'includes': 19,
#  'working': 26,
#  'toward': 9,
#  'structure': 15,
#  'flexible': 11,
#  'children': 9,
#  'american': 12,
#  'collaborate': 17,
#  'rest': 3,
#  'allowed': 11,
#  'want': 6,
#  'participate': 18,
#  'freely': 3,
#  'adults': 2,
#  'contributors': 9,
#  'process': 132,
#  'taking': 16,
#  'tasks': 42,
#  'suit': 3,
#  'skills': 55,
#  'learning': 109,
#  'techniques': 26,
#  'example': 61,
#  'study': 24,
#  'mayan': 2,
#  'fathers': 2,
#  'traditional': 30,
#  'ways': 27,
#  'worked': 8,
#  'together': 51,
#  'frequently': 7,
#  'building': 26,
#  '3d': 3,
#  'model': 35,
#  'western': 2,
#  'value': 23,
#  'around': 19,
#  'house': 3,
#  'mexico': 2,
#  'school': 35,
#  'show': 5,
#  'initiative': 5,
#  'autonomy': 4,
#  'contributing': 5,
#  'classroom': 7,
#  'completing': 4,
#  'activities': 23,
#  'assisting': 2,
#  'teacher': 8,
#  'lectures': 2,
#  'made': 21,
#  'installation': 3,
#  'becomes': 5,
#  'class': 7,
#  'students': 74,
#  'alongside': 4,
#  'without': 16,
#  'needing': 2,
#  'movements': 11,
#  'instruction': 7,
#  'hands-on': 4,
#  'experience': 24,
#  'synchronous': 3,
#  'roles': 13,
#  'sharing': 42,
#  'emphasized': 3,
#  'learners': 3,
#  'take': 29,
#  'works': 26,
#  'attempt': 6,
#  'experienced': 4,
#  'complete': 17,
#  'parts': 7,
#  'others': 31,
#  'pay': 11,
#  'close': 3,
#  'attention': 5,
#  'rand': 4,
#  'live': 8,
#  'isolated': 3,
#  'recognized': 6,
#  'crucial': 3,
#  'way': 46,
#  'develop': 32,
#  'pursue': 4,
#  'rational': 8,
#  'self-interest': 2,
#  'strong': 11,
#  'whether': 13,
#  'kind': 9,
#  'wrote': 41,
#  'hundreds': 3,
#  'pages': 3,
#  'collaborating': 5,
#  'participants': 52,
#  'connected': 6,
#  'free': 49,
#  'exchanged': 2,
#  'always': 11,
#  'presenting': 5,
#  'explained': 2,
#  'acting': 6,
#  'ones': 6,
#  'entails': 4,
#  'looking': 3,
#  'protect': 2,
#  'innocent': 2,
#  'injustice': 2,
#  'aid': 7,
#  'friends': 2,
#  'support': 31,
#  'applied': 13,
#  'mathematics': 4,
#  'economics': 2,
#  'multiple': 28,
#  'players': 6,
#  'make': 36,
#  'decisions': 10,
#  'first': 75,
#  'documented': 4,
#  'discussion': 15,
#  'letter': 3,
#  'written': 37,
#  'james': 2,
#  'waldegrave': 2,
#  "'s": 33,
#  'mathematical': 8,
#  'principles': 33,
#  'wealth': 2,
#  'provided': 16,
#  'became': 6,
#  'unique': 8,
#  'field': 27,
#  'john': 15,
#  'von': 5,
#  'neumann': 2,
#  'published': 27,
#  'series': 14,
#  'papers': 5,
#  'book': 29,
#  'games': 5,
#  'needs': 35,
#  'additional': 13,
#  'better': 27,
#  'verification': 5,
#  'article': 35,
#  'term': 42,
#  'refers': 17,
#  'among': 32,
#  'armed': 2,
#  'forces': 3,
#  'private': 17,
#  'industry': 24,
#  'associated': 13,
#  'commercial': 10,
#  'interests': 9,
#  'system': 55,
#  'military': 3,
#  'dependent': 3,
#  'supply': 4,
#  'defense': 3,
#  'government': 34,
#  'revenue': 6,
#  'skunk': 2,
#  'used': 89,
#  'engineering': 24,
#  'technical': 16,
#  'fields': 22,
#  'describe': 12,
#  'given': 25,
#  'high': 18,
#  'degree': 13,
#  'bureaucracy': 3,
#  'advanced': 7,
#  'lockheed': 2,
#  'team': 30,
#  'highly': 10,
#  'innovative': 9,
#  'short': 8,
#  'even': 27,
#  'days': 10,
#  'said': 8,
#  'basic': 5,
#  'operating': 6,
#  'rules': 13,
#  'manhattan': 3,
#  'nuclear': 2,
#  'bomb': 5,
#  'war': 8,
#  'ii': 11,
#  'united': 25,
#  'states': 27,
#  'kingdom': 3,
#  'canada': 3,
#  'formally': 4,
#  'designated': 3,
#  'engineer': 3,
#  'period': 3,
#  'control': 17,
#  'u': 10,
#  's': 28,
#  'army': 4,
#  'engineers': 5,
#  'administration': 10,
#  'scientific': 26,
#  'research': 104,
#  'directed': 5,
#  'j': 6,
#  'robert': 15,
#  'aforementioned': 2,
#  'persons': 5,
#  'influence': 8,
#  'organized': 8,
#  'attributed': 3,
#  'bush': 3,
#  'creation': 15,
#  'national': 10,
#  'previous': 4,
#  'failures': 4,
#  'implementing': 7,
#  'sought': 2,
#  'organize': 8,
#  'power': 12,
#  'three': 26,
#  'test': 12,
#  'plutonium': 2,
#  'july': 2,
#  'code-named': 2,
#  'boy': 2,
#  'august': 2,
#  'japan': 4,
#  'second': 19,
#  'man': 3,
#  'ships': 2,
#  'four': 25,
#  'required': 20,
#  'approaches': 24,
#  'manufacturing': 5,
#  'discipline': 10,
#  'application': 23,
#  'including': 29,
#  'construction': 7,
#  'henry': 5,
#  'gantt': 2,
#  'called': 29,
#  'planning': 22,
#  'famously': 2,
#  'known': 22,
#  'use': 86,
#  'bar': 2,
#  'chart': 2,
#  'tool': 12,
#  'associate': 2,
#  'frederick': 2,
#  'taylor': 2,
#  'theories': 4,
#  'navy': 2,
#  'tools': 50,
#  'resource': 8,
#  'allocation': 2,
#  '1950s': 3,
#  'marked': 4,
#  'beginning': 11,
#  'era': 2,
#  'prior': 6,
#  'managed': 4,
#  'ad': 2,
#  'hoc': 2,
#  'basis': 8,
#  'mostly': 9,
#  'informal': 8,
#  'scheduling': 2,
#  'models': 23,
#  'program': 27,
#  'evaluation': 8,
#  'review': 13,
#  'technique': 6,
#  'part': 39,
#  'conjunction': 2,
#  'corporation': 9,
#  'critical': 110,
#  'path': 4,
#  'method': 16,
#  'joint': 4,
#  'venture': 4,
#  'managing': 14,
#  'maintenance': 5,
#  'quickly': 11,
#  'spread': 3,
#  'institute': 14,
#  'pmi': 3,
#  'formed': 6,
#  'serve': 5,
#  'premise': 2,
#  'widespread': 3,
#  'software': 66,
#  'board': 7,
#  'directors': 3,
#  'development': 65,
#  'become': 24,
#  'guide': 7,
#  'body': 6,
#  'knowledge': 147,
#  'standards': 6,
#  'guidelines': 2,
#  'practice': 42,
#  'widely': 6,
#  'throughout': 6,
#  'profession': 5,
#  'international': 19,
#  'association': 4,
#  'ipma': 2,
#  'europe': 4,
#  'organizations': 27,
#  'now': 15,
#  'participating': 7,
#  'global': 24,
#  'standard': 6,
#  'black': 7,
#  'mountain': 7,
#  'college': 17,
#  'andrew': 6,
#  'theodore': 2,
#  'former': 10,
#  'faculty': 4,
#  'experimental': 3,
#  'committed': 4,
#  'interdisciplinary': 5,
#  'approach': 30,
#  'included': 9,
#  'leading': 7,
#  'visual': 17,
#  'designers': 30,
#  'relatively': 5,
#  'location': 28,
#  'budget': 8,
#  'spirit': 3,
#  'instructors': 2,
#  'innovations': 3,
#  'connections': 9,
#  'prove': 2,
#  'lasting': 2,
#  'scene': 3,
#  'culture': 31,
#  'eventually': 4,
#  'pop': 3,
#  'met': 2,
#  'student': 10,
#  'result': 13,
#  'back': 12,
#  'dance': 3,
#  'company': 34,
#  'staged': 3,
#  'happening': 2,
#  'conceived': 3,
#  'consciously': 3,
#  'grew': 4,
#  'educational': 16,
#  'experiment': 4,
#  'writers': 5,
#  'conducted': 5,
#  'important': 31,
#  'proved': 2,
#  'prototype': 8,
#  'alternative': 9,
#  'colleges': 3,
#  'today': 10,
#  'university': 31,
#  'california': 5,
#  'evergreen': 3,
#  'state': 13,
#  'roth': 2,
#  'stuart': 3,
#  'lee': 2,
#  'assert': 2,
#  '1990s': 6,
#  'focus': 25,
#  'observed': 5,
#  'researchers': 20,
#  'practitioners': 5,
#  'idea': 28,
#  'knowing': 7,
#  'thought': 17,
#  'cultural': 8,
#  'claim': 5,
#  'led': 9,
#  'changes': 11,
#  'teaching': 16,
#  'design': 295,
#  'encouraged': 6,
#  'words': 9,
#  'domains': 2,
#  'effect': 11,
#  'analysis': 33,
#  'account': 4,
#  'appearance': 3,
#  '1980s': 7,
#  'considered': 15,
#  'pioneer': 2,
#  'area': 7,
#  'established': 12,
#  'washington': 2,
#  'center': 10,
#  'quality': 26,
#  'focuses': 7,
#  'rare': 2,
#  'compared': 9,
#  'popular': 19,
#  'notable': 9,
#  'composers': 36,
#  'hexameron': 2,
#  'set': 36,
#  'variations': 25,
#  'solo': 8,
#  'piano': 27,
#  'theme': 15,
#  'vincenzo': 3,
#  'bellini': 2,
#  'opera': 16,
#  'puritani': 2,
#  'performed': 8,
#  'franz': 10,
#  'liszt': 9,
#  'frdric': 8,
#  'chopin': 10,
#  'carl': 5,
#  'czerny': 3,
#  'sigismond': 2,
#  'thalberg': 2,
#  'johann': 5,
#  'pixis': 2,
#  'henri': 5,
#  'herz': 2,
#  'f-a-e': 2,
#  'sonata': 4,
#  'violin': 3,
#  'gift': 2,
#  'violinist': 2,
#  'joseph': 6,
#  'joachim': 2,
#  'albert': 3,
#  'dietrich': 2,
#  'schumann': 5,
#  'fourth': 3,
#  'johannes': 2,
#  'brahms': 2,
#  'third': 7,
#  'lone': 5,
#  'genius': 2,
#  'artist': 3,
#  'existed': 2,
#  'since': 23,
#  'vasari': 2,
#  'lives': 4,
#  'artistic': 6,
#  'skill': 10,
#  'upon': 9,
#  'chosen': 5,
#  'individuals': 37,
#  'created': 21,
#  'largely': 4,
#  'false': 4,
#  'processes': 29,
#  'large': 42,
#  'scale': 6,
#  'centuries': 2,
#  'questioned': 2,
#  'public': 70,
#  'consciousness': 4,
#  '1960s': 6,
#  '1970s': 5,
#  'experiments': 2,
#  'girls': 3,
#  'easy': 5,
#  'fashion': 2,
#  'venue': 2,
#  'lighting': 3,
#  'etc': 18,
#  'person': 22,
#  'product': 35,
#  'earliest': 4,
#  'formal': 14,
#  'great': 7,
#  '19th': 2,
#  'pyotr': 2,
#  'tchaikovsky': 2,
#  '20th': 3,
#  'george': 5,
#  'igor': 4,
#  'stravinsky': 4,
#  'companies': 35,
#  'feature': 7,
#  'essential': 6,
#  'choreographer': 2,
#  'dancer': 3,
#  'creates': 7,
#  'head': 5,
#  'physically': 3,
#  'sees': 3,
#  'attempts': 2,
#  'either': 12,
#  'mimic': 2,
#  'interpret': 2,
#  '-': 32,
#  'found': 29,
#  'ranges': 2,
#  'partnership': 7,
#  'crowd': 39,
#  'funding': 5,
#  'complexity': 13,
#  'agree': 3,
#  'invest': 3,
#  'mutually': 2,
#  'information': 120,
#  'rewards': 8,
#  'jointly': 8,
#  'solve': 16,
#  'problems': 70,
#  'sectors': 18,
#  'tackling': 2,
#  'policy': 35,
#  'handled': 2,
#  'effectively': 11,
#  'networks': 11,
#  'organizational': 18,
#  'structures': 8,
#  'chains': 3,
#  'ideas': 68,
#  'numerous': 6,
#  'generate': 6,
#  'wide': 13,
#  'variety': 16,
#  'firms': 5,
#  'opposed': 5,
#  'number': 42,
#  'shown': 10,
#  'impact': 16,
#  'firm': 8,
#  'innovation': 41,
#  'outcomes': 12,
#  'recent': 19,
#  'improvement': 3,
#  'speed': 4,
#  'internet': 39,
#  'connection': 3,
#  'web-based': 8,
#  'blogs': 9,
#  'wikis': 14,
#  'efficiently': 4,
#  'able': 15,
#  'communicate': 8,
#  'conferences': 8,
#  'geographical': 3,
#  'barriers': 2,
#  'file': 6,
#  'transfer': 8,
#  'evan': 2,
#  'rosen': 6,
#  'author': 8,
#  'defines': 3,
#  'create': 32,
#  'virtual': 27,
#  'physical': 14,
#  'space': 17,
#  'according': 20,
#  'studies': 19,
#  'powerful': 5,
#  'towards': 18,
#  'higher': 17,
#  'increased': 15,
#  'productivity': 9,
#  'efficacy': 3,
#  'significantly': 4,
#  'aspirations': 3,
#  'motivational': 2,
#  'investment': 5,
#  'challenges': 22,
#  'however': 42,
#  'successful': 21,
#  'rapidly': 2,
#  'external': 5,
#  'relations': 4,
#  'trust': 13,
#  'specific': 29,
#  'level': 20,
#  'coworking': 2,
#  'spaces': 4,
#  'businesses': 14,
#  'dedicated': 3,
#  'environment': 25,
#  'five': 7,
#  'core': 7,
#  'values': 6,
#  'openness': 8,
#  'accessibility': 2,
#  'sustainability': 3,
#  'play': 7,
#  'media': 36,
#  'german': 3,
#  'classrooms': 3,
#  'across': 26,
#  'grade': 3,
#  'levels': 17,
#  'content': 32,
#  'areas': 7,
#  'regarded': 2,
#  'special': 10,
#  'teachers': 13,
#  'generally': 16,
#  'defined': 17,
#  'professionals': 5,
#  'delivering': 3,
#  'diverse': 11,
#  'single': 13,
#  'increasingly': 12,
#  'educators': 18,
#  'english': 7,
#  'languages': 9,
#  'varied': 2,
#  'academic': 17,
#  'provide': 23,
#  'inclusive': 2,
#  'receive': 11,
#  'separate': 6,
#  'remain': 7,
#  'place': 20,
#  'past': 5,
#  'decades': 3,
#  'conceptualizing': 3,
#  'understand': 20,
#  'expansion': 3,
#  'types': 8,
#  'resulted': 3,
#  'transformation': 2,
#  'economy': 6,
#  'technologies': 22,
#  'industries': 5,
#  'transformations': 3,
#  'projected': 2,
#  'federal': 7,
#  'reports': 6,
#  'nation': 5,
#  'risk': 9,
#  'capacity': 13,
#  'manage': 12,
#  'successfully': 5,
#  'continuing': 3,
#  'web': 37,
#  'online': 51,
#  'twitter': 6,
#  'changed': 6,
#  'manner': 3,
#  'establish': 9,
#  'environments': 12,
#  'materials': 2,
#  'feedback': 10,
#  'cases': 9,
#  'circle': 30,
#  '21st': 7,
#  'musical': 21,
#  'occurs': 5,
#  'musicians': 2,
#  'places': 3,
#  'album': 2,
#  'song': 8,
#  'involved': 16,
#  'producers': 5,
#  'come': 22,
#  'represents': 7,
#  'type': 13,
#  'paul': 6,
#  'west': 2,
#  'currently': 12,
#  'especially': 9,
#  'regards': 2,
#  'websites': 7,
#  'facilitate': 8,
#  'resulting': 5,
#  'emergence': 4,
#  'exist': 8,
#  'grammy': 3,
#  'award': 5,
#  'best': 27,
#  'country': 6,
#  'vocals': 2,
#  'awarded': 3,
#  'constant': 4,
#  'electroacoustic': 4,
#  'laboratories': 2,
#  'electronic': 11,
#  'studios': 2,
#  'presence': 9,
#  'intertwined': 2,
#  'competencies': 3,
#  'particular': 11,
#  'embedding': 2,
#  'technological': 6,
#  'agent': 2,
#  'expertise': 13,
#  'assistant': 7,
#  'technician': 2,
#  'tutor': 2,
#  'computer': 25,
#  'designer': 5,
#  'mediator': 2,
#  'described': 16,
#  'phase': 15,
#  'writing': 28,
#  'creating': 19,
#  'instruments': 7,
#  'recording': 5,
#  'andor': 9,
#  'possibilities': 4,
#  'various': 15,
#  'applications': 25,
#  'potential': 21,
#  'sound': 13,
#  'effects': 6,
#  'composer': 11,
#  'latter': 3,
#  'sufficient': 3,
#  'programme': 2,
#  'clear': 19,
#  'results': 27,
#  'translates': 2,
#  'programming': 4,
#  'finally': 5,
#  'transforms': 2,
#  'score': 7,
#  'performs': 2,
#  ...}

# %% [markdown]
# ### 7.4 Set of terms/words that occure in both corpus.

# %%
common_words = [w for w in input_freq_dist.keys() & english_freq_dist.keys()]
print(len(common_words))
# Out:
# 3001

# %%
for w in common_words: print(w)
# Out:
# credit
# 19th
# agents
# gold
# heads
# analyze
# yellow
# chosen
# belief
# evaluating
# digital
# multitude
# chief
# though
# substantial
# john
# community
# coalition
# medicine
# discovering
# systemic
# ross
# mark
# 40
# staff
# gaining
# worked
# used
# flood
# room
# pizza
# creativity
# rigorous
# general
# front
# consists
# index
# campaign
# revenue
# actions
# report
# low
# ted
# relationships
# legislation
# without
# skills
# g
# new
# higher
# two-thirds
# organize
# canada
# economic
# saves
# armed
# de
# sold
# logical
# accept
# transactions
# stravinsky
# investors
# transparent
# near
# share
# largest
# assisting
# joseph
# zones
# entire
# n
# route
# possibilities
# hours
# martin
# regions
# side
# user
# learn
# avoid
# courses
# items
# velocity
# convert
# initial
# instrumental
# alongside
# emergence
# potentially
# differently
# children's
# list
# rules
# viewed
# mob
# need
# earn
# observation
# conventional
# brief
# isolated
# london
# growth
# reconstruct
# consensus
# innovation
# embedded
# continuing
# drama
# co-operative
# attempt
# american
# order
# ford
# died
# arena
# event
# shown
# diversity
# sign
# something
# nature
# choices
# rational
# august
# survival
# educated
# exploration
# pioneering
# land
# translated
# simple
# accurate
# donate
# fashion
# mathematics
# attempts
# policy
# nation
# range
# conditions
# another
# condition
# join
# create
# charitable
# frank
# journal
# turbine
# experience
# concentrate
# journals
# nations
# kinds
# group
# array
# chorus
# obstacle
# design
# consisting
# process
# cathedral
# simulated
# arise
# distinguishes
# enables
# census
# personalized
# individual
# daily
# bad
# conflict
# watching
# writing
# tools
# lab
# forth
# necessary
# promotes
# platform
# japan
# bureaucracy
# transaction
# sickness
# devices
# spectrum
# mussorgsky
# appearance
# george
# advanced
# exchange
# dietrich
# divided
# roger
# detail
# tool
# bringing
# shift
# lose
# libraries
# mass
# undertaking
# eventually
# stages
# adopted
# light
# compromise
# known
# phenomenon
# premiere
# advice
# injustice
# tree
# defining
# parts
# intermediate
# ernest
# resulting
# liberation
# comprehend
# uses
# crowds
# main
# stimulate
# allen
# impossible
# subject
# presentations
# maximum
# power
# introduces
# likes
# mechanical
# sessions
# artistic
# driving
# laboratories
# others
# editors
# practical
# thing
# contains
# alone
# decades
# newspapers
# variety
# citation
# authors
# west
# grows
# launch
# living
# anything
# les
# represents
# take
# press
# clarity
# images
# knowing
# earlier
# ideally
# real
# manipulate
# image
# workers
# european
# albert
# version
# leads
# despite
# consistency
# classic
# explicitly
# opposed
# necessity
# irresponsible
# classical
# produced
# million
# reality
# operetta
# brought
# question
# love
# world
# election
# del
# sought
# surgery
# traffic
# policies
# locate
# polling
# direct
# access
# problem
# english
# senses
# battle
# uniform
# owns
# resources
# herbert
# guitar
# beginning
# commons
# spread
# entity
# focused
# linking
# faster
# lives
# meant
# foster
# essay
# one's
# users
# permits
# implementation
# gave
# functional
# groups
# dominant
# species
# false
# extra
# orchestra
# complete
# instances
# portal
# death
# professionals
# helps
# accelerate
# space
# begun
# publication
# education
# broadly
# marketing
# accordingly
# carefully
# shape
# separate
# story
# hand
# levels
# farmers
# trend
# input
# stored
# effectiveness
# profession
# teacher
# solo
# artist
# intentional
# language
# pulls
# experimentation
# two
# malcolm
# connected
# p
# must
# developing
# force
# pressed
# rely
# antonio
# launched
# republican
# artificial
# showing
# stakes
# increased
# insight
# noted
# receiving
# agreed
# dedicated
# autonomy
# games
# needs
# giving
# purposeful
# intent
# smaller
# carriers
# trade
# impressive
# framed
# pierre
# discussions
# majority
# operation
# apply
# act
# stage
# number
# sea
# providing
# freely
# monthly
# argue
# citizen
# barriers
# shaped
# president
# sales
# draws
# shower
# positive
# hands
# solved
# candidates
# fathers
# huddle
# features
# centuries
# manipulation
# creation
# speed
# circular
# expected
# jacques
# violin
# timely
# purpose
# s
# film
# judgments
# school
# un
# winning
# circle
# objectives
# photos
# chat
# partly
# calendar
# automatically
# follow
# projects
# combination
# belong
# 20th
# 1
# according
# good
# classroom
# replace
# innate
# gains
# university
# differs
# posted
# promising
# base
# ratings
# lowest
# experienced
# play
# wilson
# beliefs
# job
# passed
# letter
# colony
# aid
# link
# significant
# submit
# clara
# right
# facts
# less
# thread
# tend
# sector
# composition
# inquiry
# young
# great
# lockheed
# maintain
# bird
# additionally
# useful
# concerned
# linked
# volunteers
# working
# highly
# governing
# mix
# executive
# security
# world's
# engagement
# roy
# amateur
# influence
# later
# hour
# removal
# harvey
# size
# assist
# intertwined
# widely
# bombing
# controversy
# prize
# occupation
# consciousness
# flight
# percent
# opportunity
# desire
# tv
# markets
# addition
# reliable
# sponsor
# give
# occupying
# produce
# broadcast
# systematically
# achieve
# raised
# wiley
# conjunction
# communicated
# days
# church
# entries
# failing
# writes
# respective
# discuss
# organization
# crucial
# charge
# emphasis
# conceptual
# anywhere
# editing
# attain
# m
# circumstances
# invite
# past
# function
# conceived
# los
# astronomy
# updated
# separating
# democratic
# musical
# yet
# going
# balance
# shaping
# chart
# douglas
# independently
# printed
# institute
# alkali
# utilize
# publish
# experiments
# free
# desirable
# budget
# '
# dewey
# coordinated
# refined
# debate
# team
# contests
# sound
# respect
# collaboration
# department
# influenced
# border
# value
# pets
# interpret
# rewards
# type
# synthesis
# depend
# joined
# want
# managed
# des
# e
# turn
# phrase
# bill
# underlying
# evidence
# covered
# observe
# opposing
# pioneers
# travel
# agreement
# analytical
# received
# raise
# look
# society
# preferences
# mud
# j
# came
# role
# challenged
# tutor
# profit
# large
# keep
# carry
# element
# participants
# broadcasting
# trying
# blocks
# distributed
# seven
# submitting
# january
# association
# rich
# brother
# ownership
# deployed
# using
# describes
# cloud
# content
# founded
# feel
# ranking
# business
# weaknesses
# issues
# given
# around
# studies
# lot
# planned
# coins
# ambiguous
# daniel
# us
# defined
# part
# accompanied
# remain
# expertise
# improve
# transit
# cultural
# write
# processes
# close
# likelihood
# button
# sense
# answers
# april
# movement
# left
# invest
# everything
# talk
# train
# inference
# insights
# beyond
# words
# traditional
# string
# shares
# administrators
# tame
# choreographed
# funds
# reflection
# longer
# davis
# outlined
# jobs
# incentive
# distribution
# former
# francis
# observations
# action
# europe
# company
# confidence
# advent
# differences
# natural
# continually
# described
# competition
# ego
# sensation
# importance
# abstract
# filtering
# year
# formal
# dispersed
# umbrella
# aaron
# industry
# improvement
# comparisons
# announce
# voice
# procedures
# individuals
# engineering
# mental
# particularly
# months
# judged
# faulty
# prominent
# chamber
# circles
# topic
# accepted
# pass
# sample
# empirical
# officer
# volunteer
# ends
# engineers
# think
# communal
# experiment
# issue
# regard
# 21st
# voting
# developed
# lying
# t
# rapidly
# instance
# develop
# specifically
# fiction
# van
# assistants
# tackle
# emphasizes
# processing
# festival
# disciplines
# depends
# mission
# educators
# institutional
# valuable
# utopian
# opened
# songs
# strategic
# presenting
# site
# teaching
# moment
# external
# films
# gathering
# scott
# niche
# serve
# responsibility
# reduced
# crisis
# acquired
# eugene
# characterize
# impression
# note
# operating
# huge
# audiences
# bias
# planet
# ability
# techniques
# musicians
# l
# meeting
# remote
# maria
# explains
# ibm
# jointly
# considers
# companies
# amongst
# conflicts
# motivated
# convincing
# difficult
# guidance
# flexible
# bank
# provide
# independent
# grand
# referring
# short
# topics
# refer
# amount
# efficacy
# testing
# success
# prepare
# looking
# teams
# potential
# teenage
# enable
# peers
# wrote
# evaluation
# composers
# capacities
# garry
# analyzing
# variables
# best
# will
# limits
# gradually
# corporation
# inflexible
# builds
# lost
# october
# academic
# otherwise
# entry
# second
# peter
# sets
# 60
# stated
# regional
# materials
# prior
# encouraging
# places
# stays
# copies
# regulation
# philosophy
# patterns
# boston
# host
# monitor
# including
# delivery
# desired
# players
# objective
# returned
# full
# test
# charts
# effective
# mobile
# overlapping
# already
# forum
# changes
# long
# charges
# shareholders
# lines
# concrete
# conversational
# deliberations
# originated
# york
# law
# engine
# post
# dramatic
# specialized
# trends
# discipline
# production
# true
# whereas
# system
# contest
# guides
# following
# involve
# assemble
# find
# extended
# primary
# makes
# symphony
# long-term
# predicting
# king
# said
# enormous
# partisan
# win
# adopting
# louis
# program
# component
# naturally
# historical
# february
# larry
# analogy
# reasoning
# programming
# sometimes
# become
# march
# genuine
# unsolved
# prediction
# suit
# paid
# conforms
# universal
# coordination
# debates
# foundation
# across
# regulatory
# goals
# happen
# misleading
# assumptions
# claimed
# interdependent
# sufficient
# vital
# resolution
# increase
# encouraged
# instant
# let
# house
# else
# birds
# everyone
# delivering
# army
# steps
# suspension
# british
# suitable
# fbi
# applied
# actually
# symbol
# degrees
# adult
# dictionary
# game
# thinkers
# channels
# purposes
# box
# closely
# completely
# countries
# promote
# fidelity
# cite
# term
# directors
# introduced
# seeks
# today's
# obscure
# satisfaction
# computers
# wary
# directly
# books
# line
# firms
# willingness
# maintenance
# recognition
# motivation
# detachment
# agriculture
# regulations
# interaction
# resulted
# since
# upon
# communications
# urban
# theories
# cheaply
# elena
# parties
# constituted
# titled
# disposition
# cinema
# designing
# kind
# varying
# culture
# hearing
# sort
# raymond
# scene
# claim
# washington
# christopher
# ideology
# becoming
# current
# premium
# graduate
# collect
# judith
# variation
# attributed
# communicating
# encompass
# statements
# representatives
# describe
# views
# politics
# modest
# local
# announcements
# equal
# course
# prejudice
# usage
# rare
# audience
# practitioners
# demonstrated
# combine
# acts
# versions
# metropolitan
# effects
# reports
# designers
# data
# come
# en
# publishing
# classes
# beethoven
# jones
# consulting
# interest
# intrinsically
# asset
# hilton
# double
# scientific
# controlled
# administration
# patent
# study
# against
# obvious
# message
# home
# performs
# engage
# studied
# responded
# viable
# aesthetic
# educational
# class
# tried
# lone
# don
# july
# never
# quotes
# war
# origins
# created
# health
# perceives
# distinct
# joe
# outside
# next
# duration
# women
# pieces
# cents
# universities
# k
# subjective
# rule
# award
# assembling
# directed
# teach
# layout
# perspective
# tangible
# traced
# agencies
# exclude
# removed
# limited
# crumb
# integrate
# identification
# collected
# underground
# development
# staged
# talking
# overriding
# tended
# extent
# sites
# dollars
# methods
# table
# paul
# james
# takes
# civil
# creating
# manufacturing
# carl
# precision
# lots
# trio
# alex
# areas
# searches
# elements
# paper
# effect
# cycles
# entertainment
# bomb
# car
# fair
# establish
# gives
# pupil
# state
# intentions
# y
# greatly
# jeff
# infinite
# text
# tim
# projected
# starting
# perspectives
# wage
# schedule
# recording
# publisher
# runs
# theatre
# industries
# engaged
# move
# history
# loss
# cause
# cooperative
# adds
# connection
# newspaper
# rest
# entrepreneur
# submission
# reciprocal
# domain
# introduction
# status
# standard
# plan
# contributed
# core
# allow
# high
# guided
# allowing
# structured
# happens
# forming
# listening
# occupational
# optimism
# differ
# participation
# challenges
# ballet
# equity
# technique
# effort
# employed
# attributes
# finance
# customer
# findings
# promoting
# programs
# significance
# lessons
# public
# organized
# enough
# articles
# genetic
# critically
# regarding
# exercise
# feedback
# implementing
# bush
# family
# physical
# buy
# traveling
# advances
# currently
# el
# foreign
# readers
# presented
# music
# weeds
# intrinsic
# coined
# spaces
# seen
# dialogue
# experts
# suggests
# disadvantages
# definitions
# audio-visual
# explained
# pop
# b
# notion
# geographical
# jonathan
# price
# rates
# movements
# choose
# marvin
# food
# tends
# assessing
# failure
# protect
# climate
# represented
# style
# successful
# implicit
# supports
# easily
# pages
# chris
# thinking
# goal
# phase
# issued
# quite
# innovations
# specialist
# basic
# critics
# utilizing
# drawing
# requests
# transfer
# completed
# feasible
# lists
# stating
# wisdom
# express
# resource
# communicate
# concerto
# possibility
# consequences
# alliance
# hoc
# prime
# theoretical
# widespread
# instead
# states
# michael
# justifications
# messages
# headed
# operations
# mode
# investment
# either
# dating
# claims
# telephone
# aim
# modern
# cult
# henry
# brahms
# explicit
# lighting
# focus
# expanded
# architecture
# alternative
# chinese
# framework
# grouped
# available
# recognized
# based
# college
# careful
# egyptian
# qualities
# likely
# opposite
# movie
# leading
# area
# repository
# played
# heritage
# opinions
# preparation
# applicable
# david
# papers
# contribute
# broader
# seems
# arts
# students'
# clarify
# stock
# productive
# argues
# v
# piece
# designed
# proved
# roles
# continues
# displayed
# organizational
# dialed
# powerful
# person's
# relates
# combines
# piano
# cooperate
# set
# editor
# validity
# verification
# run
# abilities
# pregnancy
# collection
# vs
# solutions
# fine
# man
# french
# governor
# simplified
# trial
# peanuts
# dance
# friends
# began
# assets
# involves
# venture
# template
# vote
# lack
# theory
# authority
# structure
# evaluate
# supporting
# display
# largely
# alter
# verdi
# simpler
# contributing
# understanding
# bundled
# industrial
# teachers
# factors
# india
# dramatically
# productivity
# delayed
# questions
# faced
# neutrality
# skillfully
# andrew
# network
# mitchell
# vision
# improved
# interactions
# protecting
# read
# investigation
# presidential
# minute
# accelerating
# identifies
# initially
# eight
# article
# costs
# intellectually
# frederick
# australia
# built
# products
# economy
# went
# components
# unfortunately
# sonatas
# document
# provided
# entirely
# song
# making
# city
# outline
# businesses
# consideration
# formed
# rev
# hence
# thereby
# variable
# informal
# gilbert
# continuous
# combining
# undefined
# phone
# top
# conveys
# considered
# identity
# print
# indigenous
# idea
# week
# feeling
# sees
# bernard
# decisions
# reduce
# selling
# researcher
# knowledge
# explain
# strong
# merely
# agent
# suddenly
# virtue
# written
# perhaps
# prevent
# client
# stephen
# initiated
# model
# intelligence
# big
# implement
# objectively
# risk
# ludwig
# payment
# compensated
# path
# conservative
# example
# conference
# see
# capitalism
# sensory
# failures
# justice
# values
# reward
# category
# categories
# graphic
# arnold
# efficient
# integration
# translation
# centered
# inclusive
# german
# methodological
# log
# u
# sent
# corporations
# maurice
# publications
# generation
# counting
# cases
# single
# records
# statutory
# virtually

# %% [markdown]
# ### 7.5 Set of terms/words that occure in the sample but not in the reference corpus.

# %% [markdown]
# TO BE EXAMINED: This specific set needs to be incorporated. In fact, it may capture specifity of the content to a great extend. We need to assign a mapping score for each words in this set.

# %%
input_specifics = dict()
for w in input_freq_dist.keys() - english_freq_dist.keys():
    input_specifics[w] = input_freq_dist[w]
    print(w)
# Out:
# prepaid
# atandt
# tagging
# iws
# acm
# website
# dispositions
# ii
# tackling
# losee
# designerly
# self-interest
# josef
# stanford's
# open-api
# mompou
# noncommercial
# breakthroughs
# chopin
# interact
# boye
# kerry
# theorist
# inducement
# ornithology
# stakeholders
# gps
# inc
# pivotal
# it-mediated
# adaptability
# flat-rate
# schmidt
# rittel
# macrowork
# sharepoint
# app
# contexts
# critique
# learners
# popularized
# grieg
# human-centered
# creators
# options
# donation
# formats
# cognitive
# soft-systems
# diy
# globally
# hierarchies
# istockphoto
# developers
# online
# origination
# brogeland
# crowdsourcing
# funded
# workspace
# facebook
# brainstorming
# disambiguation
# synthesizing
# amateurs
# tchaikovsky
# ims
# entrepreneurs
# nouno
# transactional
# rubin
# skunk
# olmsted
# wikipedia
# kurt
# qatar
# menter
# hci
# saxton
# funding
# usenet
# centres
# explores
# waldegrave
# joaqun
# audio
# internalization
# knowledge-based
# participatory
# co-founder
# ontario
# facilitation
# recognised
# occupiers
# leifer
# barcelona
# dissemination
# videos
# routing
# instructors
# code-named
# ckos
# tacit
# isbn
# unresolved
# ambidextrous
# lifecycle
# carlo
# keywords
# googleable
# collaborate
# organisations
# johannes
# dlab
# inaccessible
# openness
# famously
# attendees
# radford
# discursive
# algorithm
# pianos
# k-12
# prototypes
# coded
# rand
# holographic
# exam
# microsoft
# crowdsolving
# opera-ballet
# colour
# infrastructure
# genealogical
# mozart
# fenby
# multi-user
# videotelephony
# quinito
# giacomo
# rimsky-korsakov
# electroacoustic
# rbc
# freecommunity
# intercarrier
# rebate
# coase's
# logistic
# mimic
# teamwork
# op
# telepresence
# markup
# proprietary
# rolf
# tailleferre
# ipma
# a-ha
# holistic
# internet
# tudes
# palo
# tactile
# joachim
# evan
# archer
# wonderland
# i-spy
# etc
# subjectivity
# ravel
# organisational
# telecommunications
# igloo
# carstensen
# re-design
# crowdsource
# hands-on
# berkeley
# takeuchi
# software
# real-world
# sophie
# providers
# lotus
# delibes
# youtube
# curator
# malicious
# visioning
# venue
# solution-based
# regulate
# ir
# matthews
# nonprofits
# imbalances
# technologies
# organizer
# agendas
# arpanet
# plattner
# translator
# springer
# britten
# ezenia
# grammy
# collaborative
# consultancy
# initiatives
# synchronous
# hitotsubashi
# ideate
# incorporating
# artsybushev
# dial
# self-organized
# deploys
# videoconferencing
# confusing
# lennox
# hybrid
# role-based
# iit
# hexameron
# mayan
# collaborateur
# microtasks
# schubert
# boulez
# in-depth
# interconnected
# innovative
# wihtol
# diaghilev
# self-organizing
# genographic
# database
# email
# zarzuelas
# telecommunication
# schumann
# corrections
# rewards-based
# codified
# categorize
# point-to-point
# christoph
# pmi
# apprenticeship
# hand-held
# neumann
# augmenting
# connects
# internalised
# human-based
# safire
# citations
# manifesto
# websites
# google
# waldo
# goodman
# ecological
# overview
# sustainable
# decision-making
# valverde
# non-government
# ikujiro
# nonprofit
# netflix
# ocr
# enhancing
# batman
# andr
# gpl
# objectivity
# cnn
# unfinished
# 1990s
# forums
# four-hands
# annenberg
# enipedia
# targeted
# evergreen
# wiki
# long-distance
# bodydataspace
# cui
# self-expression
# innovators
# johann
# lyadov
# orchestrations
# meta-analysis
# mediator
# activism
# kirkpatrick
# lindbergh
# cses
# libera
# toyota
# perimeter
# discernment
# alvise
# filippo
# payoffs
# groupware
# andor
# twitter
# aiga
# edu
# requiem
# summarizes
# coloured
# campra
# duplicated
# update
# zionism
# glazunov
# bipartisanship
# doi
# interdisciplinary
# balogh
# mobilizes
# payoff
# borodin
# retrieval
# ethnographic
# contextual
# workflow
# der
# chap
# marco
# k12
# delius
# teleoperation
# encompasses
# alessandro
# ofcom
# lgpl
# institutes
# avatars
# gerzso
# franz
# businesspeople
# reciprocity
# crowdworkers
# crc
# taneyev
# longitude
# post-partisan
# unbiased
# cscw
# verizon
# re-thinking
# asynchronous
# portfolio
# seeker
# al-bairaq
# exacerbated
# language-related
# etymology
# heinlein
# blogs
# judgement
# vocals
# timeline
# jostle
# finnish
# montsalvatge
# durn
# canada's
# automate
# mckim
# gallipoli
# pay-as-you-go
# pejorative
# visionaries
# ip
# intersector
# tippett
# reddit
# dilemmas
# strategies
# interactivity
# faur
# pyotr
# terminating
# digitally
# colin
# americas
# blumenfeld
# adversarial
# organisation
# inline
# validation
# anatoly
# wikinomics
# henk
# ruperto
# regroup
# kats-chernin
# lawson's
# harper
# transnational
# methodology
# ideagoras
# non-traditional
# translates
# exponents
# collaborationism
# intranet
# transparency
# alberto
# slovak
# placeware
# openagile
# telesuite
# competitions
# calleja
# parsing
# nabatchi
# ra
# collanos
# mckim's
# post-partisanship
# f-a-e
# sorce
# kodly's
# extrinsic
# walters
# km
# org
# kibbutzim
# nono
# mindtouch
# top-down
# humanities
# bookmarking
# wolfgang
# crowdsearching
# translators
# literacy
# mfa
# users'
# a-level
# uk
# facilitating
# standalone
# workforce
# netflix's
# intranets
# multidisciplinary
# discourses
# vasari
# stakeholder
# gimnez
# guidelines
# decentralized
# ill-defined
# sokolov
# computer-supported
# focuses
# sustainability
# query
# messager
# browse
# telephony
# non-state
# interrogate
# icc
# 's
# jumper
# daren
# commissioned
# iii
# amadeus
# databases
# puritani
# teleconference
# sourcing
# benchmarking
# rosen
# tcherepnin
# altruistic
# oboe
# desktop
# apps
# hyperoffice
# motivate
# poulenc
# clickworkers
# mindquarry
# on-line
# diabelli
# plutonium
# open-source
# piggyback
# oneida
# empathy
# macbride
# unintended
# incremental
# honour
# employees'
# franchomme
# info
# sauguet
# misinformation
# messaging
# behaviors
# updates
# programme
# feedbacks
# ideo
# implementations
# hexagonal
# web-based
# nuanced
# situational
# intractable
# notosh
# csar
# requesters
# crowdsourcers
# seeman
# minsky
# honegger
# sergei
# 'a
# polycom
# cse
# free-market
# mozilla
# facilitates
# retrieving
# franois
# ideation
# credibility
# facilitator
# competencies
# toolkit
# ceo
# hasso
# logged
# biases
# crowdvoting
# genealogy
# modeling
# commons-based
# categorizing
# engelbart
# mario
# coworking
# collaborations
# irobot
# outsource
# mindset
# mit
# darius
# nikolai
# computer-mediated
# verifying
# mainstream
# incorporate
# orchestrated
# infoworkspace
# scoping
# studios
# cheating
# operas
# demographics
# logicism
# sanjun
# commemorate
# cognition
# comics
# repositories
# toms
# community-based
# marketocracy
# funders
# otp
# constraints
# off-road
# integrates
# workflows
# darpa
# cimarosa
# rationality
# robotics
# problem-solving
# sec
# bandwidth
# marguerite
# sigismond
# master-slave
# chueca
# freeware
# arguably
# motivational
# adaptive
# hosted
# academia
# strategically
# 3d
# video
# worldwide
# amazon
# winkler
# nos
# anton
# blog
# linus
# nongoogleable
# fundraising
# outsourcing
# sip
# globalization
# collaborating
# gash
# casalino
# hierarchical
# anybots
# start-ups
# elgar
# pixis
# maximise
# gmbh
# luigi
# villerville
# thalberg
# finland
# seismology
# user's
# inductive
# 2014-06-25
# ict
# unsourced
# appropriateness
# rossini
# avatar
# e-mail
# reddy
# cleanup
# ave
# military-industrial
# prototyping
# mandated
# 1960s
# customization
# richman
# algorithms
# stradiotto
# rafael
# iterative
# pp
# microwork
# moscheles
# ansell
# fcc
# alexis
# crowdsourced
# implemented
# vidolin
# portals
# download
# roth
# endeavour
# solicit
# investor
# herz
# storytelling
# academics
# policy-making
# partnerships
# high-quality
# cisco
# meinel
# artifacts
# ibert
# telerobotics
# gce
# facilitators
# czerny
# localization
# internet-based
# kibbutz
# cello
# milhaud
# mozart's
# captchas
# robot
# faste
# volunteering
# understandings
# crowdfunding
# cvw
# enjoyment-based
# waltz
# mendelssohn
# convergent
# zoho
# open-minded
# londonderry
# spreadsheets
# barbero
# encyclopedia
# lawson
# real-time
# liferay
# redesign
# premiered
# unesco
# johnson-lenz
# choral
# mr
# haptic
# castelnuovo-tedesco
# integrating
# lite
# tapscott
# immersive
# dialing
# roland-manuel
# kodak
# regimes
# frdric
# scenario
# exo
# competitiveness
# gathers
# smartphone
# auric
# ladrn-de-guevara
# vendors
# campuses
# horst
# health-care
# ess
# nigel
# georges
# wikis
# relational
# ecosystem
# collaboratively
# curricular
# peer-to-peer
# goossens
# competes
# burghardt
# empowered
# telemedicine
# embedding
# cameron
# quadrille
# proofreaders
# conceptualizing
# governance
# offline
# brabham
# commercialization
# interactive
# 1980s
# massively
# schwarzenegger
# estells-arolas
# methodologies
# engendering
# postpartisan
# mussorgsky's
# gantt
# aforementioned
# leveraging
# liszt
# seq
# nonaka
# customer's
# conferencing
# cmc
# paderewski
# 1970s
# innocentive
# vincenzo
# networking
# federico
# dna
# gloor
# server
# plone
# mediation
# deliberation
# ricci
# kelley
# prehistoric
# mentor
# portmanteau
# 00month
# robotic
# concertante
# potsdam
# transformations
# lovegrove
# privacy-aware
# workplace
# gtd
# logo
# replicate
# centre
# minkus
# usa
# highlight
# metacognition
# scheduling
# aldeburgh
# technologically
# frameworks
# taxonomy
# three-way
# linux
# composer's
# fogo
# searchtogether
# capital-raising
# accessibility
# stanford
# fostering
# germaine
# physica-verlag

# %%
print(len(input_specifics))
# Out:
# 832

# %% [markdown]
# ## 8. Stemming (in case needed)

# %%
from nltk.stem.porter import PorterStemmer
stemmer = PorterStemmer()
for k,v in input_freq_dist.items():
    stemmed = stemmer.stem(k)
    if stemmed != k: print(k, "->", stemmed)
# Out:
# collaboration -> collabor
# uses -> use
# disambiguation -> disambigu
# definition -> definit
# artists -> artist
# featuring -> featur
# purposeful -> purpos
# parties -> parti
# strategically -> strateg
# choose -> choos
# cooperate -> cooper
# achieve -> achiev
# shared -> share
# overlapping -> overlap
# objectives -> object
# collaborative -> collabor
# developing -> develop
# effective -> effect
# partnerships -> partnership
# communities -> commun
# schools -> school
# explains -> explain
# voluntary -> voluntari
# nature -> natur
# depends -> depend
# leader's -> leader'
# ability -> abil
# relationships -> relationship
# closely -> close
# cooperation -> cooper
# requires -> requir
# decentralized -> decentr
# teams -> team
# collaboratively -> collabor
# resources -> resourc
# recognition -> recognit
# facing -> face
# competition -> competit
# structured -> structur
# methods -> method
# encourage -> encourag
# communication -> commun
# specifically -> specif
# increase -> increas
# engage -> engag
# solving -> solv
# forms -> form
# charts -> chart
# useful -> use
# situations -> situat
# objectively -> object
# personal -> person
# traits -> trait
# improving -> improv
# performance -> perform
# future -> futur
# projects -> project
# opposing -> oppos
# goals -> goal
# adversarial -> adversari
# using -> use
# classical -> classic
# examples -> exampl
# community -> commun
# organization -> organ
# intentional -> intent
# indigenous -> indigen
# capitalism -> capit
# theory -> theori
# military-industrial -> military-industri
# management -> manag
# occupational -> occup
# arts -> art
# groups -> group
# business -> busi
# education -> educ
# entertainment -> entertain
# publishing -> publish
# science -> scienc
# medicine -> medicin
# technology -> technolog
# wartime -> wartim
# reading -> read
# goods -> good
# economic -> econom
# activity -> activ
# providing -> provid
# originated -> origin
# prehistoric -> prehistor
# times -> time
# trading -> trade
# people -> peopl
# services -> servic
# dates -> date
# history -> histori
# long-distance -> long-dist
# years -> year
# exists -> exist
# reasons -> reason
# division -> divis
# concentrate -> concentr
# production -> product
# products -> product
# regions -> region
# different -> differ
# comparative -> compar
# advantage -> advantag
# allows -> allow
# benefits -> benefit
# prices -> price
# locations -> locat
# sources -> sourc
# please -> pleas
# improve -> improv
# adding -> ad
# citations -> citat
# reliable -> reliabl
# unsourced -> unsourc
# material -> materi
# challenged -> challeng
# removed -> remov
# november -> novemb
# remove -> remov
# template -> templat
# message -> messag
# members -> member
# provides -> provid
# typically -> typic
# political -> polit
# responsibilities -> respons
# include -> includ
# housing -> hous
# selected -> select
# existing -> exist
# agents -> agent
# owned -> own
# century -> centuri
# units -> unit
# assigned -> assign
# individual -> individu
# colony -> coloni
# little -> littl
# property -> properti
# entire -> entir
# practiced -> practic
# sense -> sens
# communal -> commun
# criticism -> critic
# every -> everi
# committee -> committe
# general -> gener
# meeting -> meet
# eliminate -> elimin
# character -> charact
# early -> earli
# founded -> found
# collective -> collect
# combines -> combin
# practical -> practic
# independent -> independ
# perhaps -> perhap
# forced -> forc
# necessity -> necess
# ideology -> ideolog
# developed -> develop
# living -> live
# attracted -> attract
# several -> sever
# generations -> gener
# today's -> today'
# enterprises -> enterpris
# originally -> origin
# supposed -> suppos
# alternatives -> altern
# citation -> citat
# needed -> need
# particularly -> particularli
# americas -> america
# includes -> includ
# working -> work
# structure -> structur
# flexible -> flexibl
# collaborate -> collabor
# allowed -> allow
# participate -> particip
# freely -> freeli
# adults -> adult
# contributors -> contributor
# taking -> take
# tasks -> task
# skills -> skill
# learning -> learn
# techniques -> techniqu
# example -> exampl
# study -> studi
# fathers -> father
# traditional -> tradit
# ways -> way
# worked -> work
# together -> togeth
# frequently -> frequent
# building -> build
# value -> valu
# house -> hous
# initiative -> initi
# autonomy -> autonomi
# contributing -> contribut
# completing -> complet
# activities -> activ
# assisting -> assist
# lectures -> lectur
# installation -> instal
# becomes -> becom
# students -> student
# alongside -> alongsid
# needing -> need
# movements -> movement
# instruction -> instruct
# experience -> experi
# synchronous -> synchron
# roles -> role
# sharing -> share
# emphasized -> emphas
# learners -> learner
# works -> work
# experienced -> experienc
# complete -> complet
# parts -> part
# others -> other
# attention -> attent
# isolated -> isol
# recognized -> recogn
# pursue -> pursu
# rational -> ration
# hundreds -> hundr
# pages -> page
# collaborating -> collabor
# participants -> particip
# connected -> connect
# exchanged -> exchang
# always -> alway
# presenting -> present
# explained -> explain
# acting -> act
# ones -> one
# entails -> entail
# looking -> look
# innocent -> innoc
# injustice -> injustic
# friends -> friend
# applied -> appli
# mathematics -> mathemat
# economics -> econom
# multiple -> multipl
# players -> player
# decisions -> decis
# documented -> document
# discussion -> discuss
# james -> jame
# waldegrave -> waldegrav
# mathematical -> mathemat
# principles -> principl
# provided -> provid
# became -> becam
# unique -> uniqu
# published -> publish
# series -> seri
# papers -> paper
# games -> game
# needs -> need
# additional -> addit
# verification -> verif
# article -> articl
# refers -> refer
# armed -> arm
# forces -> forc
# private -> privat
# industry -> industri
# associated -> associ
# commercial -> commerci
# interests -> interest
# military -> militari
# dependent -> depend
# supply -> suppli
# defense -> defens
# government -> govern
# revenue -> revenu
# used -> use
# engineering -> engin
# technical -> technic
# fields -> field
# describe -> describ
# degree -> degre
# bureaucracy -> bureaucraci
# advanced -> advanc
# lockheed -> lockhe
# highly -> highli
# innovative -> innov
# days -> day
# operating -> oper
# rules -> rule
# united -> unit
# states -> state
# formally -> formal
# designated -> design
# engineer -> engin
# army -> armi
# engineers -> engin
# administration -> administr
# scientific -> scientif
# directed -> direct
# aforementioned -> aforement
# persons -> person
# influence -> influenc
# organized -> organ
# attributed -> attribut
# national -> nation
# previous -> previou
# failures -> failur
# implementing -> implement
# organize -> organ
# july -> juli
# code-named -> code-nam
# ships -> ship
# required -> requir
# approaches -> approach
# manufacturing -> manufactur
# discipline -> disciplin
# application -> applic
# including -> includ
# construction -> construct
# henry -> henri
# called -> call
# planning -> plan
# famously -> famous
# associate -> associ
# theories -> theori
# navy -> navi
# tools -> tool
# resource -> resourc
# allocation -> alloc
# 1950s -> 1950
# marked -> mark
# beginning -> begin
# managed -> manag
# basis -> basi
# mostly -> mostli
# informal -> inform
# scheduling -> schedul
# models -> model
# evaluation -> evalu
# technique -> techniqu
# conjunction -> conjunct
# corporation -> corpor
# critical -> critic
# venture -> ventur
# managing -> manag
# maintenance -> mainten
# quickly -> quickli
# institute -> institut
# formed -> form
# serve -> serv
# premise -> premis
# software -> softwar
# directors -> director
# development -> develop
# become -> becom
# guide -> guid
# body -> bodi
# knowledge -> knowledg
# standards -> standard
# guidelines -> guidelin
# practice -> practic
# widely -> wide
# profession -> profess
# international -> intern
# association -> associ
# europe -> europ
# organizations -> organ
# participating -> particip
# college -> colleg
# theodore -> theodor
# faculty -> faculti
# experimental -> experiment
# committed -> commit
# interdisciplinary -> interdisciplinari
# included -> includ
# leading -> lead
# designers -> design
# relatively -> rel
# location -> locat
# instructors -> instructor
# innovations -> innov
# connections -> connect
# lasting -> last
# culture -> cultur
# eventually -> eventu
# dance -> danc
# company -> compani
# staged -> stage
# happening -> happen
# conceived -> conceiv
# consciously -> conscious
# educational -> educ
# experiment -> experi
# writers -> writer
# conducted -> conduct
# important -> import
# proved -> prove
# prototype -> prototyp
# alternative -> altern
# colleges -> colleg
# university -> univers
# 1990s -> 1990
# focus -> focu
# observed -> observ
# researchers -> research
# practitioners -> practition
# knowing -> know
# cultural -> cultur
# changes -> chang
# teaching -> teach
# encouraged -> encourag
# words -> word
# domains -> domain
# analysis -> analysi
# appearance -> appear
# 1980s -> 1980
# considered -> consid
# established -> establish
# quality -> qualiti
# focuses -> focus
# compared -> compar
# notable -> notabl
# composers -> compos
# variations -> variat
# performed -> perform
# czerny -> czerni
# pixis -> pixi
# johannes -> johann
# brahms -> brahm
# genius -> geniu
# existed -> exist
# since -> sinc
# lives -> live
# artistic -> artist
# individuals -> individu
# created -> creat
# largely -> larg
# false -> fals
# processes -> process
# large -> larg
# centuries -> centuri
# questioned -> question
# consciousness -> conscious
# 1960s -> 1960
# 1970s -> 1970
# experiments -> experi
# girls -> girl
# easy -> easi
# venue -> venu
# lighting -> light
# tchaikovsky -> tchaikovski
# george -> georg
# stravinsky -> stravinski
# companies -> compani
# feature -> featur
# essential -> essenti
# choreographer -> choreograph
# creates -> creat
# physically -> physic
# sees -> see
# attempts -> attempt
# ranges -> rang
# funding -> fund
# complexity -> complex
# agree -> agre
# mutually -> mutual
# information -> inform
# rewards -> reward
# jointly -> jointli
# solve -> solv
# problems -> problem
# sectors -> sector
# tackling -> tackl
# policy -> polici
# handled -> handl
# effectively -> effect
# networks -> network
# organizational -> organiz
# structures -> structur
# chains -> chain
# ideas -> idea
# numerous -> numer
# generate -> gener
# variety -> varieti
# firms -> firm
# opposed -> oppos
# innovation -> innov
# outcomes -> outcom
# improvement -> improv
# connection -> connect
# web-based -> web-bas
# blogs -> blog
# wikis -> wiki
# efficiently -> effici
# able -> abl
# communicate -> commun
# conferences -> confer
# geographical -> geograph
# barriers -> barrier
# defines -> defin
# create -> creat
# physical -> physic
# according -> accord
# studies -> studi
# powerful -> power
# towards -> toward
# increased -> increas
# productivity -> product
# efficacy -> efficaci
# significantly -> significantli
# aspirations -> aspir
# motivational -> motiv
# investment -> invest
# challenges -> challeng
# however -> howev
# successful -> success
# rapidly -> rapidli
# external -> extern
# relations -> relat
# specific -> specif
# coworking -> cowork
# spaces -> space
# businesses -> busi
# dedicated -> dedic
# environment -> environ
# values -> valu
# openness -> open
# accessibility -> access
# sustainability -> sustain
# classrooms -> classroom
# levels -> level
# areas -> area
# regarded -> regard
# teachers -> teacher
# generally -> gener
# defined -> defin
# professionals -> profession
# delivering -> deliv
# diverse -> divers
# single -> singl
# increasingly -> increasingli
# educators -> educ
# languages -> languag
# varied -> vari
# academic -> academ
# provide -> provid
# inclusive -> inclus
# receive -> receiv
# separate -> separ
# decades -> decad
# conceptualizing -> conceptu
# expansion -> expans
# types -> type
# resulted -> result
# transformation -> transform
# economy -> economi
# technologies -> technolog
# industries -> industri
# transformations -> transform
# projected -> project
# federal -> feder
# reports -> report
# capacity -> capac
# manage -> manag
# successfully -> success
# continuing -> continu
# online -> onlin
# changed -> chang
# environments -> environ
# materials -> materi
# cases -> case
# circle -> circl
# musical -> music
# occurs -> occur
# musicians -> musician
# places -> place
# involved -> involv
# producers -> produc
# represents -> repres
# currently -> current
# especially -> especi
# regards -> regard
# websites -> websit
# facilitate -> facilit
# resulting -> result
# emergence -> emerg
# grammy -> grammi
# country -> countri
# vocals -> vocal
# awarded -> award
# electroacoustic -> electroacoust
# laboratories -> laboratori
# electronic -> electron
# studios -> studio
# presence -> presenc
# intertwined -> intertwin
# competencies -> compet
# embedding -> embed
# technological -> technolog
# expertise -> expertis
# assistant -> assist
# computer -> comput
# designer -> design
# mediator -> mediat
# described -> describ
# writing -> write
# creating -> creat
# instruments -> instrument
# recording -> record
# possibilities -> possibl
# various -> variou
# applications -> applic
# potential -> potenti
# effects -> effect
# composer -> compos
# sufficient -> suffici
# programme -> programm
# results -> result
# translates -> translat
# programming -> program
# finally -> final
# transforms -> transform
# performs -> perform
# piece -> piec
# concerts -> concert
# pierre -> pierr
# alvise -> alvis
# reality -> realiti
# sites -> site
# youtube -> youtub
# actors -> actor
# television -> televis
# title -> titl
# titled -> titl
# professional -> profession
# simple -> simpl
# commons-based -> commons-bas
# lists -> list
# books -> book
# newspapers -> newspap
# journals -> journal
# institution -> institut
# organizing -> organ
# sciences -> scienc
# self-organized -> self-organ
# collaborations -> collabor
# nations -> nation
# cited -> cite
# involves -> involv
# foundation -> foundat
# institutes -> institut
# natural -> natur
# operation -> oper
# encompasses -> encompass
# range -> rang
# enable -> enabl
# networking -> network
# messaging -> messag
# conferencing -> conferenc
# telephony -> telephoni
# broadly -> broadli
# facilitates -> facilit
# linking -> link
# humans -> human
# enterprise -> enterpris
# strategies -> strategi
# employees -> employe
# customers -> custom
# partners -> partner
# centered -> center
# intelligence -> intellig
# features -> featur
# real-time -> real-tim
# enables -> enabl
# enhance -> enhanc
# awareness -> awar
# profiles -> profil
# interactions -> interact
# asynchronous -> asynchron
# serves -> serv
# commonly -> commonli
# easily -> easili
# interaction -> interact
# telepresence -> telepres
# effectiveness -> effect
# factors -> factor
# nearly -> nearli
# dramatically -> dramat
# cheaply -> cheapli
# niche -> nich
# produced -> produc
# formerly -> formerli
# coined -> coin
# creative -> creativ
# energy -> energi
# numbers -> number
# coordinated -> coordin
# usually -> usual
# meaningful -> meaning
# hierarchical -> hierarch
# financial -> financi
# compensation -> compens
# compares -> compar
# centralized -> central
# decision -> decis
# tagging -> tag
# jobs -> job
# anyone -> anyon
# interested -> interest
# means -> mean
# announcements -> announc
# website -> websit
# clickworkers -> clickwork
# another -> anoth
# helps -> help
# massively -> massiv
# distributed -> distribut
# mitchell -> mitchel
# presentation -> present
# emerging -> emerg
# collaborationism -> collaboration
# acquired -> acquir
# meaning -> mean
# referring -> refer
# countries -> countri
# occupiers -> occupi
# implies -> impli
# ideological -> ideolog
# party -> parti
# occupation -> occup
# thus -> thu
# service -> servic
# occupying -> occupi
# exploitation -> exploit
# participation -> particip
# reference -> refer
# germany -> germani
# doctrine -> doctrin
# force -> forc
# pejorative -> pejor
# original -> origin
# positive -> posit
# distinction -> distinct
# equivalent -> equival
# terms -> term
# dictionary -> dictionari
# editing -> edit
# governance -> govern
# engine -> engin
# translation -> translat
# conference -> confer
# thinking -> think
# crowdsourcing -> crowdsourc
# digital -> digit
# facilitation -> facilit
# role-based -> role-bas
# wikinomics -> wikinom
# anthony -> anthoni
# williams -> william
# language -> languag
# publisher -> publish
# publication -> public
# december -> decemb
# everything -> everyth
# explores -> explor
# open-source -> open-sourc
# concepts -> concept
# coase's -> coase'
# reception -> recept
# based -> base
# peering -> peer
# globally -> global
# extension -> extens
# outsource -> outsourc
# internal -> intern
# functions -> function
# entities -> entiti
# difference -> differ
# outsourcing -> outsourc
# referred -> refer
# discusses -> discuss
# marketocracy -> marketocraci
# employs -> employ
# completely -> complet
# source -> sourc
# peer-to-peer -> peer-to-p
# conventional -> convent
# ideagoras -> ideagora
# experts -> expert
# unsolved -> unsolv
# innocentive -> innocent
# consulting -> consult
# viewers -> viewer
# opened -> open
# february -> februari
# transparency -> transpar
# attitude -> attitud
# proprietary -> proprietari
# things -> thing
# intellectual -> intellectu
# globalization -> global
# boundaries -> boundari
# corporate -> corpor
# authors -> author
# transactions -> transact
# permits -> permit
# transaction -> transact
# costs -> cost
# carrying -> carri
# changing -> chang
# usage -> usag
# patterns -> pattern
# communicating -> commun
# change -> chang
# utilize -> util
# respective -> respect
# markets -> market
# choice -> choic
# readers -> reader
# optimistic -> optimist
# ventures -> ventur
# commons -> common
# consideration -> consider
# sides -> side
# motivation -> motiv
# primarily -> primarili
# observations -> observ
# trends -> trend
# presented -> present
# september -> septemb
# entrenched -> entrench
# crisis -> crisi
# radical -> radic
# chris -> chri
# human-based -> human-bas
# computation -> comput
# participatory -> participatori
# cathedral -> cathedr
# confused -> confus
# producing -> produc
# contributions -> contribut
# choices -> choic
# coordination -> coordin
# going -> go
# planned -> plan
# steps -> step
# discussions -> discuss
# involve -> involv
# documents -> document
# efficient -> effici
# assemble -> assembl
# systems -> system
# editors -> editor
# automatically -> automat
# labeling -> label
# contributed -> contribut
# google -> googl
# unfortunately -> unfortun
# leads -> lead
# makes -> make
# increasing -> increas
# literature -> literatur
# investigating -> investig
# experiences -> experi
# duplicated -> duplic
# require -> requir
# issues -> issu
# zones -> zone
# videoconferencing -> videoconferenc
# related -> relat
# telerobotics -> telerobot
# senses -> sens
# feeling -> feel
# additionally -> addit
# users -> user
# remote -> remot
# user's -> user'
# position -> posit
# actions -> action
# voice -> voic
# sensed -> sens
# transmitted -> transmit
# therefore -> therefor
# traveling -> travel
# directions -> direct
# possible -> possibl
# videotelephony -> videotelephoni
# deploys -> deploy
# improved -> improv
# fidelity -> fidel
# mobile -> mobil
# extended -> extend
# capabilities -> capabl
# devices -> devic
# enabling -> enabl
# implementation -> implement
# sensory -> sensori
# elements -> element
# manipulation -> manipul
# cooperative -> cooper
# connecting -> connect
# hazardous -> hazard
# pipeline -> pipelin
# inspection -> inspect
# surgery -> surgeri
# artificial -> artifici
# vendors -> vendor
# comics -> comic
# pioneering -> pioneer
# cognitive -> cognit
# minsky -> minski
# story -> stori
# proposed -> propos
# master-slave -> master-slav
# introduced -> introduc
# follows -> follow
# seemed -> seem
# passed -> pass
# started -> start
# gradually -> gradual
# moved -> move
# balance -> balanc
# naturally -> natur
# eyes -> eye
# inside -> insid
# maintaining -> maintain
# suspension -> suspens
# outlined -> outlin
# adapted -> adapt
# teleoperation -> teleoper
# focused -> focus
# giving -> give
# participant -> particip
# actually -> actual
# telesuite -> telesuit
# emerged -> emerg
# businesspeople -> businesspeopl
# stays -> stay
# meetings -> meet
# resolution -> resolut
# replace -> replac
# hotels -> hotel
# licensed -> licens
# shareholders -> sharehold
# company's -> company'
# ultimately -> ultim
# purchased -> purchas
# assets -> asset
# president -> presid
# destiny -> destini
# followed -> follow
# forming -> form
# distribution -> distribut
# january -> januari
# located -> locat
# involving -> involv
# stated -> state
# insights -> insight
# sociological -> sociolog
# linked -> link
# centres -> centr
# centre -> centr
# telecommunications -> telecommun
# drivers -> driver
# wanted -> want
# reduce -> reduc
# environmental -> environment
# employee -> employe
# participates -> particip
# distances -> distanc
# screens -> screen
# brings -> bring
# enormous -> enorm
# greatly -> greatli
# communications -> commun
# allowing -> allow
# expressions -> express
# combine -> combin
# drawing -> draw
# generation -> gener
# improvements -> improv
# customer -> custom
# fully -> fulli
# one's -> one'
# someone -> someon
# interactive -> interact
# ideally -> ideal
# corresponds -> correspond
# differs -> differ
# displays -> display
# mounted -> mount
# directly -> directli
# convincing -> convinc
# sensation -> sensat
# accurately -> accur
# unintended -> unintend
# sickness -> sick
# imagery -> imageri
# telephone -> telephon
# dating -> date
# equipment -> equip
# available -> avail
# considerable -> consider
# anybots -> anybot
# manipulate -> manipul
# implemented -> implement
# depending -> depend
# hands -> hand
# wired -> wire
# sensors -> sensor
# copies -> copi
# robotic -> robot
# varies -> vari
# tactile -> tactil
# objects -> object
# roaming -> roam
# prevalence -> preval
# computers -> comput
# enabled -> enabl
# robots -> robot
# office -> offic
# integrated -> integr
# suitable -> suitabl
# double -> doubl
# robotics -> robot
# operate -> oper
# obstacles -> obstacl
# driving -> drive
# rooms -> room
# noted -> note
# solutions -> solut
# immersive -> immers
# adaptive -> adapt
# ends -> end
# controlled -> control
# furniture -> furnitur
# thereby -> therebi
# impression -> impress
# table -> tabl
# engendering -> engend
# hence -> henc
# integration -> integr
# whereas -> wherea
# components -> compon
# integrate -> integr
# strategy -> strategi
# puts -> put
# focusing -> focus
# replicate -> replic
# innate -> innat
# preferences -> prefer
# interpersonal -> interperson
# separating -> separ
# talking -> talk
# heads -> head
# accurate -> accur
# already -> alreadi
# executive -> execut
# officer -> offic
# rarely -> rare
# transparent -> transpar
# comprehensive -> comprehens
# perceives -> perceiv
# differences -> differ
# aside -> asid
# achieves -> achiev
# limited -> limit
# hearing -> hear
# consider -> consid
# watching -> watch
# stimulates -> stimul
# primary -> primari
# gives -> give
# sometimes -> sometim
# emotional -> emot
# responses -> respons
# events -> event
# sports -> sport
# increases -> increas
# subjective -> subject
# genuine -> genuin
# movies -> movi
# feasible -> feasibl
# something -> someth
# desired -> desir
# appropriate -> appropri
# merely -> mere
# simulated -> simul
# rely -> reli
# relevant -> relev
# representation -> represent
# functional -> function
# entity -> entiti
# face-to-face -> face-to-fac
# security -> secur
# geographically -> geograph
# recognised -> recognis
# candidates -> candid
# operations -> oper
# victims -> victim
# exploration -> explor
# plays -> play
# worlds -> world
# otherwise -> otherwis
# inaccessible -> inaccess
# examination -> examin
# viewed -> view
# possibility -> possibl
# locally -> local
# obvious -> obviou
# combination -> combin
# potentially -> potenti
# battle -> battl
# recently -> recent
# telemedicine -> telemedicin
# mainly -> mainli
# employing -> employ
# audio-visual -> audio-visu
# exchange -> exchang
# demonstrated -> demonstr
# addition -> addit
# initial -> initi
# shows -> show
# making -> make
# active -> activ
# programs -> program
# researcher -> research
# explore -> explor
# attractive -> attract
# immediate -> immedi
# artifacts -> artifact
# campuses -> campus
# simultaneously -> simultan
# professors -> professor
# classes -> class
# multidisciplinary -> multidisciplinari
# integrates -> integr
# psychology -> psycholog
# internet-based -> internet-bas
# videos -> video
# image -> imag
# accompanied -> accompani
# fictional -> fiction
# telecommunication -> telecommun
# festival -> festiv
# blurred -> blur
# bodydataspace -> bodydataspac
# explored -> explor
# performing -> perform
# festivals -> festiv
# workshops -> workshop
# worldwide -> worldwid
# methodology -> methodolog
# extensively -> extens
# preparation -> prepar
# avatars -> avatar
# theatre -> theatr
# pioneers -> pioneer
# mechanical -> mechan
# designed -> design
# influenced -> influenc
# outside -> outsid
# brands -> brand
# represented -> repres
# population -> popul
# holographic -> holograph
# episode -> episod
# family -> famili
# category -> categori
# films -> film
# conviction -> convict
# female -> femal
# computing -> comput
# organisation -> organis
# achieving -> achiev
# organisational -> organis
# courses -> cours
# library -> librari
# contribute -> contribut
# universities -> univers
# degrees -> degre
# institutions -> institut
# organisations -> organis
# efforts -> effort
# departments -> depart
# advice -> advic
# regarding -> regard
# competitive -> competit
# lessons -> lesson
# learned -> learn
# continuous -> continu
# distinguished -> distinguish
# strategic -> strateg
# encouraging -> encourag
# dimensions -> dimens
# motivations -> motiv
# forums -> forum
# libraries -> librari
# training -> train
# repositories -> repositori
# intranets -> intranet
# computer-supported -> computer-support
# collections -> collect
# importance -> import
# measurement -> measur
# norms -> norm
# behaviors -> behavior
# dissemination -> dissemin
# benchmarking -> benchmark
# incentives -> incent
# accelerate -> acceler
# impressive -> impress
# concrete -> concret
# initially -> initi
# supported -> support
# world's -> world'
# objective -> object
# ckos -> cko
# maximise -> maximis
# theoretical -> theoret
# aspects -> aspect
# academics -> academ
# thomas -> thoma
# magazine -> magazin
# subsequently -> subsequ
# capital -> capit
# maturity -> matur
# publications -> public
# contribution -> contribut
# overall -> overal
# disciplines -> disciplin
# vary -> vari
# debates -> debat
# ecological -> ecolog
# identity -> ident
# details -> detail
# perspective -> perspect
# perspectives -> perspect
# relevance -> relev
# suggested -> suggest
# translate -> translat
# findings -> find
# frameworks -> framework
# distinguishing -> distinguish
# categorizing -> categor
# distinguishes -> distinguish
# internalised -> internalis
# aware -> awar
# opposite -> opposit
# holds -> hold
# communicated -> commun
# internalization -> intern
# considers -> consid
# cycle -> cycl
# suggests -> suggest
# stored -> store
# codified -> codifi
# relational -> relat
# contextual -> contextu
# retrieved -> retriev
# subsequent -> subsequ
# translated -> translat
# symbols -> symbol
# returned -> return
# debate -> debat
# embedded -> embed
# representing -> repres
# stages -> stage
# tried -> tri
# submission -> submiss
# incorporating -> incorpor
# plans -> plan
# controversy -> controversi
# consensus -> consensu
# actively -> activ
# instance -> instanc
# explicitly -> explicitli
# repository -> repositori
# database -> databas
# retrieving -> retriev
# codification -> codif
# requests -> request
# collecting -> collect
# databases -> databas
# accessible -> access
# encourages -> encourag
# fostering -> foster
# updated -> updat
# storytelling -> storytel
# description -> descript
# reviews -> review
# mapping -> map
# questions -> question
# systematic -> systemat
# architecture -> architectur
# situation -> situat
# bookmarking -> bookmark
# engines -> engin
# responsibility -> respons
# undertake -> undertak
# typical -> typic
# considerations -> consider
# cycles -> cycl
# facilitating -> facilit
# leveraging -> leverag
# intractable -> intract
# wicked -> wick
# workforce -> workforc
# groupware -> groupwar
# lotus -> lotu
# notes -> note
# automate -> autom
# validation -> valid
# portals -> portal
# monitoring -> monitor
# schedule -> schedul
# assembling -> assembl
# significant -> signific
# adoption -> adopt
# formats -> format
# freeware -> freewar
# expensive -> expens
# semantic -> semant
# modeling -> model
# goes -> goe
# boeing -> boe
# chemical -> chemic
# industrial -> industri
# describes -> describ
# invited -> invit
# coins -> coin
# leaders -> leader
# quotes -> quot
# co-founder -> co-found
# gates -> gate
# douglas -> dougla
# eugene -> eugen
# climate -> climat
# transnational -> transnat
# measures -> measur
# sustainable -> sustain
# indicators -> indic
# topics -> topic
# mechanism -> mechan
# played -> play
# cities -> citi
# ansell -> ansel
# conditions -> condit
# covers -> cover
# decision-making -> decision-mak
# identifies -> identifi
# fixed -> fix
# gathers -> gather
# policies -> polici
# answers -> answer
# stakeholders -> stakehold
# visioning -> vision
# agencies -> agenc
# delivery -> deliveri
# interconnected -> interconnect
# definitions -> definit
# advantages -> advantag
# disadvantages -> disadvantag
# governing -> govern
# regional -> region
# response -> respons
# regulation -> regul
# society -> societi
# administrators -> administr
# lines -> line
# recognize -> recogn
# primacy -> primaci
# define -> defin
# arrangement -> arrang
# non-state -> non-stat
# aims -> aim
# initiated -> initi
# carry -> carri
# purpose -> purpos
# analytic -> analyt
# arrangements -> arrang
# engagement -> engag
# non-government -> non-govern
# governments -> govern
# understanding -> understand
# makers -> maker
# identify -> identifi
# deliver -> deliv
# solution -> solut
# officials -> offici
# suggestions -> suggest
# analyze -> analyz
# commitment -> commit
# likely -> like
# combining -> combin
# capacities -> capac
# specialization -> special
# direction -> direct
# institutional -> institut
# relation -> relat
# consuming -> consum
# agreed -> agre
# confusing -> confus
# stakeholder -> stakehold
# agendas -> agenda
# loose -> loos
# expanding -> expand
# resolve -> resolv
# furthermore -> furthermor
# arise -> aris
# representatives -> repres
# collaborators -> collabor
# accountability -> account
# imbalances -> imbal
# regimes -> regim
# critics -> critic
# argue -> argu
# consistency -> consist
# seeks -> seek
# citizens -> citizen
# democracy -> democraci
# comes -> come
# initiatives -> initi
# involvement -> involv
# instances -> instanc
# growing -> grow
# affairs -> affair
# protecting -> protect
# infrastructure -> infrastructur
# opportunities -> opportun
# reviewed -> review
# outputs -> output
# statutory -> statutori
# endorsed -> endors
# legislation -> legisl
# practices -> practic
# interrogate -> interrog
# challenge -> challeng
# dominant -> domin
# visions -> vision
# critique -> critiqu
# quite -> quit
# viable -> viabl
# takes -> take
# builds -> build
# voices -> voic
# commission -> commiss
# macbride -> macbrid
# deliberations -> deliber
# operates -> oper
# rights -> right
# advocacy -> advocaci
# self-expression -> self-express
# scoping -> scope
# amateurs -> amateur
# mixed -> mix
# discursive -> discurs
# activism -> activ
# comparisons -> comparison
# discourses -> discours
# outline -> outlin
# methodological -> methodolog
# links -> link
# recommended -> recommend
# starting -> start
# co-operative -> co-op
# appears -> appear
# emphasis -> emphasi
# quarters -> quarter
# creativity -> creativ
# productive -> product
# contexts -> context
# valued -> valu
# dimension -> dimens
# grows -> grow
# virtue -> virtu
# speaking -> speak
# listening -> listen
# minority -> minor
# points -> point
# evidence -> evid
# platforms -> platform
# divided -> divid
# productions -> product
# issue -> issu
# desire -> desir
# asserts -> assert
# suddenly -> suddenli
# infinite -> infinit
# survival -> surviv
# intellectually -> intellectu
# claims -> claim
# status -> statu
# runs -> run
# risks -> risk
# everyone -> everyon
# temporary -> temporari
# opinions -> opinion
# inability -> inabl
# aesthetic -> aesthet
# curator -> curat
# documentary -> documentari
# associates -> associ
# interactivity -> interact
# shaped -> shape
# draws -> draw
# democratic -> democrat
# entry -> entri
# audiences -> audienc
# diversity -> divers
# resistance -> resist
# identification -> identif
# perceived -> perceiv
# distinctive -> distinct
# ethnographic -> ethnograph
# objectivity -> object
# emphasizes -> emphas
# hierarchy -> hierarchi
# exponents -> expon
# believe -> believ
# holding -> hold
# granted -> grant
# liberation -> liber
# accordingly -> accordingli
# faces -> face
# demonstrate -> demonstr
# significance -> signific
# notions -> notion
# duration -> durat
# embrace -> embrac
# avant-garde -> avant-gard
# experimentation -> experiment
# modes -> mode
# claimed -> claim
# incorporate -> incorpor
# opportunity -> opportun
# qualifications -> qualif
# guided -> guid
# willingness -> willing
# methodologies -> methodolog
# instrumental -> instrument
# promote -> promot
# volunteers -> volunt
# constitutes -> constitut
# styles -> style
# coming -> come
# trained -> train
# similarly -> similarli
# anywhere -> anywher
# weaknesses -> weak
# satellite -> satellit
# providers -> provid
# channels -> channel
# broadcasting -> broadcast
# advances -> advanc
# literacy -> literaci
# consumer -> consum
# argues -> argu
# majority -> major
# empowered -> empow
# asks -> ask
# edited -> edit
# owns -> own
# profits -> profit
# proposes -> propos
# finding -> find
# universal -> univers
# agreements -> agreement
# pragmatic -> pragmat
# decide -> decid
# prepare -> prepar
# finished -> finish
# promotes -> promot
# dialogue -> dialogu
# hopes -> hope
# argued -> argu
# shaping -> shape
# continues -> continu
# interdependent -> interdepend
# conflicts -> conflict
# conscious -> consciou
# lying -> lie
# circumstances -> circumst
# fundamental -> fundament
# responding -> respond
# ensure -> ensur
# divide -> divid
# journalism -> journal
# enhancing -> enhanc
# competitiveness -> competit
# accelerating -> acceler
# start-ups -> start-up
# inflexible -> inflex
# procedures -> procedur
# marketing -> market
# commercialization -> commerci
# self-organizing -> self-organ
# intrinsically -> intrins
# motivated -> motiv
# adopting -> adopt
# discovering -> discov
# promoting -> promot
# hierarchies -> hierarchi
# advance -> advanc
# fosters -> foster
# characteristics -> characterist
# dispersed -> dispers
# cause -> caus
# solved -> solv
# authority -> author
# willing -> will
# donate -> donat
# ethical -> ethic
# codes -> code
# reciprocity -> reciproc
# rationality -> ration
# calls -> call
# genetic -> genet
# guides -> guid
# beliefs -> belief
# reciprocal -> reciproc
# disruptive -> disrupt
# inventions -> invent
# competes -> compet
# linus -> linu
# thousands -> thousand
# update -> updat
# entries -> entri
# faced -> face
# corporations -> corpor
# entrepreneurs -> entrepreneur
# scholars -> scholar
# tackle -> tackl
# raise -> rais
# stimulate -> stimul
# regulatory -> regulatori
# necessary -> necessari
# gains -> gain
# innovators -> innov
# begins -> begin
# politics -> polit
# symbolic -> symbol
# messages -> messag
# reflection -> reflect
# feelings -> feel
# designing -> design
# people's -> people'
# technologically -> technolog
# origins -> origin
# solution-based -> solution-bas
# scientists -> scientist
# synthesis -> synthesi
# divergent -> diverg
# versus -> versu
# convergent -> converg
# problem-solving -> problem-solv
# attributes -> attribut
# analogy -> analog
# inspiration -> inspir
# ideation -> ideat
# empathy -> empathi
# prototyping -> prototyp
# humanities -> human
# traced -> trace
# mckim's -> mckim'
# lawson's -> lawson'
# addressing -> address
# intrinsic -> intrins
# qualities -> qualiti
# abilities -> abil
# architects -> architect
# faste -> fast
# expanded -> expand
# purposes -> purpos
# consultancy -> consult
# expressed -> express
# concerns -> concern
# stating -> state
# facts -> fact
# ambiguous -> ambigu
# discover -> discov
# parameters -> paramet
# sets -> set
# iterative -> iter
# intermediate -> intermedi
# paths -> path
# empirical -> empir
# investigate -> investig
# asked -> ask
# coloured -> colour
# blocks -> block
# perimeter -> perimet
# adopted -> adopt
# trying -> tri
# designs -> design
# combinations -> combin
# acceptable -> accept
# discovered -> discov
# concluded -> conclud
# respectively -> respect
# procedure -> procedur
# substantial -> substanti
# ideate -> ideat
# impossible -> imposs
# realize -> realiz
# analytical -> analyt
# limits -> limit
# brainstorming -> brainstorm
# failure -> failur
# phases -> phase
# discovery -> discoveri
# ambiguities -> ambigu
# faulty -> faulti
# assumptions -> assumpt
# framed -> frame
# larry -> larri
# defining -> defin
# testing -> test
# shares -> share
# ambidextrous -> ambidextr
# curiosity -> curios
# optimism -> optim
# ambiguity -> ambigu
# thinkers -> thinker
# differently -> differ
# previously -> previous
# tangible -> tangibl
# prototypes -> prototyp
# ill-defined -> ill-defin
# malicious -> malici
# exercise -> exercis
# clarify -> clarifi
# requirements -> requir
# consists -> consist
# captured -> captur
# seems -> seem
# asking -> ask
# situational -> situat
# stanford's -> stanford'
# simplified -> simplifi
# summarizes -> summar
# considering -> consid
# obscure -> obscur
# expected -> expect
# images -> imag
# mechanisms -> mechan
# systemic -> system
# customer's -> customer'
# nonprofits -> nonprofit
# clients -> client
# consumers -> consum
# carried -> carri
# starts -> start
# constraints -> constraint
# measure -> measur
# pointing -> point
# incremental -> increment
# breakthroughs -> breakthrough
# simply -> simpli
# characterized -> character
# studied -> studi
# disposition -> disposit
# other's -> other'
# judged -> judg
# outcome -> outcom
# tends -> tend
# tendency -> tendenc
# continue -> continu
# headed -> head
# options -> option
# following -> follow
# organization's -> organization'
# conservative -> conserv
# route -> rout
# obstacle -> obstacl
# condition -> condit
# produce -> produc
# lots -> lot
# themes -> theme
# open-minded -> open-mind
# courage -> courag
# generated -> gener
# turned -> turn
# refined -> refin
# feedbacks -> feedback
# pieces -> piec
# failing -> fail
# appropriateness -> appropri
# jones -> jone
# responded -> respond
# historical -> histor
# designerly -> designerli
# neutrality -> neutral
# subjectivity -> subject
# imagination -> imagin
# justice -> justic
# drawings -> draw
# bringing -> bring
# interpretation -> interpret
# alone -> alon
# becoming -> becom
# characterizes -> character
# human-centered -> human-cent
# sales -> sale
# average -> averag
# historically -> histor
# feasibility -> feasibl
# helping -> help
# graduate -> graduat
# secondary -> secondari
# settings -> set
# apply -> appli
# rigorous -> rigor
# offers -> offer
# standardized -> standard
# tests -> test
# nuanced -> nuanc
# understandings -> understand
# months -> month
# arrives -> arriv
# pupils -> pupil
# displayed -> display
# contemporary -> contemporari
# attendees -> attende
# introduces -> introduc
# integrating -> integr
# hexagonal -> hexagon
# gathering -> gather
# googleable -> googleabl
# nongoogleable -> nongoogl
# setting -> set
# bias -> bia
# observe -> observ
# views -> view
# determine -> determin
# confidence -> confid
# publishes -> publish
# offered -> offer
# volunteer -> volunt
# motivate -> motiv
# utilizing -> util
# multitude -> multitud
# offering -> offer
# applying -> appli
# reduced -> reduc
# uncertainty -> uncertainti
# presents -> present
# placed -> place
# promising -> promis
# holistic -> holist
# happens -> happen
# pressing -> press
# operational -> oper
# so-called -> so-cal
# soft-systems -> soft-system
# christopher -> christoph
# alexander -> alexand
# knowledge-based -> knowledge-bas
# incorporated -> incorpor
# assessment -> assess
# arguably -> arguabl
# establishes -> establish
# partly -> partli
# anything -> anyth
# logical -> logic
# dilemmas -> dilemma
# showing -> show
# developments -> develop
# inadequate -> inadequ
# inquiry -> inquiri
# scholarly -> scholarli
# kinds -> kind
# launched -> launch
# cognition -> cognit
# writes -> write
# reflective -> reflect
# emerges -> emerg
# showcase -> showcas
# popularized -> popular
# workplace -> workplac
# joined -> join
# categories -> categori
# developers -> develop
# concerned -> concern
# supporting -> support
# personalized -> person
# handle -> handl
# gaining -> gain
# popularity -> popular
# workflows -> workflow
# creators -> creator
# customization -> custom
# automation -> autom
# timely -> time
# targeted -> target
# informed -> inform
# saves -> save
# consistent -> consist
# browse -> brows
# pulls -> pull
# running -> run
# offline -> offlin
# submitting -> submit
# license -> licens
# collanos -> collano
# huddle -> huddl
# hyperoffice -> hyperoffic
# jostle -> jostl
# mindquarry -> mindquarri
# freecommunity -> freecommun
# sorce -> sorc
# standalone -> standalon
# unbiased -> unbias
# etymology -> etymolog
# inductive -> induct
# deductive -> deduct
# habits -> habit
# computer-mediated -> computer-medi
# reasoned -> reason
# judgments -> judgment
# disciplined -> disciplin
# skillfully -> skill
# analyzing -> analyz
# synthesizing -> synthes
# evaluating -> evalu
# gathered -> gather
# observation -> observ
# reasoning -> reason
# judging -> judg
# conclusion -> conclus
# deciding -> decid
# inference -> infer
# explanation -> explan
# conceptual -> conceptu
# efficiency -> effici
# errors -> error
# biases -> bias
# appraisal -> apprais
# careful -> care
# exclude -> exclud
# philosophy -> philosophi
# kerry -> kerri
# walters -> walter
# logicism -> logic
# logistic -> logist
# conveys -> convey
# legitimate -> legitim
# conforms -> conform
# necessarily -> necessarili
# reliance -> relianc
# quantitative -> quantit
# re-thinking -> re-think
# constituted -> constitut
# accepted -> accept
# circles -> circl
# differential -> differenti
# acts -> act
# intuition -> intuit
# engaged -> engag
# critically -> critic
# non-traditional -> non-tradit
# metacognition -> metacognit
# applicable -> applic
# disposed -> dispos
# clarity -> clariti
# credibility -> credibl
# accuracy -> accuraci
# precision -> precis
# discernment -> discern
# evaluate -> evalu
# arguments -> argument
# conclusions -> conclus
# generalizations -> gener
# persistent -> persist
# examine -> examin
# supports -> support
# characterize -> character
# wherever -> wherev
# component -> compon
# subjects -> subject
# aimed -> aim
# dispositions -> disposit
# inherent -> inher
# underlying -> underli
# compiled -> compil
# invite -> invit
# assessing -> assess
# validity -> valid
# admissions -> admiss
# examinations -> examin
# alliance -> allianc
# specification -> specif
# meta-analysis -> meta-analysi
# politicians -> politician
# society's -> society'
# well-educated -> well-educ
# tended -> tend
# variable -> variabl
# categorize -> categor
# skepticism -> skeptic
# reflecting -> reflect
# prejudice -> prejudic
# misinformation -> misinform
# nurses -> nurs
# nursing -> nurs
# affecting -> affect
# records -> record
# continued -> continu
# tolerance -> toler
# course -> cours
# relative -> rel
# discourse -> discours
# featured -> featur
# justifications -> justif
# comments -> comment
# showed -> show
# statements -> statement
# systematically -> systemat
# coded -> code
# solely -> sole
# dramatic -> dramat
# cultures -> cultur
# thoughts -> thought
# try -> tri
# slightly -> slightli
# covered -> cover
# facilitator -> facilit
# employed -> employ
# unresolved -> unresolv
# calling -> call
# arranged -> arrang
# dynamics -> dynam
# facilitators -> facilit
# consequences -> consequ
# introduction -> introduct
# teleconference -> teleconfer
# possibly -> possibl
# contains -> contain
# verifying -> verifi
# inline -> inlin
# consisting -> consist
# plus -> plu
# relates -> relat
# variables -> variabl
# deployed -> deploy
# collection -> collect
# multi-user -> multi-us
# logged -> log
# placeware -> placewar
# audience -> audienc
# infoworkspace -> infoworkspac
# iws -> iw
# middle -> middl
# managers -> manag
# else -> els
# appeared -> appear
# infancy -> infanc
# losee -> lose
# really -> realli
# sessions -> session
# announce -> announc
# exacerbated -> exacerb
# ellis -> elli
# carefully -> care
# balanced -> balanc
# voting -> vote
# completed -> complet
# photos -> photo
# prediction -> predict
# spreadsheets -> spreadsheet
# conversations -> convers
# conversational -> convers
# transactional -> transact
# consultation -> consult
# deliberation -> deliber
# memory -> memori
# augmenting -> augment
# heritage -> heritag
# release -> releas
# louis -> loui
# lets -> let
# dispute -> disput
# compromise -> compromis
# virtually -> virtual
# references -> refer
# presidential -> presidenti
# election -> elect
# los -> lo
# angeles -> angel
# hosted -> host
# safire -> safir
# despite -> despit
# schwarzenegger -> schwarzenegg
# derived -> deriv
# overriding -> overrid
# coalition -> coalit
# minister -> minist
# policy-making -> policy-mak
# canada's -> canada'
# october -> octob
# proposal -> propos
# teenage -> teenag
# pregnancy -> pregnanc
# witnessed -> wit
# rates -> rate
# occurred -> occur
# mandated -> mandat
# ratings -> rate
# filtering -> filter
# reduction -> reduct
# implementations -> implement
# searches -> search
# retrieval -> retriev
# query -> queri
# clicked -> click
# mediation -> mediat
# privacy-aware -> privacy-awar
# recommendation -> recommend
# i-spy -> i-spi
# queries -> queri
# prominent -> promin
# searchtogether -> searchtogeth
# interface -> interfac
# reddy -> reddi
# cses -> cse
# collected -> collect
# ranking -> rank
# person's -> person'
# independently -> independ
# intentions -> intent
# privacy -> privaci
# disclosed -> disclos
# desirable -> desir
# pets -> pet
# hours -> hour
# issued -> issu
# sourcing -> sourc
# undefined -> undefin
# commissioned -> commiss
# named -> name
# competitions -> competit
# contests -> contest
# minds -> mind
# microtasks -> microtask
# crowds -> crowd
# noncommercial -> noncommerci
# timeline -> timelin
# astronomy -> astronomi
# genealogy -> genealog
# linguistics -> linguist
# ornithology -> ornitholog
# seismology -> seismolog
# crowdvoting -> crowdvot
# language-related -> language-rel
# crowdsolving -> crowdsolv
# crowdsearching -> crowdsearch
# crowdfunding -> crowdfund
# inducement -> induc
# health-care -> health-car
# agriculture -> agricultur
# cheating -> cheat
# bridge -> bridg
# crowdsourcers -> crowdsourc
# demographics -> demograph
# requesters -> request
# limitations -> limit
# controversies -> controversi
# funded -> fund
# irresponsible -> irrespons
# estells-arolas -> estells-arola
# varying -> vari
# undertaking -> undertak
# satisfaction -> satisfact
# mentioned -> mention
# it-mediated -> it-medi
# crowdsourced -> crowdsourc
# compensated -> compens
# prizes -> prize
# longitude -> longitud
# monetary -> monetari
# charge -> charg
# peanuts -> peanut
# paris -> pari
# city -> citi
# movie -> movi
# farmers -> farmer
# selling -> sell
# raised -> rais
# finance -> financ
# volunteering -> volunt
# picture -> pictur
# gps -> gp
# routing -> rout
# algorithms -> algorithm
# rewarded -> reward
# turbine -> turbin
# campaigns -> campaign
# olmsted -> olmst
# noticed -> notic
# stars -> star
# newspaper -> newspap
# nationwide -> nationwid
# helped -> help
# showers -> shower
# velocity -> veloc
# estimate -> estim
# crowdsource -> crowdsourc
# genealogical -> genealog
# ancestors -> ancestor
# valuable -> valuabl
# genographic -> genograph
# articles -> articl
# daily -> daili
# investigation -> investig
# vocabulary -> vocabulari
# christmas -> christma
# census -> censu
# birds -> bird
# species -> speci
# laws -> law
# resolutions -> resolut
# keywords -> keyword
# corrections -> correct
# beneficial -> benefici
# scrutinized -> scrutin
# comfortable -> comfort
# maybe -> mayb
# items -> item
# mobilizes -> mobil
# processing -> process
# counting -> count
# likes -> like
# contracts -> contract
# printed -> print
# purchase -> purchas
# predicting -> predict
# collectively -> collect
# high-quality -> high-qual
# smartphone -> smartphon
# charitable -> charit
# rewards-based -> rewards-bas
# funders -> funder
# donation -> donat
# equity -> equiti
# regulate -> regul
# regulations -> regul
# fundraising -> fundrais
# funds -> fund
# amounts -> amount
# dollars -> dollar
# specialized -> special
# workers -> worker
# chinese -> chines
# versions -> version
# getting -> get
# taxonomy -> taxonomi
# posted -> post
# stakes -> stake
# netflix's -> netflix'
# winning -> win
# department -> depart
# locate -> locat
# incentive -> incent
# connects -> connect
# entirely -> entir
# captchas -> captcha
# educated -> educ
# weeds -> weed
# boye -> boy
# internally -> intern
# parsing -> pars
# updates -> updat
# sample -> sampl
# crowdworkers -> crowdwork
# earning -> earn
# two-thirds -> two-third
# employers -> employ
# extrinsic -> extrins
# full-time -> full-tim
# enjoyment-based -> enjoyment-bas
# community-based -> community-bas
# peers -> peer
# payoffs -> payoff
# delayed -> delay
# immediately -> immedi
# received -> receiv
# altruistic -> altruist
# prestige -> prestig
# children's -> children'
# translators -> translat
# completion -> complet
# localization -> local
# translations -> translat
# decrease -> decreas
# capital-raising -> capital-rais
# investors -> investor
# wary -> wari
# replaced -> replac
# cutting -> cut
# translator -> translat
# ready -> readi
# collaborated -> collabor
# bombing -> bomb
# proofreaders -> proofread
# talks -> talk
# adds -> add
# dialing -> dial
# dialed -> dial
# pressed -> press
# flat-rate -> flat-rat
# ims -> im
# presentations -> present
# quarterly -> quarterli
# analysts -> analyst
# monthly -> monthli
# carriers -> carrier
# bundled -> bundl
# distance -> distanc
# organizer -> organ
# fees -> fee
# terminating -> termin
# origination -> origin
# termination -> termin
# intercarrier -> intercarri
# charges -> charg
# charging -> charg
# pays -> pay
# added -> ad
# cents -> cent
# minute -> minut
# rebate -> rebat
# minutes -> minut
# polling -> poll
# lovegrove -> lovegrov
# continually -> continu
# on-line -> on-lin
# adaptability -> adapt
# descriptive -> descript
# honoring -> honor
# edwards -> edward
# openagile -> openagil
# garry -> garri
# pivotal -> pivot
# guidance -> guidanc
# detachment -> detach
# receiving -> receiv
# opening -> open
# tracking -> track
# apps -> app
# visionaries -> visionari
# digitally -> digit
# workspace -> workspac
# lifecycle -> lifecycl
# compositions -> composit
# orchestral -> orchestr
# concertante -> concertant
# four-hands -> four-hand
# completions -> complet
# operas -> opera
# charles -> charl
# cardinal -> cardin
# composed -> compos
# les -> le
# franois -> franoi
# amadeus -> amadeu
# des -> de
# mozart's -> mozart'
# delibes -> delib
# jacques -> jacqu
# georges -> georg
# minkus -> minku
# mussorgsky -> mussorgski
# valverde -> valverd
# zarzuelas -> zarzuela
# toms -> tom
# maurice -> mauric
# mussorgsky's -> mussorgsky'
# removal -> remov
# honegger -> honegg
# orchestrations -> orchestr
# anatoly -> anatoli
# choreographed -> choreograph
# darius -> dariu
# francis -> franci
# germaine -> germain
# tailleferre -> tailleferr
# alexis -> alexi
# montsalvatge -> montsalvatg
# orchestrated -> orchestr
# goossens -> goossen
# shortly -> shortli
# suite -> suit
# dances -> danc
# revealed -> reveal
# harris -> harri
# premiered -> premier
# symphony -> symphoni
# premiere -> premier
# variation -> variat
# marguerite -> marguerit
# sections -> section
# kodly's -> kodly'
# composition -> composit
# matthews -> matthew
# moscheles -> moschel
# pianos -> piano
# sophie -> sophi
# songs -> song
# anniversary -> anniversari
# messager -> messag
# villerville -> villervil
# nos -> no
# chorus -> choru
# commemorate -> commemor
# franchomme -> franchomm
# unfinished -> unfinish
# davis -> davi
# londonderry -> londonderri
# hans -> han
# anthology -> antholog
# quadrille -> quadril
# died -> die
# assistants -> assist
# scores -> score
# fenby -> fenbi
# delius -> deliu
# sonatas -> sonata
# tudes -> tude
# playing -> play
# oboe -> obo
# grouped -> group
# misleading -> mislead
# composer's -> composer'

# %% [markdown]
# ## 9. Computing representation power of common words.

# %%
# combine
makerness = {}
# common_words = [w[0] for w in common_words]
for w in common_words:
    # Consider only words whose charcater length is larger than 1
    if len(w) > 1:
        # Log likelihood scores are computed:
        score = log((input_freq_dist[w] / n_input) / (english_freq_dist[w] / n_english))
        makerness[w] = score

# %%
common_words
# Out:
# ['credit',
#  '19th',
#  'agents',
#  'gold',
#  'heads',
#  'analyze',
#  'yellow',
#  'chosen',
#  'belief',
#  'evaluating',
#  'digital',
#  'multitude',
#  'chief',
#  'though',
#  'substantial',
#  'john',
#  'community',
#  'coalition',
#  'medicine',
#  'discovering',
#  'systemic',
#  'ross',
#  'mark',
#  '40',
#  'staff',
#  'gaining',
#  'worked',
#  'used',
#  'flood',
#  'room',
#  'pizza',
#  'creativity',
#  'rigorous',
#  'general',
#  'front',
#  'consists',
#  'index',
#  'campaign',
#  'revenue',
#  'actions',
#  'report',
#  'low',
#  'ted',
#  'relationships',
#  'legislation',
#  'without',
#  'skills',
#  'g',
#  'new',
#  'higher',
#  'two-thirds',
#  'organize',
#  'canada',
#  'economic',
#  'saves',
#  'armed',
#  'de',
#  'sold',
#  'logical',
#  'accept',
#  'transactions',
#  'stravinsky',
#  'investors',
#  'transparent',
#  'near',
#  'share',
#  'largest',
#  'assisting',
#  'joseph',
#  'zones',
#  'entire',
#  'n',
#  'route',
#  'possibilities',
#  'hours',
#  'martin',
#  'regions',
#  'side',
#  'user',
#  'learn',
#  'avoid',
#  'courses',
#  'items',
#  'velocity',
#  'convert',
#  'initial',
#  'instrumental',
#  'alongside',
#  'emergence',
#  'potentially',
#  'differently',
#  "children's",
#  'list',
#  'rules',
#  'viewed',
#  'mob',
#  'need',
#  'earn',
#  'observation',
#  'conventional',
#  'brief',
#  'isolated',
#  'london',
#  'growth',
#  'reconstruct',
#  'consensus',
#  'innovation',
#  'embedded',
#  'continuing',
#  'drama',
#  'co-operative',
#  'attempt',
#  'american',
#  'order',
#  'ford',
#  'died',
#  'arena',
#  'event',
#  'shown',
#  'diversity',
#  'sign',
#  'something',
#  'nature',
#  'choices',
#  'rational',
#  'august',
#  'survival',
#  'educated',
#  'exploration',
#  'pioneering',
#  'land',
#  'translated',
#  'simple',
#  'accurate',
#  'donate',
#  'fashion',
#  'mathematics',
#  'attempts',
#  'policy',
#  'nation',
#  'range',
#  'conditions',
#  'another',
#  'condition',
#  'join',
#  'create',
#  'charitable',
#  'frank',
#  'journal',
#  'turbine',
#  'experience',
#  'concentrate',
#  'journals',
#  'nations',
#  'kinds',
#  'group',
#  'array',
#  'chorus',
#  'obstacle',
#  'design',
#  'consisting',
#  'process',
#  'cathedral',
#  'simulated',
#  'arise',
#  'distinguishes',
#  'enables',
#  'census',
#  'personalized',
#  'individual',
#  'daily',
#  'bad',
#  'conflict',
#  'watching',
#  'writing',
#  'tools',
#  'lab',
#  'forth',
#  'necessary',
#  'promotes',
#  'platform',
#  'japan',
#  'bureaucracy',
#  'transaction',
#  'sickness',
#  'devices',
#  'spectrum',
#  'mussorgsky',
#  'appearance',
#  'george',
#  'advanced',
#  'exchange',
#  'dietrich',
#  'divided',
#  'roger',
#  'detail',
#  'tool',
#  'bringing',
#  'shift',
#  'lose',
#  'libraries',
#  'mass',
#  'undertaking',
#  'eventually',
#  'stages',
#  'adopted',
#  'light',
#  'compromise',
#  'known',
#  'phenomenon',
#  'premiere',
#  'advice',
#  'injustice',
#  'tree',
#  'defining',
#  'parts',
#  'intermediate',
#  'ernest',
#  'resulting',
#  'liberation',
#  'comprehend',
#  'uses',
#  'crowds',
#  'main',
#  'stimulate',
#  'allen',
#  'impossible',
#  'subject',
#  'presentations',
#  'maximum',
#  'power',
#  'introduces',
#  'likes',
#  'mechanical',
#  'sessions',
#  'artistic',
#  'driving',
#  'laboratories',
#  'others',
#  'editors',
#  'practical',
#  'thing',
#  'contains',
#  'alone',
#  'decades',
#  'newspapers',
#  'variety',
#  'greater',
#  'geographically',
#  'admissions',
#  'page',
#  'frequently',
#  'specific',
#  'designated',
#  'commitment',
#  'concepts',
#  'systems',
#  'existed',
#  'cited',
#  'developments',
#  'newman',
#  'makers',
#  'embrace',
#  'housing',
#  'unique',
#  'back',
#  'participating',
#  'considerations',
#  'behalf',
#  '0',
#  'picture',
#  'contrast',
#  'concluded',
#  'structures',
#  'biggest',
#  'institutions',
#  'name',
#  'conduct',
#  'steve',
#  'increasing',
#  'transmitted',
#  'occurs',
#  'fix',
#  'characteristics',
#  'swarm',
#  'session',
#  'rate',
#  'intuition',
#  'engineer',
#  'differential',
#  'legitimate',
#  'fixed',
#  'citizens',
#  'featuring',
#  'vary',
#  'capital',
#  'divergent',
#  'germany',
#  'member',
#  'ideal',
#  'enterprises',
#  'genius',
#  'output',
#  'encourage',
#  'setting',
#  'adoption',
#  'arranged',
#  'comparative',
#  'compares',
#  'analysts',
#  'wave',
#  'director',
#  'writers',
#  'compass',
#  'clear',
#  'sociological',
#  'tag',
#  'lasting',
#  'voluntary',
#  'navy',
#  'release',
#  'radical',
#  'valued',
#  'expand',
#  'traits',
#  'regular',
#  'boeing',
#  'bridge',
#  'relations',
#  'non',
#  'competitive',
#  'styles',
#  'told',
#  'last',
#  'active',
#  'manhattan',
#  're',
#  'assistant',
#  'customers',
#  'distinctive',
#  'inside',
#  'lee',
#  'infancy',
#  'satin',
#  'holds',
#  'live',
#  'inventions',
#  'performing',
#  'participates',
#  'phases',
#  'solving',
#  'scholarly',
#  'fully',
#  'allows',
#  'symbols',
#  'previous',
#  'units',
#  'honoring',
#  'metaphor',
#  'vocal',
#  'completing',
#  'bellini',
#  'screen',
#  'dances',
#  'feasibility',
#  'spatial',
#  'met',
#  'forgotten',
#  'improving',
#  'coin',
#  'noticed',
#  'serves',
#  'account',
#  'loose',
#  'really',
#  'save',
#  'tablet',
#  'membership',
#  'project',
#  'draw',
#  'pin',
#  'task',
#  'dancer',
#  'joel',
#  'nuclear',
#  'pay',
#  'method',
#  'skill',
#  'employee',
#  'incentives',
#  'modes',
#  'neil',
#  'open',
#  'nonetheless',
#  'examinations',
#  'dates',
#  'electronic',
#  'theodore',
#  'memory',
#  'managing',
#  'viewpoint',
#  'meaningful',
#  'addressing',
#  'numerous',
#  'members',
#  'profits',
#  'subjects',
#  'codes',
#  'captured',
#  'section',
#  'prizes',
#  'sweden',
#  'examination',
#  'period',
#  'discusses',
#  'parameters',
#  'dimensions',
#  'entails',
#  'creates',
#  'sole',
#  'partner',
#  'furthermore',
#  'mutually',
#  'assess',
#  'assigned',
#  'maintaining',
#  'compositions',
#  'discussion',
#  'recently',
#  'speak',
#  'work',
#  'voices',
#  'six',
#  'objects',
#  'tolerance',
#  'disruptive',
#  'igor',
#  'associate',
#  'applications',
#  'mountain',
#  'decide',
#  'matthew',
#  'change',
#  'sheep',
#  'seek',
#  'conscious',
#  'meetings',
#  'media',
#  'quickly',
#  'classrooms',
#  'solve',
#  'motion',
#  'exist',
#  'paradigm',
#  'disciplined',
#  'fees',
#  'amounts',
#  'personal',
#  'requirements',
#  'air',
#  'call',
#  'successfully',
#  'violinist',
#  'typical',
#  'character',
#  'holding',
#  'forced',
#  'grade',
#  'scope',
#  'years',
#  'accurately',
#  'provides',
#  'intellect',
#  'appraisal',
#  'june',
#  'highest',
#  'worlds',
#  'challenge',
#  'nick',
#  'originally',
#  'helped',
#  'completions',
#  'unknown',
#  'optimistic',
#  'training',
#  'reach',
#  'termination',
#  'gain',
#  'concept',
#  'scrutinized',
#  'judgment',
#  'publishes',
#  'middle',
#  'disposed',
#  'contact',
#  'discern',
#  'chains',
#  'much',
#  'cooperation',
#  'art',
#  'benjamin',
#  'quartet',
#  'virtual',
#  'risks',
#  'doctrine',
#  'freedom',
#  'form',
#  'colleges',
#  'physician',
#  'level',
#  'attitude',
#  'draft',
#  'cultures',
#  'management',
#  'investigating',
#  'salt',
#  'efforts',
#  'reduction',
#  'stuart',
#  'appropriate',
#  'participate',
#  'mechanisms',
#  'end',
#  'prototype',
#  'curriculum',
#  'remove',
#  'jean',
#  'aspects',
#  'contain',
#  'displays',
#  'determine',
#  'facing',
#  'contributors',
#  'comes',
#  'calls',
#  'contribution',
#  'students',
#  'indicators',
#  'sonata',
#  'prices',
#  'money',
#  'consciously',
#  'fact',
#  'achieving',
#  'medium',
#  'international',
#  'argument',
#  'persistent',
#  'different',
#  'quarterly',
#  'licensed',
#  'early',
#  'assessment',
#  'critical',
#  'environmental',
#  'lawyer',
#  'achieves',
#  'spend',
#  'several',
#  'designer',
#  'whether',
#  'robots',
#  'sciences',
#  'source',
#  'emerges',
#  'services',
#  'labor',
#  'count',
#  'instruction',
#  'toll',
#  'purchase',
#  'ethical',
#  'aspirations',
#  'relationship',
#  'expert',
#  'robert',
#  'technician',
#  'awarded',
#  'pursue',
#  'better',
#  'deliver',
#  'aimed',
#  'producing',
#  'operates',
#  'corresponds',
#  'boy',
#  'result',
#  'numbers',
#  'observed',
#  'body',
#  'gathered',
#  'disclosed',
#  'connect',
#  'responses',
#  'suite',
#  'named',
#  'camera',
#  'road',
#  'eric',
#  'screens',
#  'citation',
#  'authors',
#  'west',
#  'grows',
#  'launch',
#  'living',
#  'anything',
#  'les',
#  'represents',
#  'take',
#  'press',
#  'clarity',
#  'images',
#  'knowing',
#  'earlier',
#  'ideally',
#  'real',
#  'manipulate',
#  'image',
#  'workers',
#  'european',
#  'albert',
#  'version',
#  'leads',
#  'despite',
#  'consistency',
#  'classic',
#  'explicitly',
#  'opposed',
#  'necessity',
#  'irresponsible',
#  'classical',
#  'produced',
#  'million',
#  'reality',
#  'operetta',
#  'brought',
#  'question',
#  'love',
#  'world',
#  'election',
#  'del',
#  'sought',
#  'surgery',
#  'traffic',
#  'policies',
#  'locate',
#  'polling',
#  'direct',
#  'access',
#  'problem',
#  'english',
#  'senses',
#  'battle',
#  'uniform',
#  'owns',
#  'resources',
#  'herbert',
#  'guitar',
#  'beginning',
#  'commons',
#  'spread',
#  'entity',
#  'focused',
#  'linking',
#  'faster',
#  'lives',
#  'meant',
#  'foster',
#  'essay',
#  "one's",
#  'users',
#  'permits',
#  'implementation',
#  'gave',
#  'functional',
#  'groups',
#  'dominant',
#  'species',
#  'false',
#  'extra',
#  'orchestra',
#  'complete',
#  'instances',
#  'portal',
#  'death',
#  'professionals',
#  'helps',
#  'accelerate',
#  'space',
#  'begun',
#  'publication',
#  'education',
#  'broadly',
#  'marketing',
#  'accordingly',
#  'carefully',
#  'shape',
#  'separate',
#  'story',
#  'hand',
#  'levels',
#  'farmers',
#  'trend',
#  'input',
#  'stored',
#  'effectiveness',
#  'profession',
#  'teacher',
#  'solo',
#  'artist',
#  'intentional',
#  'language',
#  'pulls',
#  'experimentation',
#  'two',
#  'malcolm',
#  'connected',
#  'p',
#  'must',
#  'developing',
#  'force',
#  'pressed',
#  'rely',
#  'antonio',
#  'launched',
#  'republican',
#  'artificial',
#  'showing',
#  'stakes',
#  'increased',
#  'insight',
#  'noted',
#  'receiving',
#  'agreed',
#  'dedicated',
#  'autonomy',
#  'games',
#  'needs',
#  'giving',
#  'purposeful',
#  'intent',
#  'smaller',
#  'carriers',
#  'trade',
#  'impressive',
#  'framed',
#  'pierre',
#  'discussions',
#  'majority',
#  'operation',
#  'apply',
#  'act',
#  'stage',
#  'number',
#  'sea',
#  'providing',
#  'freely',
#  'monthly',
#  'argue',
#  'citizen',
#  'barriers',
#  'shaped',
#  'president',
#  'sales',
#  'draws',
#  'shower',
#  'positive',
#  'hands',
#  'solved',
#  'candidates',
#  'fathers',
#  'huddle',
#  'features',
#  'centuries',
#  'manipulation',
#  'creation',
#  'speed',
#  'circular',
#  'expected',
#  'jacques',
#  'violin',
#  'timely',
#  'purpose',
#  's',
#  'film',
#  'judgments',
#  'school',
#  'un',
#  'winning',
#  'circle',
#  'objectives',
#  'photos',
#  'chat',
#  'partly',
#  'calendar',
#  'automatically',
#  'follow',
#  'projects',
#  'combination',
#  'belong',
#  '20th',
#  '1',
#  'according',
#  'good',
#  'classroom',
#  'replace',
#  'innate',
#  'gains',
#  'university',
#  'differs',
#  'posted',
#  'promising',
#  'base',
#  'ratings',
#  'lowest',
#  'experienced',
#  'play',
#  'wilson',
#  'beliefs',
#  'job',
#  'passed',
#  'letter',
#  'colony',
#  'aid',
#  'link',
#  'significant',
#  'submit',
#  'clara',
#  'right',
#  'facts',
#  'less',
#  'thread',
#  'tend',
#  'sector',
#  'composition',
#  'inquiry',
#  'young',
#  'great',
#  'lockheed',
#  'maintain',
#  'bird',
#  'additionally',
#  'useful',
#  'concerned',
#  'linked',
#  'volunteers',
#  'working',
#  'highly',
#  'governing',
#  'mix',
#  'executive',
#  'security',
#  "world's",
#  'engagement',
#  'roy',
#  'amateur',
#  'influence',
#  'later',
#  'hour',
#  'removal',
#  'harvey',
#  'size',
#  'assist',
#  'intertwined',
#  'widely',
#  'bombing',
#  'controversy',
#  'prize',
#  'occupation',
#  'consciousness',
#  'flight',
#  'percent',
#  'opportunity',
#  'desire',
#  'tv',
#  'markets',
#  'addition',
#  'reliable',
#  'sponsor',
#  'give',
#  'occupying',
#  'produce',
#  'broadcast',
#  'systematically',
#  'achieve',
#  'raised',
#  'wiley',
#  'conjunction',
#  'communicated',
#  'days',
#  'church',
#  'entries',
#  'failing',
#  'writes',
#  'respective',
#  'discuss',
#  'organization',
#  'crucial',
#  'charge',
#  'emphasis',
#  'conceptual',
#  'anywhere',
#  'editing',
#  'attain',
#  'm',
#  'circumstances',
#  'invite',
#  'past',
#  'function',
#  'conceived',
#  'los',
#  'astronomy',
#  'updated',
#  'separating',
#  'democratic',
#  'musical',
#  'yet',
#  'going',
#  'balance',
#  'shaping',
#  'chart',
#  'douglas',
#  'independently',
#  'printed',
#  'institute',
#  'alkali',
#  'utilize',
#  'publish',
#  'experiments',
#  'free',
#  'desirable',
#  'budget',
#  "'",
#  'dewey',
#  'coordinated',
#  'refined',
#  'debate',
#  'team',
#  'contests',
#  'sound',
#  'respect',
#  'collaboration',
#  'department',
#  'influenced',
#  'border',
#  'value',
#  'pets',
#  'interpret',
#  'rewards',
#  'type',
#  'synthesis',
#  'depend',
#  'joined',
#  'want',
#  'managed',
#  'des',
#  'e',
#  'turn',
#  'phrase',
#  'bill',
#  'underlying',
#  'evidence',
#  'covered',
#  'observe',
#  'opposing',
#  'pioneers',
#  'travel',
#  'agreement',
#  'analytical',
#  'received',
#  'raise',
#  'look',
#  'society',
#  'preferences',
#  'mud',
#  'j',
#  'came',
#  'role',
#  'challenged',
#  'tutor',
#  'profit',
#  'large',
#  'keep',
#  'carry',
#  'element',
#  'participants',
#  'broadcasting',
#  'trying',
#  'blocks',
#  'distributed',
#  'seven',
#  'submitting',
#  'january',
#  'association',
#  'rich',
#  'brother',
#  'ownership',
#  'deployed',
#  'using',
#  ...]

# %%
# Sorting by scores:
for k,v in sorted(makerness.items(), key=lambda x:x[1], reverse=True): print(k,v)
# Out:
# collaboration 5.991934107047692
# users 5.758840224880314
# user 5.308639222930758
# portal 5.288836595634578
# participants 5.1739066289606015
# web 4.987731502850657
# global 4.960332528662542
# innovation 4.9362349770834815
# challenges 4.873321151672912
# virtual 4.854972013004716
# researchers 4.7780109718685875
# motivations 4.6501776003587025
# expertise 4.634910128227914
# turk 4.554867420554378
# connect 4.4678560435647485
# organizational 4.449506904896552
# template 4.449506904896552
# implementation 4.384968383758981
# perspectives 4.372545863760424
# citation 4.331723869240168
# educators 4.267185348102597
# environments 4.267185348102597
# solving 4.224625733683801
# digital 4.210026934262649
# capacities 4.198192476615645
# media 4.187142640429061
# composers 4.187142640429061
# vs 4.180173971112967
# prototype 4.149402312446214
# les 4.149402312446214
# coined 4.149402312446214
# definitions 4.149402312446214
# indigenous 4.149402312446214
# design 4.1193499673798115
# feedback 4.084863791308642
# links 4.05587625443539
# allows 4.052775476757142
# editing 4.044041796788387
# robots 4.015870919821691
# 21st 4.015870919821691
# niche 4.015870919821691
# implementing 4.015870919821691
# face-to-face 4.015870919821691
# interactions 4.015870919821691
# thinking 3.9694916402365696
# designers 3.930713111481384
# deductive 3.861720239994433
# cinema 3.861720239994433
# advocacy 3.861720239994433
# researcher 3.861720239994433
# rewards 3.8617202399944324
# computers 3.8617202399944324
# implement 3.8617202399944324
# translation 3.829971541679852
# computer 3.8224995268411512
# critical 3.8086104146804844
# divergent 3.774708863004803
# traits 3.774708863004803
# sharing 3.7707484617887057
# learning 3.7655763794415305
# intentional 3.756359724336606
# sectors 3.756359724336606
# agenda 3.756359724336606
# managing 3.72818884736991
# access 3.7040912957908496
# lab 3.679398683200478
# purposeful 3.679398683200478
# publish 3.679398683200478
# viewers 3.679398683200478
# queries 3.679398683200478
# solutions 3.672478240355904
# facilitate 3.6385766886802227
# genetic 3.6385766886802227
# platforms 3.6385766886802227
# implicit 3.5993559755269415
# document 3.5993559755269415
# matthew 3.5740381675426516
# publishes 3.5740381675426516
# contributors 3.5740381675426516
# peer 3.5740381675426516
# orchestral 3.5740381675426516
# bruce 3.5740381675426516
# standardized 3.5740381675426516
# nurses 3.5740381675426516
# skills 3.564988332022734
# tools 3.554235540246472
# interaction 3.554235540246472
# tasks 3.5389468477313817
# challenged 3.5362978395598046
# wicked 3.5362978395598046
# chat 3.5050452960557
# ranking 3.5050452960557
# enhance 3.5050452960557
# intrinsic 3.5050452960557
# typically 3.487026790553022
# emergence 3.456255131886268
# pioneering 3.456255131886268
# igor 3.456255131886268
# coins 3.456255131886268
# topic 3.456255131886268
# began -0.27184503538094945
# shows -0.276109434167407
# though -0.27914433786256104
# highest -0.28141448639710015
# dramatic -0.28141448639710015
# happen -0.28141448639710015
# placed -0.28141448639710015
# broken -0.28141448639710015
# office -0.2932489440441029
# small -0.2934795979489428
# accepted -0.2971628433652391
# dream -0.2971628433652393
# explain -0.2971628433652393
# us -0.3016171937146195
# direct -0.3049449838072942
# mind -0.3126670299012045
# join -0.31266702990120465
# rapidly -0.31266702990120465
# supposed -0.31266702990120465
# object -0.31266702990120465
# getting -0.32185545595561077
# substantial -0.327934502031993
# experiments -0.327934502031993
# association -0.327934502031993
# forest -0.327934502031993
# chair -0.327934502031993
# cutting -0.327934502031993
# army -0.327934502031993
# july -0.327934502031993
# significance -0.327934502031993
# sales -0.3354817076673759
# meant -0.33798483788549444
# places -0.33798483788549444
# sides -0.33798483788549444
# things -0.34161460593607323
# direction -0.34297237939653347
# asking -0.34297237939653347
# aside -0.34297237939653347
# sit -0.34297237939653347
# york -0.34462938060416304
# areas -0.3493485965358095
# policies -0.3577874651816741
# won -0.3577874651816741
# news -0.3577874651816741
# board -0.3619803434417101
# move -0.3636525846340722
# basic -0.3636525846340722
# word -0.36511350527374714
# record -0.36511350527374714
# makes -0.36948350494486537
# followed -0.36948350494486537
# two -0.3706172919143921
# fashion -0.3723862646028268
# willing -0.3723862646028268
# lost -0.3752806226291913
# death -0.3760029050730153
# despite -0.3772055510387756
# kind -0.3804055537694466
# hours -0.38104432734594135
# read -0.38104432734594135
# rate -0.38200172330226884
# see -0.3893690372319731
# federal -0.39084832744256215
# brown -0.3924730231695642
# scene -0.39625374600947016
# april -0.4009596370468828
# factor -0.4009596370468828
# carrying -0.4009596370468828
# du -0.4009596370468828
# proved -0.4009596370468828
# continue -0.4056434863593092
# division -0.4056434863593092
# late -0.40937483397216734
# attention -0.40937483397216734
# long -0.4096408267919296
# detail -0.4149458790216227
# plus -0.4149458790216227
# faces -0.4149458790216227
# distance -0.4149458790216227
# brought -0.41890628023771953
# sent -0.42186632186619644
# deep -0.42416253412654675
# without -0.42702540467622385
# brother -0.42873920115395864
# discovered -0.42873920115395864
# nevertheless -0.42873920115395864
# chapter -0.42873920115395864
# completely -0.4332950176898194
# question -0.4345928764054192
# following -0.4378301728552104
# rich -0.4423448532097372
# pool -0.4423448532097372
# store -0.4423448532097372
# expressed -0.4557678735418778
# national -0.4557678735418778
# vote -0.4557678735418778
# must -0.45626157880986706
# operation -0.4602024706097436
# born -0.4602024706097436
# choice -0.4602024706097436
# money -0.4652466174964216
# latter -0.4690131002918984
# watching -0.4690131002918986
# hearing -0.4690131002918986
# finally -0.47426245617804225
# forward -0.47774678026065315
# days -0.4794844001591938
# love -0.48208518185925137
# election -0.48208518185925137
# turn -0.49070592490315834
# mission -0.49498858669515916
# property -0.49498858669515916
# certain -0.49818858942583
# middle -0.5034992763630678
# children -0.5063201527047092
# maximum -0.5077276124725889
# reduced -0.5077276124725889
# sam -0.5077276124725889
# chief -0.5119381450089325
# job -0.5119381450089325
# asked -0.5152938528559049
# show -0.8849495082673583
# looking -0.8861062463951821
# war -0.891869951111932
# forces -0.897600625820917
# character -0.9089643844712322
# image -0.9174032531170968
# spirit -0.9368213389741984
# eye -0.9423008047388239
# immediately -0.9504641153779848
# ground -0.9585613256106043
# state -0.9598012513739248
# fire -0.9639232687519896
# carried -0.9665934973078685
# go -0.9681922186715657
# spring -0.9824668464641586
# fear -0.9824668464641586
# longer -0.9955048408022885
# still -1.0083750313228235
# met -1.0210816825919382
# lines -1.0210816825919382
# table -1.0210816825919382
# going -1.0286288882273211
# continued -1.0286288882273211
# maybe -1.0286288882273211
# trial -1.0361195599564788
# car -1.0582606858336925
# western -1.0582606858336925
# came -1.0671424559684728
# nearly -1.0870396503837356
# military -1.0894009265694153
# took -1.0941068176068283
# ready -1.1011243902654748
# big -1.1080930595815681
# hands -1.1115592675580543
# food -1.1287123467843037
# line -1.1422260659510266
# earth -1.1489150541018232
# wanted -1.153349651169689
# side -1.1647884032581133
# hear -1.168717681398003
# close -1.1881357672551045
# passed -1.1945255653538756
# floor -1.2008747930325343
# foreign -1.2008747930325343
# wall -1.2134535752393945
# back -1.2196841249900305
# fine -1.2196841249900305
# picture -1.2258760952379515
# friends -1.2258760952379515
# end -1.235704184174214
# sort -1.238146187829766
# son -1.2442252339061481
# river -1.2442252339061481
# yet -1.25985994805355
# head -1.27172248336337
# tried -1.2740781970558293
# air -1.2818907367926229
# coming -1.2973350592200963
# nations -1.3030657339290814
# now -1.3042079385078584
# else -1.3087637550437192
# held -1.3087637550437192
# period -1.3125444778836253
# along -1.3172503689210378
# fact -1.324547622744981
# little -1.3568321580847416
# everything -1.3586355850838923
# much -1.3715251298098892
# year -1.3747217228355164
# months -1.3800267750652098
# great -1.3853038321660536
# president -1.3905531880521973
# left -1.395775132033349
# living -1.4061379190688956
# women -1.4112793185693142
# minutes -1.4163944192360847
# city -1.4189421913148834
# road -1.421483488743556
# red -1.421483488743556
# near -1.4265467907001028
# say -1.444565296202781
# washington -1.4661559287951487
# home -1.5264378305533934
# front -1.5364424615233203
# away -1.5676253889600082
# seem -1.572001763559807
# day -1.5720017635598071
# church -1.5850171316718773
# west -1.5978652741497263
# boy -1.627217486162254
# ago -1.64361129593793
# heard -1.6476680966335446
# whose -1.6637326991373513
# let -1.6834572044851297
# seems -1.6951078217051052
# last -1.7381821041743764
# really -1.7550508576721386
# week -1.7550508576721386
# told -1.756262244858436
# anything -1.7730693631748171
# quite -1.7766344293393133
# gave -1.790768940274218
# enough -1.7965998605850113
# something -1.8420622346617683
# turned -1.9066007557993396
# family -1.9403981353826303
# light -1.946422249986011
# seemed -1.946422249986011
# went -1.9613256554885863
# house -2.114630669303501
# eyes -2.1322411873121365
# far -2.192719106274938
# old -2.2265684917490893
# never -2.279600062657927
# course -2.280317165592924
# said -2.333195225082023
# man -2.8287078729949346

# %%
with open('makerness_diy.csv', 'w') as csvfile:
    thewriter = csv.writer(csvfile, delimiter=',')
    for k,v in sorted(makerness.items(), key=lambda x:x[1], reverse=True):
        thewriter.writerow([k,v])
