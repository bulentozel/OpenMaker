# %%
from utils import tokenizer
import nltk
from nltk import FreqDist
from math import log
import json, csv

# %%
from nltk.corpus import brown
brown.categories()
# Out:
# ['adventure',
#  'belles_lettres',
#  'editorial',
#  'fiction',
#  'government',
#  'hobbies',
#  'humor',
#  'learned',
#  'lore',
#  'mystery',
#  'news',
#  'religion',
#  'reviews',
#  'romance',
#  'science_fiction']

# %%
#load stopwords to remove
with open("data/stopwords.txt", "r") as f:
    STOP_WORDS = set(f.read().strip().split("\n"))
print(STOP_WORDS)
# Out:
# {'she', 'through', 'here', "where's", 'into', 'very', 'our', 'all', 'myself', "they'll", 'her', "she'll", 'under', "they're", 'like', 'of', 'he', "don't", 'again', "haven't", "it's", 'an', 'how', 'off', 'am', 'it', 'be', 'did', "we'd", 'were', 'then', 'do', "who's", "you'll", 'is', "mustn't", 'where', 'other', 'further', 'should', "won't", "he'd", 'himself', 'ours ', 'www', 'some', 'when', 'over', 'on', 'by', 'down', 'out', "didn't", 'me', 'r', 'same', 'those', 'above', "couldn't", 'such', 'that', 'own', "i'm", 'just', 'whom', 'know', 'to', "wouldn't", 'ourselves', 'at', "there's", 'cannot', 'been', 'themselves', "aren't", 'while', 'its', "let's", 'being', 'each', 'after', 'could', "isn't", 'are', 'herself', 'few', 'a', 'up', "we'll", 'during', 'so', 'http', 'yours', "we're", 'not', "when's", 'with', 'them', 'the', "can't", 'both', "i'd", 'no', 'my', 'because', 'before', 'their', 'would', "hasn't", 'have', "you're", "weren't", 'him', 'nor', 'but', 'your', 'too', 'these', 'as', 'in', 
# ...

# %%
# load english words from 
english_freq_dist = FreqDist([w.lower() for w in nltk.corpus.brown.words()
                              if w not in STOP_WORDS])

# remove rare words and get total count
english_freq_dist = {k:v for k,v in english_freq_dist.items() if v > 2}
n_english = sum(english_freq_dist.values())

# %%
with open("data/wikipedia.json", "r") as f: OM_Corpus_text = f.read()
OM_Corpus = json.loads(OM_Corpus_text)
print(len(OM_Corpus))
OM_Corpus[0].keys()
# Out:
# 152
# dict_keys(['theme.id', 'title', 'url', 'depth', 'text'])

# %%
def display_pages(tid):
    meme = [page for page in OM_Corpus if page['theme.id'] == tid]
    for m in meme:
        print(m['depth'],m['title'], m['url'])

# %%
display_pages(0)
# Out:
# 0 Do it yourself https://en.wikipedia.org/wiki/Do_it_yourself
# 1 Edupunk https://en.wikipedia.org/wiki/Edupunk
# 1 Prosumer https://en.wikipedia.org/wiki/Prosumer
# 1 How-to https://en.wikipedia.org/wiki/How-to
# 1 Kludge https://en.wikipedia.org/wiki/Kludge
# 1 Bricolage https://en.wikipedia.org/wiki/Bricolage
# 1 Junk box https://en.wikipedia.org/wiki/Junk_box
# 1 Number 8 wire https://en.wikipedia.org/wiki/Number_8_wire
# 1 Ready-to-assemble furniture https://en.wikipedia.org/wiki/Ready-to-assemble_furniture
# 1 Open design https://en.wikipedia.org/wiki/Open_Design
# 1 Hackerspace https://en.wikipedia.org/wiki/Hackerspace
# 1 Instructables https://en.wikipedia.org/wiki/Instructables
# 1 Handyman https://en.wikipedia.org/wiki/Handyman
# 1 Circuit bending https://en.wikipedia.org/wiki/Circuit_bending
# 1 Project GreenWorld International https://en.wikipedia.org/wiki/Project_GreenOman
# 1 3D printing https://en.wikipedia.org/wiki/3D_printing

# %%
display_pages(1)
# Out:
# 0 Open design https://en.wikipedia.org/wiki/Open_design
# 1 Knowledge commons https://en.wikipedia.org/wiki/Knowledge_commons
# 1 Open Source Ecology https://en.wikipedia.org/wiki/Open_Source_Ecology
# 1 Computer-aided design https://en.wikipedia.org/wiki/Computer-aided_design
# 1 Open Source Initiative https://en.wikipedia.org/wiki/Open_Source_Initiative
# 1 Open Architecture Network https://en.wikipedia.org/wiki/Open_Architecture_Network
# 1 Open-source architecture https://en.wikipedia.org/wiki/Open-source_architecture
# 1 Commons-based peer production https://en.wikipedia.org/wiki/Commons-based_peer_production
# 1 Open standard https://en.wikipedia.org/wiki/Open_standard
# 1 OpenCores https://en.wikipedia.org/wiki/OpenCores
# 1 Co-creation https://en.wikipedia.org/wiki/Co-creation
# 1 OpenBTS https://en.wikipedia.org/wiki/OpenBTS
# 1 Open manufacturing https://en.wikipedia.org/wiki/Open_manufacturing
# 1 Open-source hardware https://en.wikipedia.org/wiki/Open-source_hardware
# ...

# %%
display_pages(2)
# Out:
# 0 Sustainability https://en.wikipedia.org/wiki/Sustainability
# 1 Sustainability standards and certification https://en.wikipedia.org/wiki/Sustainability_standards_and_certification
# 1 Appropriate technology https://en.wikipedia.org/wiki/Appropriate_technology
# 1 Sustainable development https://en.wikipedia.org/wiki/Sustainable_development
# 1 Environmental issue https://en.wikipedia.org/wiki/Environmental_issue
# 1 World Cities Summit https://en.wikipedia.org/wiki/World_Cities_Summit
# 1 Ecopsychology https://en.wikipedia.org/wiki/Ecopsychology
# 1 Book:Sustainability https://en.wikipedia.org/wiki/Book:Sustainability
# 1 Sustainable design https://en.wikipedia.org/wiki/Sustainable_design
# 1 Circles of Sustainability https://en.wikipedia.org/wiki/Circles_of_Sustainability
# 1 Sustainability science https://en.wikipedia.org/wiki/Sustainability_science
# 1 Sustainable living https://en.wikipedia.org/wiki/Sustainable_living
# ...

# %%
display_pages(3)
# Out:
# 0 Maker culture https://en.wikipedia.org/wiki/Maker_culture
# 1 Modular design https://en.wikipedia.org/wiki/Modular_design
# 1 Open-source car https://en.wikipedia.org/wiki/Open-source_car
# 1 Electric vehicle conversion https://en.wikipedia.org/wiki/Electric_vehicle_conversion
# 1 Thingiverse https://en.wikipedia.org/wiki/Thingiverse
# 1 Fab lab https://en.wikipedia.org/wiki/Fab_Lab_(fabrication_laboratory)
# 1 SparkFun Electronics https://en.wikipedia.org/wiki/SparkFun
# 1 RepRap project https://en.wikipedia.org/wiki/RepRap
# 1 Distributed manufacturing https://en.wikipedia.org/wiki/Distributed_manufacturing
# 1 Craft production https://en.wikipedia.org/wiki/Craft_production
# 1 Autonomous building https://en.wikipedia.org/wiki/Autonomous_building
# 1 Open-source hardware https://en.wikipedia.org/wiki/Open_source_hardware
# 1 Kit car https://en.wikipedia.org/wiki/Kit_car

# %%
display_pages(4)
# Out:
# 0 Innovation https://en.wikipedia.org/wiki/Innovation
# 1 Competitive intelligence https://en.wikipedia.org/wiki/Creative_competitive_intelligence
# 1 Multiple discovery https://en.wikipedia.org/wiki/Multiple_discovery
# 1 UNDP Innovation Facility https://en.wikipedia.org/wiki/UNDP_Innovation_Facility
# 1 Open Innovations (event) https://en.wikipedia.org/wiki/Open_Innovations_(Forum_and_Technology_Show)
# 1 Trans-cultural diffusion https://en.wikipedia.org/wiki/Diffusion_(anthropology)
# 1 Individual capital https://en.wikipedia.org/wiki/Individual_capital
# 1 Innovation system https://en.wikipedia.org/wiki/Innovation_system
# 1 Public domain https://en.wikipedia.org/wiki/Public_domain
# 1 Ingenuity https://en.wikipedia.org/wiki/Ingenuity
# 1 Sustainable Development Goals https://en.wikipedia.org/wiki/Sustainable_Development_Goals
# 1 Participatory design https://en.wikipedia.org/wiki/Participatory_design
# 1 Innovation management https://en.wikipedia.org/wiki/Innovation_management
# ...

# %%
display_pages(5)
# Out:
# 0 Collaboration https://en.wikipedia.org/wiki/Collaboration
# 1 Wikinomics https://en.wikipedia.org/wiki/Wikinomics
# 1 Collaborative editing https://en.wikipedia.org/wiki/Collaborative_editing
# 1 Telepresence https://en.wikipedia.org/wiki/Telepresence
# 1 Knowledge management https://en.wikipedia.org/wiki/Knowledge_management
# 1 The Culture of Collaboration https://en.wikipedia.org/wiki/The_Culture_of_Collaboration
# 1 Collaborative governance https://en.wikipedia.org/wiki/Collaborative_governance
# 1 Community film https://en.wikipedia.org/wiki/Community_film
# 1 Collaborative innovation network https://en.wikipedia.org/wiki/Collaborative_innovation_network
# 1 Design thinking https://en.wikipedia.org/wiki/Design_thinking
# 1 Role-based collaboration https://en.wikipedia.org/wiki/Role-based_collaboration
# 1 Intranet portal https://en.wikipedia.org/wiki/Intranet_portal
# 1 Critical thinking https://en.wikipedia.org/wiki/Critical_thinking
# ...

# %%
input_text = " ".join([page['text'] for page in OM_Corpus if page['theme.id'] == 0])

# %%
tokenized = tokenizer.tokenize_words(input_text)
number_of_words = len(tokenized)
print(number_of_words)
# Out:
# 30073

# %%
sample_freq_dist = FreqDist(tokenized)

# %%
sample_freq_dist.most_common(20)
# Out:
# [('\n', 3787),
#  ('the', 1257),
#  ('and', 776),
#  ('of', 771),
#  ('a', 661),
#  ('to', 642),
#  ('in', 563),
#  ('"', 429),
#  ('is', 303),
#  ('as', 276),
#  ('for', 257),
#  ('that', 224),
#  ('or', 206),
#  ('by', 186),
#  ('with', 182),
#  ('on', 156),
#  ('are', 151),
#  ('3d', 142),
#  ('from', 129),
#  ('it', 119)]

# %%
# remove punctuation and stopwords
for stopword in STOP_WORDS:
    if stopword in sample_freq_dist:
        del sample_freq_dist[stopword]
        
for punctuation in tokenizer.CHARACTERS_TO_SPLIT:
    if punctuation in sample_freq_dist:
        del sample_freq_dist[punctuation]

# %%
sample_freq_dist.most_common(20)
# Out:
# [('3d', 142),
#  ('printing', 94),
#  ('design', 75),
#  ('used', 72),
#  ('open', 65),
#  ('also', 63),
#  ('one', 58),
#  ('new', 56),
#  ('many', 55),
#  ('kludge', 55),
#  ('term', 53),
#  ('diy', 52),
#  ('may', 52),
#  ('manufacturing', 51),
#  ('use', 50),
#  ('project', 49),
#  ('bricolage', 46),
#  ('often', 45),
#  ('work', 45),
#  ('hackerspaces', 44)]

# %%
print(sample_freq_dist)
sample_freq_dist
# Out:
# <FreqDist with 5820 samples and 16400 outcomes>
# FreqDist({'uses': 23,
#           'see': 29,
#           'disambiguation': 5,
#           'diy': 52,
#           'redirects': 3,
#           'article': 21,
#           'multiple': 13,
#           'issues': 10,
#           'please': 9,
#           'help': 20,
#           'improve': 15,
#           'discuss': 4,
#           'talk': 1,
#           'page': 2,
#           'learn': 14,
#           'remove': 11,
#           'template': 10,
#           'messages': 1,
#           'possibly': 4,
#           'contains': 3,
#           'original': 11,
#           'research': 17,
#           'verifying': 2,
#           'claims': 5,
#           'made': 19,
#           'adding': 11,
#           'inline': 2,
#           'citations': 7,
#           'statements': 2,
#           'consisting': 3,
#           'removed': 8,
#           'november': 3,
#           'message': 10,
#           'needs': 8,
#           'additional': 5,
#           'better': 6,
# ...

# %%
# load english words from 
english_freq_dist = FreqDist([w.lower() for w in nltk.corpus.brown.words()
                              if w not in STOP_WORDS])

# remove rare words and get total count
english_freq_dist = {k:v for k,v in english_freq_dist.items() if v > 2}
n_english = sum(english_freq_dist.values())

# remove rare words from sample distribution
sample_freq_dist = {k:v for k,v in sample_freq_dist.items() if v > 2}
n_sample = sum(sample_freq_dist.values())

# %%
print(n_english, n_sample)
# Out:
# 687120 11136

# %%
for k,v in sample_freq_dist.items(): print(k,v)
# Out:
# uses 23
# see 29
# disambiguation 5
# diy 52
# redirects 3
# article 21
# multiple 13
# issues 10
# please 9
# help 20
# improve 15
# discuss 4
# learn 14
# remove 11
# template 10
# possibly 4
# contains 3
# original 11
# research 17
# claims 5
# made 19
# adding 11
# citations 7
# consisting 3
# removed 8
# november 3
# message 10
# needs 8
# additional 5
# better 6
# verification 3
# reliable 3
# sources 12
# unsourced 3
# material 27
# may 52
# challenged 3
# part 23
# series 11
# individualism 4
# topics 4
# free 29
# love 6
# human 12
# rights 8
# individual 13
# liberty 4
# negative 3
# personal 7
# property 12
# positive 4
# private 4
# karl 3
# john 5
# h 3
# l 8
# michel 3
# de 4
# murray 3
# david 4
# warren 3
# anarchism 11
# individualist 5
# feminism 3
# market 14
# libertarianism 3
# libertarian 3
# socialism 3
# right 3
# social 29
# group 9
# mass 12
# society 4
# engineering 11
# majority 3
# v 7
# t 5
# e 21
# boy 3
# building 22
# model 19
# security 3
# ...

# %%
for w in sample_freq_dist.keys() & english_freq_dist.keys(): print(w)
# Out:
# active
# jobs
# critical
# voice
# class
# restricted
# remove
# producing
# whole
# brain
# older
# multiple
# origins
# machines
# single
# skills
# third
# complexity
# bent
# component
# provide
# clear
# thin
# electrical
# resources
# custom
# extension
# located
# released
# half
# apply
# drywall
# help
# china
# pool
# fashion
# australian
# sharing
# income
# compared
# languages
# films
# greater
# time
# school
# press
# repairs
# makers
# learning
# message
# chinese
# pieces
# discusses
# successful
# developed
# might
# will
# another
# claimed
# paper
# original
# category
# called
# fix
# completed
# cost
# computers
# motivations
# carpentry
# d
# suggested
# properties
# dutch
# liquid
# population
# followed
# widely
# final
# simultaneously
# contemporary
# invented
# make
# item
# wide
# previously
# budget
# individual
# human
# call
# thereafter
# small
# content
# book
# created
# wires
# method
# days
# library
# included
# cutting
# light
# code
# maintain
# ...

# %%
sample_specifics = dict()
for w in sample_freq_dist.keys() - english_freq_dist.keys():
    sample_specifics[w] = sample_freq_dist[w]
    print(w)
# Out:
# audio
# granholm's
# admiral
# lvi-strauss
# printers
# autodesk
# hackerspaces
# trash
# unsourced
# citations
# cf
# hackers
# sws
# dr
# customized
# commons-based
# atm
# toffler's
# edupunk
# shaji
# commercialized
# cad
# hobbyists
# printable
# precursors
# techshop
# etc
# kluhj
# wiring
# workaround
# internet
# patio
# capacitors
# friesen
# sintering
# instructables
# hackspace
# klug
# homebrewing
# atari
# contractors
# kludge
# websites
# spence
# innovators
# community-operated
# sudev
# michel
# module
# extrusion
# filament
# ip
# oman's
# participatory
# 2010s
# kluge
# remodeling
# moulding
# technologies
# laser
# open-design
# slang
# website
# kludges
# c-span
# thingiverse
# open-source
# faire
# labs
# console
# redirects
# skylab
# murgatroyd
# marxism
# reprap
# feeder
# mainstream
# oman
# networking
# salalah
# tmrc
# polymer
# kit
# forums
# makerspace
# camcorders
# metalworking
# stl
# online
# repairing
# etymology
# stereolithography
# fab
# hridith
# ...

# %%
print(len(sample_specifics))
# Out:
# 203

# %%
from nltk.stem.porter import PorterStemmer
stemmer = PorterStemmer()
for k,v in sample_specifics.items():
    print(k,v)
    print(stemmer.stem(k))
# Out:
# audio 4
# audio
# granholm's 5
# granholm'
# admiral 4
# admir
# lvi-strauss 4
# lvi-strauss
# printers 27
# printer
# autodesk 3
# autodesk
# hackerspaces 44
# hackerspac
# trash 3
# trash
# unsourced 3
# unsourc
# citations 7
# citat
# cf 4
# cf
# hackers 7
# hacker
# sws 3
# sw
# dr 3
# dr
# customized 4
# custom
# commons-based 5
# commons-bas
# atm 4
# atm
# toffler's 3
# toffler'
# edupunk 21
# edupunk
# shaji 4
# shaji
# commercialized 3
# commerci
# cad 9
# cad
# hobbyists 4
# hobbyist
# printable 5
# printabl
# precursors 3
# precursor
# techshop 4
# techshop
# etc 8
# etc
# kluhj 3
# kluhj
# wiring 3
# wire
# workaround 4
# workaround
# internet 19
# internet
# patio 3
# patio
# capacitors 4
# capacitor
# friesen 3
# friesen
# sintering 8
# sinter
# instructables 18
# instruct
# hackspace 4
# hackspac
# klug 3
# klug
# homebrewing 3
# homebrew
# atari 3
# atari
# contractors 4
# contractor
# kludge 55
# kludg
# websites 10
# websit
# spence 4
# spenc
# innovators 3
# innov
# ...

# %%
# combine
makerness = {}
for w in sample_freq_dist.keys() & english_freq_dist.keys():
    if len(w) > 2:
        makerness[w] = log( (sample_freq_dist[w] / n_sample) / (english_freq_dist[w] / n_english))

# %%
for k,v in sorted(makerness.items(), key=lambda x:x[1], reverse=True): print(k,v)
# Out:
# additive 6.39100938718427
# printer 6.019445830751787
# printing 5.775248870239745
# digital 5.549442201506051
# franchise 5.285476655671586
# users 5.220938134534015
# global 5.220938134534015
# citation 5.151945263047064
# bending 5.120854675977033
# deposition 4.969623706253109
# do-it-yourself 4.9107832062301755
# manufacturing 4.876097648242285
# computers 4.815473026425851
# jargon 4.815473026425851
# evolutionary 4.815473026425851
# homeowners 4.815473026425851
# non-profit 4.815473026425851
# junk 4.815473026425851
# template 4.815473026425851
# hardware 4.815473026425851
# layer 4.772913412007055
# fabrication 4.75093450528828
# bug 4.681941633801328
# zealand 4.633151469631896
# hack 4.633151469631896
# lab 4.633151469631896
# coined 4.633151469631896
# individualist 4.633151469631896
# portal 4.633151469631896
# computer 4.601898926127792
# media 4.601898926127792
# commons 4.52779095397407
# consumers 4.4900506259912225
# maker 4.470632540134122
# ...

# %%
with open('makerness.csv', 'w') as csvfile:
    thewriter = csv.writer(csvfile, delimiter=',')
    for k,v in sorted(makerness.items(), key=lambda x:x[1], reverse=True):
        thewriter.writerow([k,v])
