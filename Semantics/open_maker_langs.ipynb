# %% [markdown]
# # Discovery and Representation of Open Making Related Terms

# %% [markdown]
# This notebook sketches the initial exercise on discovering the open making related keywords. The input text is harvested via a Web crawler that identifies and crawls semantically related wikipedia articles.

# %%
from utils import tokenizer
import nltk
from nltk import FreqDist
from math import log
import json, csv

# %% [markdown]
# ## 1. Loading a reference English language corpus

# %%
from nltk.corpus import brown
brown.categories()
# Out:
# ['adventure',
#  'belles_lettres',
#  'editorial',
#  'fiction',
#  'government',
#  'hobbies',
#  'humor',
#  'learned',
#  'lore',
#  'mystery',
#  'news',
#  'religion',
#  'reviews',
#  'romance',
#  'science_fiction']

# %% [markdown]
# ## 2. Stop words

# %% [markdown]
# ### 2.1 Standard stop words

# %%
with open("data/stopwords_standard.txt", "r") as f:
    STOP_WORDS_STANDARD = set(f.read().strip().split("\n"))
print(STOP_WORDS_STANDARD)
# Out:
# {"you're", 'own', 'not', 'just', 'down', 'those', 'about', "we've", 'has', "aren't", 'r', 'under', 'other', 'get', 'they', "couldn't", 'doing', "he'll", "we're", 'themselves', 'through', 'ours ', 'himself', 'had', "they've", 'any', 'like', 'between', 'on', 'a', 'cannot', "i'm", 'how', 'when', 'further', 'then', 'if', "didn't", 'his', "she'd", "they'll", 'while', 'him', 'your', 'we', 'be', 'should', 'have', 'he', 'could', "don't", 'or', 'would', 'were', 'very', 'www', 'until', "you'd", 'to', 'having', 'why', "who's", 'into', 'our', 'each', 'all', 'again', 'com', 'where', 'am', 'ourselves', 'itself', 'do', 'there', 'most', "won't", "weren't", 'and', 'it', 'so', 'below', 'more', 'than', 'yours', "doesn't", 'out', 'who', 'up', 'too', 'does', "he's", "he'd", "isn't", 'hers', 'an', 'such', "there's", 'only', 'me', 'for', "i've", 'off', "she's", "we'd", "i'd", "where's", 'my', 'can', "can't", 'some', 'did', 'above', 'both', "how's", "hadn't", 'over', "that's", 'being', 'know', 'as', 'http', 'whom', 'yourself', 'by', "what's", "i'll", "mustn't", 'herself', "wouldn't", 'nor', "shan't", 'she', "you'll", 'her', 'with', 'at', "haven't", 'here', 'same', 'its', 'you', "when's", 'are', 'few', 'is', "it's", "here's", 'them', "why's", 'before', 'was', "they're", 'what', "wasn't", "we'll", 'which', 'but', 'been', 'from', 'i', "let's", 'yourselves', 'this', "they'd", 'of', "you've", 'their', 'theirs', 'during', 'in', 'ought', 'after', 'myself', 'once', 'no', 'because', "she'll", 'that', "hasn't", 'these', "shouldn't", 'the'}

# %% [markdown]
# ### 2.2 Open-making related stop words

# %%
with open("data/stopwords_openmaker.txt", "r") as f:
    STOP_WORDS_OPENMAKER = set(f.read().strip().split("\n"))
print(STOP_WORDS_OPENMAKER)
# Out:
# {'may', 'almost', 'often', 'one', 'well', 'many', 'also'}

# %% [markdown]
# ## 3. Removing stop words from the reference English corpus

# %%
# merging the two list together
STOP_WORDS = STOP_WORDS_STANDARD.union(STOP_WORDS_OPENMAKER)
print(STOP_WORDS)
# Out:
# {'just', 'down', 'those', 'about', 'has', 'under', 'they', 'doing', "he'll", 'ours ', 'himself', "they've", 'like', 'between', 'a', "i'm", 'when', 'then', 'if', "didn't", "she'd", "they'll", 'while', 'him', 'we', 'should', 'have', 'he', "don't", 'or', 'were', 'very', 'until', 'why', "who's", 'into', 'each', 'again', 'well', 'ourselves', 'do', 'and', 'it', 'below', "doesn't", 'out', 'who', 'up', 'too', 'does', "he's", "there's", 'only', 'me', 'for', "i've", "she's", "we'd", "i'd", "can't", 'did', 'above', "how's", "that's", "hadn't", 'as', 'yourself', "what's", 'herself', 'many', 'nor', "shan't", 'she', "you'll", 'with', "haven't", 'same', 'here', 'you', 'are', 'them', 'before', "we'll", 'which', 'but', 'i', "let's", 'yourselves', "you've", 'their', 'during', 'myself', 'no', 'because', "she'll", 'that', 'these', "shouldn't", "you're", 'own', 'not', "we've", 'r', "aren't", 'other', 'get', "couldn't", "we're", 'themselves', 'through', 'had', 'any', 'on', 'cannot', 'how', 'further', 'his', 'your', 'be', 'could', 'would', 'www', "you'd", 'to', 'having', 'our', 'all', 'where', 'com', 'am', 'itself', 'there', 'most', "won't", "weren't", 'so', 'often', 'yours', 'more', 'than', 'almost', "he'd", "isn't", 'hers', 'an', 'such', 'off', "where's", 'my', 'can', 'some', 'both', 'over', 'also', 'being', 'know', 'http', 'whom', 'may', 'by', "i'll", "mustn't", "wouldn't", 'her', 'at', 'its', "when's", 'few', 'one', 'is', "it's", "here's", "why's", 'was', "they're", 'what', "wasn't", 'been', 'from', 'this', "they'd", 'of', 'theirs', 'in', 'ought', 'after', 'once', "hasn't", 'the'}

# %%
# load english words from the Brown corpus removing stop words.
english_freq_dist = FreqDist([w.lower() for w in nltk.corpus.brown.words()
                              if w not in STOP_WORDS])

# %% [markdown]
# ## 4. Removing the rare words.

# %% [markdown]
# Below we remove rare words and get total count. The code below keeps all words with a occurance frequency above 2.

# %%
english_freq_dist = {k:v for k,v in english_freq_dist.items() if v > 2}

# %% [markdown]
# ## 5. Loading the input Open Maker corpus

# %%
# load the harvested text from wikipedia.
with open("data/wikipedia.json", "r") as f: OM_Corpus_text = f.read()
OM_Corpus = json.loads(OM_Corpus_text)

# %%
# The total number of wiki articles used:
print(len(OM_Corpus))
# Out:
# 152

# %%
# Column names of the the corpus.
OM_Corpus[0].keys()
# Out:
# dict_keys(['theme.id', 'title', 'url', 'depth', 'text'])

# %%
def display_pages(tid):
    meme = [page for page in OM_Corpus if page['theme.id'] == tid]
    for m in meme:
        print(m['depth'],m['title'], m['url'])

# %%
display_pages(0)
# Out:
# 0 Do it yourself https://en.wikipedia.org/wiki/Do_it_yourself
# 1 Edupunk https://en.wikipedia.org/wiki/Edupunk
# 1 Prosumer https://en.wikipedia.org/wiki/Prosumer
# 1 How-to https://en.wikipedia.org/wiki/How-to
# 1 Kludge https://en.wikipedia.org/wiki/Kludge
# 1 Bricolage https://en.wikipedia.org/wiki/Bricolage
# 1 Junk box https://en.wikipedia.org/wiki/Junk_box
# 1 Number 8 wire https://en.wikipedia.org/wiki/Number_8_wire
# 1 Community film https://en.wikipedia.org/wiki/Community_film
# 1 Collaborative innovation network https://en.wikipedia.org/wiki/Collaborative_innovation_network
# 1 Design thinking https://en.wikipedia.org/wiki/Design_thinking
# 1 Role-based collaboration https://en.wikipedia.org/wiki/Role-based_collaboration
# 1 Intranet portal https://en.wikipedia.org/wiki/Intranet_portal
# 1 Critical thinking https://en.wikipedia.org/wiki/Critical_thinking
# 1 Facilitation (business) https://en.wikipedia.org/wiki/Facilitation_(business)
# 1 Collaborative software https://en.wikipedia.org/wiki/Collaborative_software
# 1 Postpartisan https://en.wikipedia.org/wiki/Postpartisan
# 1 Collaborative search engine https://en.wikipedia.org/wiki/Collaborative_search_engine
# 1 Crowdsourcing https://en.wikipedia.org/wiki/Crowdsourcing
# 1 Conference call https://en.wikipedia.org/wiki/Conference_call
# 1 Collaborative leadership https://en.wikipedia.org/wiki/Collaborative_leadership
# 1 Learning circle https://en.wikipedia.org/wiki/Learning_circle
# 1 Unorganisation https://en.wikipedia.org/wiki/Unorganisation
# 1 Digital collaboration https://en.wikipedia.org/wiki/Digital_Collaboration
# 1 Collaborative translation https://en.wikipedia.org/wiki/Collaborative_translation
# 1 Classical music written in collaboration https://en.wikipedia.org/wiki/Classical_music_written_in_collaboration

# %% [markdown]
# ## 6. Analyzing a specific corpus based on a theme

# %%
# Note that theme.id: 0 corresponds to the the Do IT YOURSELF
input_text = " ".join([page['text'] for page in OM_Corpus if page['theme.id'] == 0])

# %%
# Tokenizing the input text:
tokenized = tokenizer.tokenize_words(input_text)
number_of_words = len(tokenized)
print(number_of_words),OM_Corpus[0]['title']
# Out:
# 30073
# (None, 'Do it yourself')

# %% [markdown]
# ### 6.1 Computing frequency distributions of each token, i.e word, term, pancuation, etc.

# %%
input_freq_dist = FreqDist(tokenized)

# %%
input_freq_dist.most_common(20)
# Out:
# [('\n', 3787),
#  ('the', 1257),
#  ('and', 776),
#  ('of', 771),
#  ('a', 661),
#  ('to', 642),
#  ('in', 563),
#  ('"', 429),
#  ('is', 303),
#  ('as', 276),
#  ('for', 257),
#  ('that', 224),
#  ('or', 206),
#  ('by', 186),
#  ('with', 182),
#  ('on', 156),
#  ('are', 151),
#  ('3d', 142),
#  ('from', 129),
#  ('it', 119)]

# %% [markdown]
# ### 6.2 Removing punctuation and stopwords from the input corpus

# %%
for stopword in STOP_WORDS:
    if stopword in input_freq_dist:
        del input_freq_dist[stopword]
        
for punctuation in tokenizer.CHARACTERS_TO_SPLIT:
    if punctuation in input_freq_dist:
        del input_freq_dist[punctuation]

# Re-control most common words after cleaning:
input_freq_dist.most_common(80)
# Out:
# [('3d', 142),
#  ('printing', 94),
#  ('design', 75),
#  ('used', 72),
#  ('open', 65),
#  ('new', 56),
#  ('kludge', 55),
#  ('term', 53),
#  ('diy', 52),
#  ('manufacturing', 51),
#  ('use', 50),
#  ('project', 49),
#  ('bricolage', 46),
#  ('work', 45),
#  ('hackerspaces', 44),
#  ('handyman', 43),
#  ('projects', 38),
#  ('using', 38),
#  ('parts', 37),
#  ('music', 35),
#  ('furniture', 34),
#  ('people', 33),
#  ('production', 33),
#  ('software', 33),
#  ('kluge', 33),
#  ('technology', 32),
#  ('home', 31),
#  ('circuit', 31),
#  ('common', 30),
#  ('make', 30),
#  ('first', 30),
#  ('see', 29),
#  ('free', 29),
#  ('social', 29),
#  ('culture', 29),
#  ('process', 29),
#  ('additive', 29),
#  ('material', 27),
#  ('example', 27),
#  ('world', 27),
#  ('printers', 27),
#  ('electronic', 26),
#  ('materials', 25),
#  ('hackerspace', 25),
#  ('prosumer', 25),
#  ('digital', 25),
#  ('processes', 24),
#  ('printed', 24),
#  ('repair', 24),
#  ('metal', 24),
#  ('uses', 23),
#  ('part', 23),
#  ('time', 23),
#  ('include', 23),
#  ('products', 23),
#  ('layer', 23),
#  ('building', 22),
#  ('movement', 22),
#  ('way', 22),
#  ('around', 22),
#  ('hardware', 22),
#  ('will', 22),
#  ('source', 22),
#  ('article', 21),
#  ('e', 21),
#  ('community', 21),
#  ('consumer', 21),
#  ('components', 21),
#  ('tools', 21),
#  ('equipment', 21),
#  ('needed', 21),
#  ('media', 21),
#  ('edupunk', 21),
#  ('less', 21),
#  ('company', 21),
#  ('knowledge', 21),
#  ('computer', 21),
#  ('handymen', 21),
#  ('help', 20),
#  ('education', 20)]

# %% [markdown]
# ### 6.3 Removing rare words from input distribution

# %%
input_freq_dist = {k:v for k,v in input_freq_dist.items() if v > 1}

# %% [markdown]
# ## 7. Comparing input vs English corpus volumes

# %% [markdown]
# ### 7.1 Total words (after cleaning)

# %%
n_input = sum(input_freq_dist.values())
n_english = sum(english_freq_dist.values())
n_input, n_english
# Out:
# (12668, 679519)

# %% [markdown]
# ### 7.2 Unique words (after cleaning)

# %%
n_unique_word_input = len(input_freq_dist.items())
n_unique_word_brown = len(english_freq_dist.items())
n_unique_word_input, n_unique_word_brown
# Out:
# (2381, 20591)

# %% [markdown]
# ### 7.3 Cleaned set of input words/terms

# %% [markdown]
# List of words in the corpus in case, for a visual inspection. Such inspections will be used both to improve tokenization as well as filtering.

# %%
input_freq_dist
# Out:
# {'uses': 23,
#  'see': 29,
#  'disambiguation': 5,
#  'diy': 52,
#  'redirects': 3,
#  'article': 21,
#  'multiple': 13,
#  'issues': 10,
#  'please': 9,
#  'help': 20,
#  'improve': 15,
#  'discuss': 4,
#  'page': 2,
#  'learn': 14,
#  'remove': 11,
#  'template': 10,
#  'possibly': 4,
#  'contains': 3,
#  'original': 11,
#  'research': 17,
#  'verifying': 2,
#  'claims': 5,
#  'made': 19,
#  'adding': 11,
#  'inline': 2,
#  'citations': 7,
#  'statements': 2,
#  'consisting': 3,
#  'removed': 8,
#  'november': 3,
#  'message': 10,
#  'needs': 8,
#  'additional': 5,
#  'better': 6,
#  'verification': 3,
#  'reliable': 3,
#  'sources': 12,
#  'unsourced': 3,
#  'material': 27,
#  'challenged': 3,
#  'september': 2,
#  'part': 23,
#  'series': 11,
#  'individualism': 4,
#  'topics': 4,
#  'concepts': 2,
#  'autonomy': 2,
#  'free': 29,
#  'love': 6,
#  'freethought': 2,
#  'human': 12,
#  'rights': 8,
#  'individual': 13,
#  'reclamation': 2,
#  'liberty': 4,
#  'negative': 3,
#  'personal': 7,
#  'property': 12,
#  'positive': 4,
#  'private': 4,
#  'self-ownership': 2,
#  'mile': 2,
#  'armand': 2,
#  'albert': 2,
#  'william': 2,
#  'godwin': 2,
#  'emma': 2,
#  'goldman': 2,
#  'friedrich': 2,
#  'karl': 3,
#  'john': 5,
#  'h': 3,
#  'l': 8,
#  'michel': 3,
#  'de': 4,
#  'robert': 2,
#  'murray': 3,
#  'rothbard': 2,
#  'arthur': 2,
#  'smith': 2,
#  'spencer': 2,
#  'lysander': 2,
#  'spooner': 2,
#  'max': 2,
#  'stirner': 2,
#  'henry': 2,
#  'david': 4,
#  'thoreau': 2,
#  'benjamin': 2,
#  'tucker': 2,
#  'james': 2,
#  'josiah': 2,
#  'warren': 3,
#  'anarchism': 11,
#  'anarcho-capitalism': 2,
#  'liberalism': 2,
#  'egoist': 2,
#  'individualist': 5,
#  'feminism': 3,
#  'left-wing': 2,
#  'market': 14,
#  'libertarianism': 3,
#  'libertarian': 3,
#  'socialism': 3,
#  'right': 3,
#  'social': 29,
#  'group': 9,
#  'mentality': 2,
#  'mass': 12,
#  'society': 4,
#  'engineering': 11,
#  'tyranny': 2,
#  'majority': 3,
#  'v': 7,
#  't': 5,
#  'e': 21,
#  'boy': 3,
#  'building': 22,
#  'model': 19,
#  'texas': 2,
#  'security': 3,
#  'administration': 4,
#  'method': 9,
#  'modifying': 3,
#  'repairing': 4,
#  'things': 13,
#  'without': 15,
#  'direct': 7,
#  'aid': 5,
#  'experts': 3,
#  'professionals': 4,
#  'academic': 4,
#  'describes': 6,
#  'individuals': 8,
#  'engage': 3,
#  'raw': 4,
#  'materials': 25,
#  'component': 4,
#  'parts': 37,
#  'produce': 13,
#  'transform': 2,
#  'including': 18,
#  'drawn': 2,
#  'natural': 2,
#  'environment': 9,
#  'g': 13,
#  'landscaping': 2,
#  'behavior': 2,
#  'various': 18,
#  'motivations': 3,
#  'previously': 6,
#  'categorized': 2,
#  'marketplace': 2,
#  'economic': 10,
#  'benefits': 5,
#  'lack': 6,
#  'product': 11,
#  'availability': 4,
#  'quality': 12,
#  'need': 11,
#  'customization': 8,
#  'identity': 2,
#  'empowerment': 3,
#  'community': 21,
#  'term': 53,
#  'do-it-yourself': 11,
#  'associated': 8,
#  'consumers': 13,
#  'since': 11,
#  'least': 7,
#  'primarily': 2,
#  'domain': 3,
#  'home': 31,
#  'improvement': 13,
#  'maintenance': 7,
#  'activities': 8,
#  'phrase': 4,
#  'come': 10,
#  'common': 30,
#  'usage': 12,
#  'standard': 10,
#  'english': 7,
#  '1950s': 3,
#  'reference': 5,
#  'emergence': 2,
#  'trend': 6,
#  'people': 33,
#  'small': 9,
#  'craft': 4,
#  'construction': 8,
#  'projects': 38,
#  'activity': 4,
#  'subsequently': 2,
#  'taken': 5,
#  'broader': 3,
#  'meaning': 17,
#  'covers': 4,
#  'wide': 10,
#  'range': 12,
#  'skill': 5,
#  'sets': 5,
#  'international': 15,
#  'alternative': 10,
#  'rock': 4,
#  'punk': 11,
#  'indie': 2,
#  'music': 35,
#  'scenes': 2,
#  'indymedia': 2,
#  'networks': 2,
#  'pirate': 2,
#  'radio': 10,
#  'zine': 2,
#  'context': 3,
#  'related': 12,
#  'arts': 11,
#  'crafts': 3,
#  'movement': 22,
#  'modern': 4,
#  'consumer': 21,
#  'culture': 29,
#  "'s": 7,
#  'relying': 2,
#  'others': 10,
#  'satisfy': 3,
#  'widely': 11,
#  'used': 72,
#  'military': 8,
#  'way': 22,
#  'teach': 2,
#  'types': 3,
#  'units': 2,
#  'take': 7,
#  'able': 5,
#  'preparation': 2,
#  'future': 7,
#  'fashion': 8,
#  'subculture': 4,
#  'groups': 10,
#  'publications': 4,
#  'bc': 3,
#  'greek': 2,
#  'structure': 7,
#  'southern': 3,
#  'italy': 2,
#  'came': 8,
#  'assembly': 6,
#  'instructions': 7,
#  'called': 13,
#  'ikea': 2,
#  'city': 3,
#  'region': 3,
#  'local': 15,
#  'along': 6,
#  'known': 14,
#  'century': 7,
#  'professor': 2,
#  'director': 2,
#  'british': 6,
#  'school': 15,
#  'rome': 2,
#  'said': 11,
#  'example': 27,
#  'yet': 3,
#  'found': 9,
#  'marks': 2,
#  'time': 23,
#  'looks': 2,
#  'someone': 6,
#  'components': 21,
#  'put': 6,
#  'together': 13,
#  'much': 10,
#  'instruction': 2,
#  'sections': 2,
#  'showing': 3,
#  'pieces': 3,
#  'date': 4,
#  'back': 9,
#  'around': 22,
#  'architectural': 6,
#  'evidence': 2,
#  'suggested': 6,
#  'decoration': 2,
#  'built': 13,
#  'shelves': 2,
#  'toy': 3,
#  'vehicle': 2,
#  'old': 8,
#  'pattern': 3,
#  'use': 50,
#  'skills': 11,
#  'house': 8,
#  'making': 12,
#  'clothes': 2,
#  'cars': 2,
#  'computers': 10,
#  'websites': 10,
#  'living': 7,
#  'panel': 2,
#  'discussion': 4,
#  'edition': 2,
#  'san': 3,
#  'francisco': 3,
#  'reflected': 2,
#  'growing': 7,
#  'educational': 6,
#  'system': 18,
#  'nothing': 2,
#  'give': 7,
#  'us': 15,
#  'kind': 7,
#  'words': 6,
#  'make': 30,
#  'build': 18,
#  'houses': 2,
#  'fundamental': 2,
#  'life': 7,
#  'whole': 9,
#  'education': 20,
#  'children': 2,
#  'entirely': 6,
#  'terms': 12,
#  'insurance': 3,
#  'character': 3,
#  '1970s': 5,
#  'spread': 5,
#  'north': 8,
#  'american': 19,
#  'population': 3,
#  'age': 3,
#  'involved': 8,
#  'affordable': 3,
#  'older': 5,
#  'homes': 7,
#  'environmental': 6,
#  '1960s': 7,
#  'early': 16,
#  'young': 4,
#  'stewart': 2,
#  'brand': 3,
#  'working': 13,
#  'friends': 4,
#  'family': 3,
#  'initially': 2,
#  'using': 38,
#  'basic': 5,
#  'typesetting': 2,
#  'tools': 21,
#  'published': 5,
#  'first': 30,
#  'earth': 3,
#  'catalog': 4,
#  'access': 14,
#  'late': 6,
#  'fiberglass': 2,
#  'california': 5,
#  'style': 10,
#  'techniques': 18,
#  'broad': 2,
#  'definition': 6,
#  'informational': 3,
#  'books': 13,
#  'technical': 7,
#  'nature': 6,
#  'professional': 13,
#  'journals': 2,
#  'courses': 4,
#  'classes': 5,
#  'specialized': 3,
#  'designed': 7,
#  'items': 8,
#  "'": 2,
#  'welding': 4,
#  'equipment': 21,
#  'even': 15,
#  'designer': 2,
#  'j': 4,
#  'editor': 2,
#  'include': 23,
#  'writing': 5,
#  'reviews': 2,
#  's': 8,
#  'publication': 3,
#  'emerged': 4,
#  'spurred': 3,
#  'great': 10,
#  'wave': 5,
#  'attitude': 4,
#  'cross-section': 2,
#  'america': 2,
#  'influence': 8,
#  'decades': 4,
#  'magazines': 4,
#  'popular': 17,
#  'mechanics': 2,
#  'illustrated': 5,
#  'readers': 3,
#  'keep': 4,
#  'current': 9,
#  'useful': 3,
#  'practical': 3,
#  'began': 9,
#  'created': 14,
#  'collections': 2,
#  'magazine': 16,
#  'articles': 7,
#  'extensive': 6,
#  'line': 5,
#  'how-to': 16,
#  'sunset': 2,
#  'based': 14,
#  'upon': 4,
#  'publishers': 2,
#  'soon': 3,
#  'followed': 4,
#  'electronics': 16,
#  'world': 27,
#  'assembled': 4,
#  'amplifier': 5,
#  'mid-1990s': 4,
#  'home-improvement': 2,
#  'content': 9,
#  'find': 9,
#  'onto': 8,
#  'web': 5,
#  'earliest': 6,
#  'site': 10,
#  'users': 18,
#  'share': 9,
#  'information': 14,
#  'established': 8,
#  'among': 8,
#  'sites': 9,
#  'deliver': 3,
#  'authors': 4,
#  'citation': 14,
#  'needed': 21,
#  '1990s': 3,
#  'thousands': 2,
#  'video': 10,
#  'vcrs': 2,
#  'quickly': 7,
#  'potential': 9,
#  'processes': 24,
#  'means': 9,
#  'television': 18,
#  'starring': 2,
#  'bob': 2,
#  'revolution': 9,
#  'show': 8,
#  'conditions': 2,
#  'value': 7,
#  'paying': 2,
#  'work': 45,
#  'network': 14,
#  'cable': 4,
#  'channel': 3,
#  'launched': 7,
#  'united': 19,
#  'states': 15,
#  'canada': 3,
#  'interested': 2,
#  'knitting': 2,
#  'channels': 2,
#  "one's": 5,
#  'budget': 4,
#  'achieve': 2,
#  'results': 7,
#  'design': 75,
#  'etc': 8,
#  'specifically': 2,
#  'beyond': 4,
#  'scope': 7,
#  'continues': 4,
#  'grow': 3,
#  'online': 17,
#  'mainstream': 4,
#  'media': 21,
#  'now': 16,
#  'hometalk': 2,
#  'growth': 6,
#  'independent': 11,
#  'resources': 9,
#  'number': 15,
#  'homeowners': 6,
#  'blog': 2,
#  'experiences': 3,
#  'smaller': 3,
#  'organizations': 16,
#  'amongst': 2,
#  'ideas': 12,
#  'shared': 5,
#  'youtube': 2,
#  'clothing': 4,
#  'jewellery': 2,
#  'styles': 5,
#  'distressing': 4,
#  'jeans': 2,
#  'becoming': 2,
#  'main': 10,
#  'ethic': 4,
#  'maker': 17,
#  'describe': 8,
#  'zines': 5,
#  'london': 3,
#  'self-publishing': 2,
#  'comics': 2,
#  'bands': 6,
#  'artists': 3,
#  'record': 2,
#  'labels': 2,
#  'homemade': 2,
#  'principles': 7,
#  'recycle': 2,
#  'reuse': 2,
#  'reduce': 3,
#  'movements': 4,
#  'encouraging': 2,
#  'objects': 15,
#  'simple': 6,
#  'paper': 6,
#  'sewing': 3,
#  'designing': 4,
#  'business': 15,
#  'cards': 2,
#  'creating': 12,
#  'musical': 8,
#  'merchandise': 2,
#  'recycling': 2,
#  'thrift': 2,
#  'store': 4,
#  'usually': 10,
#  'art': 12,
#  'applied': 10,
#  'screen': 3,
#  'game': 9,
#  'development': 19,
#  'contemporary': 4,
#  'paid': 5,
#  'assistance': 2,
#  'electronic': 26,
#  'circuits': 4,
#  'atari': 3,
#  'console': 3,
#  'create': 19,
#  'circuit': 31,
#  'bending': 19,
#  'noise': 4,
#  'machines': 12,
#  'toys': 4,
#  'products': 23,
#  'allow': 6,
#  'extended': 2,
#  'unintended': 2,
#  'commonly': 8,
#  'referred': 7,
#  'internet': 19,
#  'mods': 2,
#  'littlebits': 2,
#  'science': 12,
#  'open-source': 19,
#  'hardware': 22,
#  'scientific': 3,
#  'simply': 4,
#  'low-cost': 5,
#  'traditional': 11,
#  'arduino': 4,
#  'embedded': 2,
#  'systems': 14,
#  'applications': 14,
#  'robot': 4,
#  'begun': 4,
#  'instead': 10,
#  'audiences': 2,
#  'large': 16,
#  'manufacturing': 51,
#  'wider': 6,
#  'recognition': 2,
#  'gain': 2,
#  'status': 5,
#  'took': 4,
#  'significantly': 3,
#  'musicians': 6,
#  'become': 15,
#  'became': 13,
#  'tutorial': 2,
#  'food': 12,
#  'section': 5,
#  'list': 14,
#  'format': 5,
#  'presented': 2,
#  'prose': 2,
#  'appropriate': 6,
#  'available': 18,
#  'faire': 3,
#  'focus': 7,
#  'andor': 4,
#  'crafting': 4,
#  'informal': 4,
#  'book': 17,
#  'name': 4,
#  'emphasizing': 3,
#  'focusing': 3,
#  'cheap': 2,
#  'anarchist': 6,
#  'collective': 4,
#  'destination': 2,
#  'discussing': 2,
#  'networking': 3,
#  'instructables': 18,
#  'website': 10,
#  'featuring': 2,
#  'tips': 2,
#  'array': 3,
#  'complex': 10,
#  'conferences': 3,
#  'events': 2,
#  'places': 6,
#  'sometimes': 19,
#  'sponsored': 2,
#  'publishing': 4,
#  'technology': 32,
#  'focused': 5,
#  'sustainable': 9,
#  'techshop': 4,
#  'chain': 3,
#  'workshops': 3,
#  'enabling': 3,
#  'levels': 3,
#  'industrial': 13,
#  'topic': 7,
#  'look': 4,
#  'wiktionary': 2,
#  'dictionary': 6,
#  'wikimedia': 2,
#  'commons': 6,
#  'bricolage': 46,
#  'edupunk': 21,
#  'hackerspace': 25,
#  'handyman': 43,
#  'junk': 16,
#  'box': 11,
#  'kludge': 55,
#  'wire': 17,
#  'open': 65,
#  'project': 49,
#  'greenoman': 11,
#  'prosumer': 25,
#  'ready-to-assemble': 9,
#  'furniture': 34,
#  '3d': 142,
#  'printing': 94,
#  'jim': 4,
#  'groom': 4,
#  'teaching': 3,
#  'learning': 12,
#  'practices': 2,
#  'kuntz': 2,
#  'described': 6,
#  'approach': 10,
#  'avoids': 2,
#  'aims': 5,
#  'bring': 4,
#  'classroom': 3,
#  'instructional': 2,
#  'covered': 3,
#  'less': 21,
#  'week': 3,
#  'later': 11,
#  'higher': 7,
#  'stephen': 3,
#  'downes': 3,
#  'journal': 2,
#  'distance': 2,
#  'noted': 5,
#  'concept': 19,
#  'wind': 2,
#  'spreading': 4,
#  'aspects': 8,
#  'examples': 9,
#  'notes': 6,
#  'efforts': 4,
#  'government': 3,
#  'corporate': 8,
#  'interests': 4,
#  'emerging': 4,
#  'technologies': 20,
#  'similar': 20,
#  'reaction': 3,
#  'though': 5,
#  'identified': 3,
#  'three': 4,
#  'against': 3,
#  'commercialization': 2,
#  'thinking': 3,
#  'university': 12,
#  'course': 3,
#  'wikipedia': 6,
#  'murder': 2,
#  'madness': 2,
#  'mayhem': 2,
#  'experiment': 2,
#  'ones': 3,
#  'students': 3,
#  'produced': 9,
#  'hirst': 2,
#  'uk': 2,
#  'june': 7,
#  'adopted': 4,
#  'outside': 6,
#  'set': 6,
#  'australian': 3,
#  'norm': 3,
#  'friesen': 3,
#  'identifies': 2,
#  'possible': 9,
#  'intellectual': 7,
#  'precursors': 3,
#  'hampshire': 2,
#  'college': 5,
#  'state': 2,
#  'new': 56,
#  'student': 2,
#  'voice': 3,
#  'critical': 7,
#  'b': 3,
#  'jargon': 8,
#  'green': 3,
#  'wired': 3,
#  'retrieved': 9,
#  'weblog': 2,
#  'bavatuesdays': 2,
#  '2008-05-28': 2,
#  'introducing': 2,
#  '2008-06-06': 2,
#  '2008-06-16': 2,
#  'virtual': 3,
#  'changing': 3,
#  'expectations': 2,
#  'heritage': 3,
#  'tv': 2,
#  '2009-02-23': 2,
#  'july': 5,
#  'written': 7,
#  'essay': 4,
#  'feelings': 2,
#  'encyclopedic': 2,
#  'april': 2,
#  'person': 6,
#  'produces': 2,
#  'derived': 3,
#  'prosumption': 11,
#  'era': 2,
#  'production': 33,
#  'coined': 5,
#  'futurist': 2,
#  'alvin': 2,
#  'toffler': 7,
#  'writers': 2,
#  'trade': 5,
#  'perspective': 5,
#  'high-end': 2,
#  'devices': 14,
#  'digital': 25,
#  'cameras': 4,
#  'price': 10,
#  'point': 6,
#  'definitions': 2,
#  'origins': 4,
#  'general': 10,
#  'meanings': 5,
#  'relationship': 7,
#  'producer': 8,
#  'non-corporate': 2,
#  'company': 21,
#  'impact': 9,
#  'reception': 2,
#  'adoption': 2,
#  "company's": 3,
#  'd': 12,
#  'blurring': 2,
#  'roles': 3,
#  'producers': 4,
#  'cooperative': 3,
#  'enthusiasts': 4,
#  'buy': 4,
#  'always': 2,
#  'fall': 4,
#  'grade': 2,
#  'standards': 4,
#  'complexity': 7,
#  'refers': 4,
#  'category': 5,
#  'camcorders': 3,
#  'advanced': 6,
#  'features': 9,
#  'increased': 3,
#  'customizing': 2,
#  "toffler's": 3,
#  'sense': 13,
#  'next': 3,
#  'marshall': 2,
#  'today': 7,
#  'electric': 5,
#  'third': 7,
#  'futurologist': 2,
#  'role': 6,
#  'begin': 2,
#  'merge': 2,
#  'shock': 2,
#  'highly': 5,
#  'demands': 2,
#  'continue': 2,
#  'profit': 2,
#  'businesses': 12,
#  'process': 29,
#  'customized': 4,
#  'however': 13,
#  'reach': 5,
#  'high': 8,
#  'especially': 12,
#  'requirements': 8,
#  'extension': 3,
#  'clients': 4,
#  'cases': 4,
#  'primary': 3,
#  "'prosumption": 2,
#  'architecture': 8,
#  'decentralization': 3,
#  'agency': 2,
#  "imperative'": 2,
#  'recently': 7,
#  'works': 11,
#  'wealth': 5,
#  'fact': 7,
#  'seen': 8,
#  'felt': 2,
#  'worldwide': 2,
#  'scale': 4,
#  'global': 12,
#  'particular': 8,
#  'china': 5,
#  'gingrich': 2,
#  'c-span': 3,
#  'program': 7,
#  'mentioned': 3,
#  'second': 5,
#  'behind': 2,
#  'don': 2,
#  'tapscott': 2,
#  'economy': 5,
#  'despite': 3,
#  'several': 11,
#  'full': 3,
#  'theoretical': 2,
#  'george': 2,
#  'claim': 3,
#  'characteristic': 4,
#  'prosumers': 3,
#  'companies': 11,
#  'wages': 2,
#  'place': 8,
#  'areas': 3,
#  'industry': 7,
#  'years': 8,
#  'choices': 2,
#  'stores': 3,
#  'ways': 5,
#  'sold': 2,
#  'names': 3,
#  'giving': 3,
#  'recorded': 5,
#  'fast': 4,
#  'indeed': 2,
#  'generally': 15,
#  'going': 2,
#  'effort': 5,
#  'myriad': 2,
#  'choice': 4,
#  'producing': 4,
#  'still': 10,
#  'key': 5,
#  'area': 11,
#  'taking': 3,
#  'hobbyists': 4,
#  "today's": 2,
#  'team': 2,
#  'field': 5,
#  'energy': 14,
#  'households': 2,
#  'times': 4,
#  'surplus': 3,
#  'fuel': 3,
#  'feed': 2,
#  'national': 13,
#  'distribution': 10,
#  'consume': 2,
#  'grid': 4,
#  'done': 10,
#  'panels': 2,
#  'generating': 3,
#  'electricity': 2,
#  'gas': 2,
#  'european': 7,
#  'innovation': 6,
#  'programme': 2,
#  'leisure': 2,
#  'pursuits': 3,
#  'initial': 6,
#  'combination': 2,
#  'pair': 2,
#  'hobbies': 3,
#  'rising': 2,
#  'level': 2,
#  'amateur': 7,
#  'interest': 4,
#  'rather': 17,
#  'profession': 2,
#  'serious': 3,
#  'rise': 2,
#  'cooking': 3,
#  'creation': 5,
#  'dedicated': 5,
#  'photography': 2,
#  'trends': 6,
#  'factors': 5,
#  'disposable': 2,
#  'sectors': 5,
#  'prices': 5,
#  'ever': 3,
#  'towards': 2,
#  'amateurs': 4,
#  'beginning': 10,
#  '1980s': 3,
#  'advent': 5,
#  'desktop': 6,
#  'forums': 3,
#  'pool': 4,
#  'experience': 7,
#  'considered': 4,
#  'fence': 2,
#  'lower': 3,
#  'form': 14,
#  'bells': 2,
#  'expanded': 2,
#  'philip': 3,
#  'kotler': 3,
#  'saw': 3,
#  'challenge': 2,
#  'anticipated': 2,
#  'will': 22,
#  'want': 2,
#  'play': 7,
#  'larger': 2,
#  'certain': 7,
#  'goods': 3,
#  'services': 12,
#  'furthermore': 2,
#  'forces': 2,
#  'lead': 6,
#  'developed': 16,
#  'szymusiak': 3,
#  'two': 14,
#  'marketing': 6,
#  'politics': 4,
#  'schools': 6,
#  'thought': 4,
#  'black': 3,
#  'feminist': 3,
#  'infoanarchism': 2,
#  'philosophical': 2,
#  'theory': 3,
#  'practice': 8,
#  'class': 4,
#  'struggle': 3,
#  'democracy': 3,
#  'deep': 2,
#  'ecology': 4,
#  'power': 7,
#  'association': 2,
#  'law': 3,
#  'mutual': 2,
#  'participatory': 3,
#  'autonomous': 2,
#  'zone': 2,
#  'center': 8,
#  'spontaneous': 3,
#  'order': 10,
#  'squatting': 2,
#  'temporary': 5,
#  'union': 4,
#  'm': 5,
#  'peter': 2,
#  'colin': 2,
#  'lifestylism': 2,
#  'marxism': 3,
#  'sex': 2,
#  'violence': 3,
#  'congress': 2,
#  ...}

# %% [markdown]
# ### 7.4 Set of terms/words that occure in both corpus.

# %%
common_words = [w for w in input_freq_dist.keys() & english_freq_dist.keys()]
print(len(common_words))
# Out:
# 1940

# %%
for w in common_words: print(w)
# Out:
# previously
# marks
# door
# discourse
# chains
# even
# office
# fundamental
# address
# patents
# radical
# candy
# carpentry
# swimming
# founding
# far
# course
# economy
# welcome
# firms
# whether
# politics
# fields
# drawn
# writing
# advanced
# covers
# against
# rig
# experimentation
# meets
# handy
# essentially
# pieces
# sponsored
# cutters
# serve
# inefficient
# business
# traditional
# code
# influence
# acquisition
# set
# scanning
# opened
# akin
# university
# fence
# mess
# '
# giving
# integrate
# notes
# trusting
# areas
# melting
# smaller
# essay
# possess
# military
# journals
# album
# yes
# matter
# wider
# molding
# bent
# primary
# reconstruction
# reporter
# nail
# simple
# wages
# august
# unpaid
# complete
# cause
# version
# photography
# teaching
# discussing
# assessment
# application
# contest
# significantly
# sheds
# process
# week
# asking
# branch
# powder
# thinking
# french
# jim
# name
# homeowners
# particle
# motors
# awareness
# fully
# europe
# platform
# change
# related
# materials
# sectors
# data
# file
# sophisticated
# quantities
# satisfy
# open
# myriad
# assembled
# ever
# paper
# useful
# emerged
# capabilities
# record
# jet
# real
# stewart
# s
# vary
# definitions
# object
# guarantee
# sense
# began
# exclusively
# personalized
# peer
# includes
# turn
# drives
# episode
# fees
# question
# security
# seriously
# educational
# store
# porch
# fuel
# maintenance
# danish
# solid
# creativity
# behavior
# ghana
# translation
# among
# task
# odd
# longer
# avoid
# criteria
# removed
# pool
# launched
# continues
# management
# techniques
# hours
# required
# damage
# comes
# policies
# though
# claim
# levels
# amplifier
# staff
# identical
# orbit
# especially
# arts
# limited
# appear
# fictional
# installing
# specialized
# evolved
# publishers
# computers
# section
# finishing
# took
# following
# identities
# library
# street
# saturn
# speaker
# provides
# chinese
# fed
# publication
# help
# installation
# check
# clever
# named
# results
# originally
# making
# source
# employed
# produce
# catalog
# locally
# shock
# shared
# hull
# find
# assemble
# evidence
# lee
# reasons
# administrative
# present
# switches
# array
# moving
# artistic
# environment
# lack
# mister
# forms
# canada
# particularly
# box
# summer
# artificial
# small
# enabled
# proper
# jury
# continued
# expansion
# surgery
# unique
# ireland
# aims
# march
# locations
# purposes
# value
# nights
# fix
# heads
# exception
# systems
# printing
# places
# country
# practices
# considered
# story
# described
# consequence
# read
# designed
# context
# keep
# another
# became
# weapons
# domain
# conditions
# rises
# e
# electron
# carnival
# wave
# distribution
# mentioned
# begun
# environmental
# published
# slowly
# sources
# conference
# hardware
# today's
# play
# someone
# larger
# common
# instructions
# crown
# types
# case
# instance
# advantage
# pattern
# please
# writes
# cooperative
# return
# bug
# standards
# necessary
# level
# theory
# several
# cheap
# possibly
# tile
# something
# international
# said
# crew
# advertising
# cleaning
# concept
# winner
# style
# away
# experts
# region
# local
# labor
# industries
# warren
# british
# capable
# greater
# extension
# authors
# post
# pioneers
# costs
# went
# greece
# worker
# kitchen
# come
# l
# paul
# love
# resistors
# usage
# classroom
# computing
# years
# mile
# c
# likely
# folklore
# initiative
# contains
# shelf
# household
# texas
# research
# invented
# home
# lower
# order
# free
# money
# commercial
# steel
# tend
# india
# fashion
# technician
# go
# stores
# experimental
# theme
# brother
# spencer
# turning
# craft
# creating
# type
# male
# humming
# controlled
# citizens
# biggest
# toys
# public
# history
# wrong
# culture
# law
# engine
# reduced
# america
# compared
# companies
# spell
# murray
# introduced
# keeping
# benefit
# rest
# always
# entirely
# concluded
# jersey
# spreading
# sections
# practical
# electrical
# teach
# files
# poland
# cases
# list
# plastic
# tech
# mentality
# widely
# nuts
# advantages
# instead
# improvement
# mutual
# awarded
# finish
# family
# think
# human
# german
# english
# world
# organizations
# learning
# manned
# life
# achieve
# minor
# wheel
# tips
# emma
# now
# manufacturers
# collection
# provide
# lead
# status
# character
# technology
# require
# great
# vehicle
# fledgling
# terminology
# benefits
# societies
# although
# rebuild
# estimate
# government
# continue
# thrift
# felt
# city
# museum
# due
# per
# men
# australia
# proposed

# %% [markdown]
# ### 7.5 Set of terms/words that occure in the sample but not in the reference corpus.

# %% [markdown]
# TO BE EXAMINED: This specific set needs to be incorporated. In fact, it may capture specifity of the content to a great extend. We need to assign a mapping score for each words in this set.

# %%
input_specifics = dict()
for w in input_freq_dist.keys() - english_freq_dist.keys():
    input_specifics[w] = input_freq_dist[w]
    print(w)
# Out:
# hacker
# how-tos
# wipers
# faire
# abs
# zines
# polymer
# emissions
# kludged
# hometalk
# uv
# atm
# disposable
# thoreau
# poorly-matching
# leone
# buyer
# labs
# blurring
# commons-based
# copyright
# hirst
# josiah
# prosumers'
# ac
# docking
# kotler
# kluhj
# sub-cultures
# collaborate
# nepal
# uganda
# libertarianism
# commercialization
# module
# software
# manifesto
# repairing
# home-improvement
# stereolithography
# globalization
# step-by-step
# skylab
# commentators
# machining
# handyman's
# workaround
# 1980s
# matrix
# internet
# klooj
# futurist
# high-tech
# matured
# xinchejian
# lvi-strauss
# infrastructure
# wiring
# vcrs
# sprinkler
# innovators
# futurologist
# armand
# consumer-oriented
# potentiometers
# hams
# friedrich
# starring
# wikipedia
# makerbot
# implemented
# weblog
# 1960s
# laser
# vernacular
# wiki-based
# genre
# beijing
# anarchism
# reuse
# cognitive
# landscaping
# options
# stylistic
# jeans
# greenoman
# fiberglass
# extrusion
# zine
# widgets
# jugaad
# homebrewers
# wiki
# synthesizers
# forums
# wiktionary
# academics
# hobbyists
# redirected
# console
# isbn
# pastiche
# day'
# verifying
# dhofar
# 2010s
# categorized
# c-base
# kluge
# top-down
# kincheloe
# phineas
# anarcho-capitalism
# adjective
# diy
# automated
# littlebits
# techshop
# clips
# encyclopedic
# mid-1990s
# rica
# 2008-06-06
# dr
# honours
# implants
# 2008-06-16
# camcorders
# laptop
# comics
# cleanup
# grid
# workspace
# contractors
# spence
# agile
# org
# bavatuesdays
# vatakara
# oman's
# networking
# mainstream
# shanghai
# prosumers
# feminist
# actuators
# downes
# sierra
# flatpack
# 's
# nigeria
# ikea
# c-span
# macgyver
# gel
# prosumer
# neuroscience
# 'prosumption
# sustainability
# kit
# handymen
# programme
# kerala
# reprap
# faq
# filament
# manufactures
# redirects
# madness
# infoanarchism
# bahrain
# anarchists
# complementing
# o'reilly
# feeder
# x-y
# inc
# marxism
# community-operated
# self-correcting
# welding
# rothbard
# printable
# hackers
# admiral
# self-ownership
# 2008-05-28
# word's
# egoist
# burling
# prototyping
# inkjet
# transistor
# klug
# gutter
# high-end
# clod
# branding
# anthropologist
# indymedia
# wikihow
# incorporating
# powertrain
# fab
# wikimedia
# bender
# open-design
# technologies
# ill-assorted
# labor-intensive
# tapscott
# informational
# customized
# squid
# audio
# inline
# wiggles
# ccc
# binder
# sustainable
# computer-aided
# fiona
# tinker
# 2009-02-23
# commercialized
# sintering
# autonomous
# goldman
# supercar
# szymusiak
# participatory
# affordable
# mayhem
# etymology
# fdm
# worldwide
# customization
# citations
# non-corporate
# knockdown
# etymologies
# advocates
# overview
# slang
# fix-up
# toffler
# crafting
# hackerspace
# tmrc
# recycling
# unsourced
# pronunciation
# homebrewing
# typesetting
# pgwi
# transforming
# reclamation
# overcomplicated
# woodworking
# costa
# municipality
# left-wing
# cad
# app
# samved
# prosumption
# gemini
# metalworking
# gingrich
# cnc
# how-to
# prgrom
# airbus
# datamation
# patio
# genetically
# lysander
# homeowner
# threeding
# basements
# collaborative
# capacitors
# self-publishing
# lifestylism
# inelegant
# greenindia
# michel
# update
# feminism
# retrieve
# spooner
# crock
# robot
# leaky
# sws
# subculture
# inventora
# overhanging
# fasteners
# modeling
# jeffrey
# toolroom
# open-source
# bolts
# andor
# for-profit
# 3d
# jewellery
# multilingual
# amf
# ecology
# g-code
# moulding
# precursors
# makerspaces
# edupunk
# acronym
# autodesk
# sudev
# timelapse
# kraakdoos
# foldoc
# openbook
# bricolage
# freethought
# decentralization
# displacing
# amateurs
# mid-1950s
# instructables
# recombine
# payers
# households
# punk
# mods
# brandtjen
# customizing
# targeted
# salalah
# consume
# kuntz
# medium-level
# manny
# actuator
# blog
# websites
# fabricated
# cf
# 1970s
# fix-it
# electrocution
# ii
# metalab
# tiling
# recycle
# bc
# oman
# desktop
# 1990s
# colin
# regimes
# subtractive
# rio20
# youtube
# unintended
# stl
# etc
# granholm's
# weick
# uk
# logo
# airlock
# photopolymer
# manipulating
# improvisation
# turkle
# stirner
# ready-to-assemble
# shaji
# empowerment
# handiwork
# hobbyist
# raumzeitlabor
# kludge
# friesen
# hackerspaces
# co-creation
# tinkering
# arduino
# mit
# knock-down
# disambiguation
# hackspace
# copyrightable
# 'kluge'
# pronunciations
# remodeling
# libertarian
# thingiverse
# photopolymerization
# bricoleur
# recycled
# ip
# pronounce
# tutorial
# hridith
# online
# toffler's
# makerspace
# anarcho-punk
# ceo
# knobs
# atari
# ghazala
# kludges
# granules
# knitting
# solidified
# funding
# greenworld
# imperative'
# website
# anarchist
# sanchez-burks
# copying
# end-users
# dpi
# geometrical
# taipei
# jetting
# kluges
# on-demand
# trash
# video
# printers
# indie
# professionalism
# granholm
# murgatroyd
# haphazard
# handyman

# %%
print(len(input_specifics))
# Out:
# 441

# %% [markdown]
# ## 8. Stemming (in case needed)

# %%
from nltk.stem.porter import PorterStemmer
stemmer = PorterStemmer()
for k,v in input_freq_dist.items():
    stemmed = stemmer.stem(k)
    if stemmed != k: print(k, "->", stemmed)
# Out:
# uses -> use
# disambiguation -> disambigu
# redirects -> redirect
# article -> articl
# multiple -> multipl
# issues -> issu
# please -> pleas
# improve -> improv
# remove -> remov
# template -> templat
# possibly -> possibl
# contains -> contain
# original -> origin
# verifying -> verifi
# claims -> claim
# adding -> ad
# inline -> inlin
# citations -> citat
# statements -> statement
# consisting -> consist
# removed -> remov
# november -> novemb
# message -> messag
# needs -> need
# additional -> addit
# verification -> verif
# reliable -> reliabl
# sources -> sourc
# unsourced -> unsourc
# material -> materi
# challenged -> challeng
# september -> septemb
# series -> seri
# individualism -> individu
# topics -> topic
# concepts -> concept
# autonomy -> autonomi
# rights -> right
# individual -> individu
# reclamation -> reclam
# liberty -> liberti
# negative -> neg
# personal -> person
# property -> properti
# positive -> posit
# private -> privat
# lysander -> lysand
# henry -> henri
# james -> jame
# anarchism -> anarch
# anarcho-capitalism -> anarcho-capit
# liberalism -> liber
# feminism -> femin
# left-wing -> left-w
# libertarianism -> libertarian
# socialism -> social
# mentality -> mental
# society -> societi
# engineering -> engin
# tyranny -> tyranni
# majority -> major
# building -> build
# texas -> texa
# security -> secur
# administration -> administr
# modifying -> modifi
# repairing -> repair
# things -> thing
# experts -> expert
# professionals -> profession
# academic -> academ
# describes -> describ
# individuals -> individu
# engage -> engag
# materials -> materi
# component -> compon
# parts -> part
# produce -> produc
# including -> includ
# natural -> natur
# environment -> environ
# landscaping -> landscap
# various -> variou
# motivations -> motiv
# previously -> previous
# categorized -> categor
# marketplace -> marketplac
# economic -> econom
# benefits -> benefit
# availability -> avail
# quality -> qualiti
# customization -> custom
# identity -> ident
# empowerment -> empower
# community -> commun
# associated -> associ
# consumers -> consum
# since -> sinc
# primarily -> primarili
# improvement -> improv
# maintenance -> mainten
# activities -> activ
# usage -> usag
# 1950s -> 1950
# reference -> refer
# emergence -> emerg
# people -> peopl
# construction -> construct
# projects -> project
# activity -> activ
# subsequently -> subsequ
# meaning -> mean
# covers -> cover
# range -> rang
# sets -> set
# international -> intern
# alternative -> altern
# indie -> indi
# scenes -> scene
# networks -> network
# pirate -> pirat
# related -> relat
# arts -> art
# crafts -> craft
# consumer -> consum
# culture -> cultur
# relying -> reli
# others -> other
# satisfy -> satisfi
# widely -> wide
# used -> use
# military -> militari
# types -> type
# units -> unit
# able -> abl
# preparation -> prepar
# future -> futur
# subculture -> subcultur
# groups -> group
# publications -> public
# structure -> structur
# italy -> itali
# assembly -> assembl
# instructions -> instruct
# called -> call
# city -> citi
# century -> centuri
# example -> exampl
# marks -> mark
# looks -> look
# someone -> someon
# components -> compon
# together -> togeth
# instruction -> instruct
# sections -> section
# showing -> show
# pieces -> piec
# architectural -> architectur
# evidence -> evid
# suggested -> suggest
# decoration -> decor
# shelves -> shelv
# vehicle -> vehicl
# skills -> skill
# house -> hous
# making -> make
# clothes -> cloth
# cars -> car
# computers -> comput
# websites -> websit
# living -> live
# discussion -> discuss
# edition -> edit
# reflected -> reflect
# growing -> grow
# educational -> educ
# nothing -> noth
# words -> word
# houses -> hous
# fundamental -> fundament
# education -> educ
# entirely -> entir
# terms -> term
# insurance -> insur
# character -> charact
# 1970s -> 1970
# population -> popul
# involved -> involv
# affordable -> afford
# homes -> home
# environmental -> environment
# 1960s -> 1960
# early -> earli
# working -> work
# friends -> friend
# family -> famili
# initially -> initi
# using -> use
# typesetting -> typeset
# tools -> tool
# published -> publish
# techniques -> techniqu
# definition -> definit
# informational -> inform
# books -> book
# technical -> technic
# nature -> natur
# professional -> profession
# journals -> journal
# courses -> cours
# classes -> class
# specialized -> special
# designed -> design
# items -> item
# welding -> weld
# equipment -> equip
# designer -> design
# include -> includ
# writing -> write
# reviews -> review
# publication -> public
# emerged -> emerg
# spurred -> spur
# attitude -> attitud
# cross-section -> cross-sect
# influence -> influenc
# decades -> decad
# magazines -> magazin
# mechanics -> mechan
# illustrated -> illustr
# readers -> reader
# useful -> use
# practical -> practic
# created -> creat
# collections -> collect
# magazine -> magazin
# articles -> articl
# extensive -> extens
# based -> base
# publishers -> publish
# followed -> follow
# electronics -> electron
# assembled -> assembl
# amplifier -> amplifi
# mid-1990s -> mid-1990
# home-improvement -> home-improv
# users -> user
# information -> inform
# established -> establish
# sites -> site
# deliver -> deliv
# authors -> author
# citation -> citat
# needed -> need
# 1990s -> 1990
# thousands -> thousand
# vcrs -> vcr
# quickly -> quickli
# potential -> potenti
# processes -> process
# means -> mean
# television -> televis
# starring -> star
# revolution -> revolut
# conditions -> condit
# value -> valu
# paying -> pay
# cable -> cabl
# launched -> launch
# united -> unit
# states -> state
# interested -> interest
# knitting -> knit
# channels -> channel
# one's -> one'
# achieve -> achiev
# results -> result
# specifically -> specif
# continues -> continu
# online -> onlin
# independent -> independ
# resources -> resourc
# homeowners -> homeown
# experiences -> experi
# organizations -> organ
# ideas -> idea
# shared -> share
# youtube -> youtub
# clothing -> cloth
# jewellery -> jewelleri
# styles -> style
# distressing -> distress
# jeans -> jean
# becoming -> becom
# describe -> describ
# zines -> zine
# self-publishing -> self-publish
# comics -> comic
# bands -> band
# artists -> artist
# labels -> label
# homemade -> homemad
# principles -> principl
# recycle -> recycl
# reuse -> reus
# reduce -> reduc
# movements -> movement
# encouraging -> encourag
# objects -> object
# simple -> simpl
# sewing -> sew
# designing -> design
# business -> busi
# cards -> card
# creating -> creat
# musical -> music
# merchandise -> merchandis
# recycling -> recycl
# usually -> usual
# applied -> appli
# development -> develop
# contemporary -> contemporari
# assistance -> assist
# electronic -> electron
# circuits -> circuit
# console -> consol
# create -> creat
# bending -> bend
# noise -> nois
# machines -> machin
# toys -> toy
# products -> product
# extended -> extend
# unintended -> unintend
# commonly -> commonli
# referred -> refer
# mods -> mod
# littlebits -> littlebit
# science -> scienc
# open-source -> open-sourc
# hardware -> hardwar
# scientific -> scientif
# simply -> simpli
# traditional -> tradit
# embedded -> embed
# systems -> system
# applications -> applic
# audiences -> audienc
# large -> larg
# manufacturing -> manufactur
# recognition -> recognit
# status -> statu
# significantly -> significantli
# musicians -> musician
# become -> becom
# became -> becam
# tutorial -> tutori
# presented -> present
# appropriate -> appropri
# available -> avail
# faire -> fair
# focus -> focu
# crafting -> craft
# informal -> inform
# emphasizing -> emphas
# focusing -> focus
# collective -> collect
# destination -> destin
# discussing -> discuss
# networking -> network
# instructables -> instruct
# website -> websit
# featuring -> featur
# tips -> tip
# conferences -> confer
# events -> event
# places -> place
# sometimes -> sometim
# sponsored -> sponsor
# publishing -> publish
# technology -> technolog
# focused -> focus
# sustainable -> sustain
# workshops -> workshop
# enabling -> enabl
# levels -> level
# industrial -> industri
# wiktionary -> wiktionari
# dictionary -> dictionari
# commons -> common
# bricolage -> bricolag
# hackerspace -> hackerspac
# kludge -> kludg
# prosumer -> prosum
# ready-to-assemble -> ready-to-assembl
# furniture -> furnitur
# printing -> print
# teaching -> teach
# learning -> learn
# practices -> practic
# described -> describ
# avoids -> avoid
# aims -> aim
# instructional -> instruct
# covered -> cover
# downes -> down
# distance -> distanc
# noted -> note
# spreading -> spread
# aspects -> aspect
# examples -> exampl
# notes -> note
# efforts -> effort
# government -> govern
# corporate -> corpor
# interests -> interest
# emerging -> emerg
# technologies -> technolog
# identified -> identifi
# commercialization -> commerci
# thinking -> think
# university -> univers
# course -> cours
# madness -> mad
# experiment -> experi
# ones -> one
# students -> student
# produced -> produc
# adopted -> adopt
# outside -> outsid
# identifies -> identifi
# possible -> possibl
# intellectual -> intellectu
# precursors -> precursor
# hampshire -> hampshir
# college -> colleg
# voice -> voic
# critical -> critic
# wired -> wire
# retrieved -> retriev
# bavatuesdays -> bavatuesday
# introducing -> introduc
# changing -> chang
# expectations -> expect
# heritage -> heritag
# july -> juli
# feelings -> feel
# encyclopedic -> encycloped
# produces -> produc
# derived -> deriv
# prosumption -> prosumpt
# production -> product
# coined -> coin
# writers -> writer
# perspective -> perspect
# devices -> devic
# digital -> digit
# cameras -> camera
# definitions -> definit
# origins -> origin
# general -> gener
# meanings -> mean
# producer -> produc
# non-corporate -> non-corpor
# company -> compani
# reception -> recept
# adoption -> adopt
# company's -> company'
# blurring -> blur
# roles -> role
# producers -> produc
# cooperative -> cooper
# enthusiasts -> enthusiast
# always -> alway
# standards -> standard
# complexity -> complex
# refers -> refer
# category -> categori
# camcorders -> camcord
# advanced -> advanc
# features -> featur
# increased -> increas
# customizing -> custom
# toffler's -> toffler'
# sense -> sens
# marshall -> marshal
# electric -> electr
# merge -> merg
# highly -> highli
# demands -> demand
# continue -> continu
# businesses -> busi
# customized -> custom
# however -> howev
# especially -> especi
# requirements -> requir
# extension -> extens
# clients -> client
# cases -> case
# primary -> primari
# 'prosumption -> 'prosumpt
# architecture -> architectur
# decentralization -> decentr
# agency -> agenc
# recently -> recent
# works -> work
# worldwide -> worldwid
# mentioned -> mention
# economy -> economi
# despite -> despit
# several -> sever
# theoretical -> theoret
# george -> georg
# characteristic -> characterist
# prosumers -> prosum
# companies -> compani
# wages -> wage
# areas -> area
# industry -> industri
# years -> year
# choices -> choic
# stores -> store
# ways -> way
# names -> name
# giving -> give
# recorded -> record
# indeed -> inde
# generally -> gener
# going -> go
# choice -> choic
# producing -> produc
# taking -> take
# hobbyists -> hobbyist
# today's -> today'
# energy -> energi
# households -> household
# times -> time
# surplus -> surplu
# national -> nation
# distribution -> distribut
# consume -> consum
# panels -> panel
# generating -> gener
# electricity -> electr
# gas -> ga
# innovation -> innov
# programme -> programm
# leisure -> leisur
# pursuits -> pursuit
# initial -> initi
# combination -> combin
# hobbies -> hobbi
# rising -> rise
# profession -> profess
# serious -> seriou
# cooking -> cook
# dedicated -> dedic
# photography -> photographi
# trends -> trend
# factors -> factor
# disposable -> dispos
# sectors -> sector
# prices -> price
# towards -> toward
# amateurs -> amateur
# beginning -> begin
# 1980s -> 1980
# forums -> forum
# experience -> experi
# considered -> consid
# fence -> fenc
# bells -> bell
# expanded -> expand
# challenge -> challeng
# anticipated -> anticip
# goods -> good
# services -> servic
# furthermore -> furthermor
# forces -> forc
# developed -> develop
# marketing -> market
# politics -> polit
# schools -> school
# infoanarchism -> infoanarch
# philosophical -> philosoph
# theory -> theori
# practice -> practic
# struggle -> struggl
# democracy -> democraci
# ecology -> ecolog
# association -> associ
# participatory -> participatori
# autonomous -> autonom
# spontaneous -> spontan
# squatting -> squat
# temporary -> temporari
# lifestylism -> lifestyl
# violence -> violenc
# conference -> confer
# incident -> incid
# republic -> republ
# europe -> europ
# france -> franc
# days -> day
# triangle -> triangl
# collection -> collect
# library -> librari
# carnival -> carniv
# capital -> capit
# seattle -> seattl
# films -> film
# masters -> master
# radical -> radic
# glossary -> glossari
# economics -> econom
# really -> realli
# germany -> germani
# greece -> greec
# lists -> list
# communities -> commun
# fictional -> fiction
# characters -> charact
# anarchists -> anarchist
# communism -> commun
# thus -> thu
# profits -> profit
# reduced -> reduc
# supplying -> suppli
# consumer-oriented -> consumer-ori
# diminished -> diminish
# income -> incom
# globalization -> global
# automation -> autom
# integrate -> integr
# end-users -> end-us
# instance -> instanc
# integrated -> integr
# strengthened -> strengthen
# customer -> custom
# increasingly -> increasingli
# utilizing -> util
# parties -> parti
# allows -> allow
# software -> softwar
# update -> updat
# collaboration -> collabor
# changes -> chang
# increase -> increas
# sharing -> share
# terminology -> terminolog
# source -> sourc
# creates -> creat
# successful -> success
# operating -> oper
# capabilities -> capabl
# goals -> goal
# playing -> play
# instruments -> instrument
# listening -> listen
# creative -> creativ
# generated -> gener
# developing -> develop
# nations -> nation
# aware -> awar
# investments -> invest
# plus -> plu
# waste -> wast
# taxes -> tax
# comes -> come
# wants -> want
# supply -> suppli
# serve -> serv
# payers -> payer
# different -> differ
# locally -> local
# asking -> ask
# service -> servic
# resource -> resourc
# manipulating -> manipul
# spending -> spend
# directly -> directli
# manufacturer -> manufactur
# widgets -> widget
# customers -> custom
# important -> import
# seriously -> serious
# solve -> solv
# specific -> specif
# effects -> effect
# immediate -> immedi
# meets -> meet
# willingness -> willing
# commons-based -> commons-bas
# episode -> episod
# december -> decemb
# sustainability -> sustain
# solutions -> solut
# studying -> studi
# values -> valu
# descriptions -> descript
# wiki-based -> wiki-bas
# guides -> guid
# manuals -> manual
# description -> descript
# leave -> leav
# overall -> overal
# entitled -> entitl
# perhaps -> perhap
# genre -> genr
# carnegie -> carnegi
# existed -> exist
# tradition -> tradit
# generation -> gener
# languages -> languag
# invented -> invent
# learned -> learn
# traditions -> tradit
# eventually -> eventu
# broadened -> broaden
# forming -> form
# printed -> print
# texts -> text
# painting -> paint
# swimming -> swim
# easily -> easili
# everyone -> everyon
# consistent -> consist
# documentation -> document
# another -> anoth
# makes -> make
# necessarily -> necessarili
# how-tos -> how-to
# history -> histori
# knowledge -> knowledg
# added -> ad
# methods -> method
# imparted -> impart
# guide -> guid
# bridge -> bridg
# damage -> damag
# solution -> solut
# clumsy -> clumsi
# inelegant -> ineleg
# inefficient -> ineffici
# diverse -> divers
# fields -> field
# computer -> comput
# aerospace -> aerospac
# evolutionary -> evolutionari
# neuroscience -> neurosci
# pronunciation -> pronunci
# etymology -> etymolog
# surname -> surnam
# industries -> industri
# alternate -> altern
# pronunciations -> pronunci
# proposed -> propos
# etymologies -> etymolog
# entry -> entri
# cites -> cite
# word's -> word'
# granholm's -> granholm'
# appeared -> appear
# datamation -> datam
# invention -> invent
# ill-assorted -> ill-assort
# poorly-matching -> poorly-match
# computing -> comput
# machine -> machin
# improvised -> improvis
# poorly -> poorli
# phineas -> phinea
# burling -> burl
# wiggles -> wiggl
# multilingual -> multilingu
# according -> accord
# language -> languag
# originally -> origin
# typical -> typic
# leading -> lead
# forms -> form
# stands -> stand
# handy -> handi
# application -> applic
# anyone -> anyon
# adjective -> adject
# following -> follow
# reasons -> reason
# equivalent -> equival
# speakers -> speaker
# variation -> variat
# derive -> deriv
# engineers -> engin
# includes -> includ
# kludges -> kludg
# applying -> appli
# programmer -> programm
# maintained -> maintain
# spelling -> spell
# confused -> confus
# kludged -> kludg
# device -> devic
# programming -> program
# involves -> involv
# something -> someth
# routine -> routin
# probably -> probabl
# feature -> featur
# implemented -> implement
# reported -> report
# mid-1950s -> mid-1950
# exclusively -> exclus
# kluges -> kluge
# gives -> give
# jury -> juri
# navy -> navi
# piece -> piec
# worked -> work
# folklore -> folklor
# quarterly -> quarterli
# story -> stori
# overcomplicated -> overcompl
# dates -> date
# complete -> complet
# quoted -> quot
# wanting -> want
# ignorant -> ignor
# asked -> ask
# actually -> actual
# makers -> maker
# reached -> reach
# admiral -> admir
# returned -> return
# interesting -> interest
# condition -> condit
# hackers -> hacker
# pronounce -> pronounc
# mostly -> mostli
# restricted -> restrict
# convinced -> convinc
# named -> name
# presses -> press
# fledgling -> fledgl
# brothers -> brother
# automatic -> automat
# allowed -> allow
# continued -> continu
# active -> activ
# seems -> seem
# mechanical -> mechan
# connection -> connect
# points -> point
# likely -> like
# tended -> tend
# diminutive -> diminut
# separate -> separ
# enable -> enabl
# manufactured -> manufactur
# movie -> movi
# sws -> sw
# vehicles -> vehicl
# module -> modul
# position -> posit
# docking -> dock
# recycled -> recycl
# managed -> manag
# manned -> man
# historical -> histor
# fixing -> fix
# properties -> properti
# change -> chang
# introduced -> introduc
# essentially -> essenti
# expected -> expect
# intimate -> intim
# typically -> typic
# required -> requir
# consequence -> consequ
# slightly -> slightli
# internal -> intern
# wires -> wire
# increasing -> increas
# electrical -> electr
# translation -> translat
# inside -> insid
# particularly -> particularli
# discusses -> discuss
# cognitive -> cognit
# every -> everi
# pastiche -> pastich
# turns -> turn
# wipers -> wiper
# gets -> get
# wiring -> wire
# genetically -> genet
# unprecedented -> unpreced
# macgyver -> macgyv
# replacement -> replac
# philosophy -> philosophi
# academics -> academ
# literature -> literatur
# cultural -> cultur
# studies -> studi
# psychology -> psycholog
# improvisation -> improvis
# humming -> hum
# drums -> drum
# storage -> storag
# bicycle -> bicycl
# unusual -> unusu
# automotive -> automot
# stylistic -> stylist
# writes -> write
# sub-cultures -> sub-cultur
# experimentation -> experiment
# daily -> daili
# pioneers -> pioneer
# artistic -> artist
# limited -> limit
# remote -> remot
# financially -> financi
# commercial -> commerci
# unlike -> unlik
# necessary -> necessari
# training -> train
# creativity -> creativ
# careful -> care
# observation -> observ
# welcome -> welcom
# trusting -> trust
# self-correcting -> self-correct
# structures -> structur
# targeted -> target
# technique -> techniqu
# constructed -> construct
# collage -> collag
# strategy -> strategi
# players -> player
# spaces -> space
# designers -> design
# unique -> uniqu
# buildings -> build
# suggesting -> suggest
# identities -> ident
# safety -> safeti
# psychological -> psycholog
# problems -> problem
# unrelated -> unrel
# already -> alreadi
# sanchez-burks -> sanchez-burk
# disciplines -> disciplin
# claude -> claud
# societies -> societi
# retrieve -> retriev
# recombine -> recombin
# therefore -> therefor
# patterns -> pattern
# opposed -> oppos
# discourse -> discours
# calls -> call
# identify -> identifi
# solving -> solv
# trying -> tri
# testing -> test
# kincheloe -> kinchelo
# denote -> denot
# employed -> employ
# foundation -> foundat
# researchers -> research
# rigorous -> rigor
# provide -> provid
# sophisticated -> sophist
# understanding -> understand
# capable -> capabl
# sis -> si
# competitive -> competit
# advantage -> advantag
# tinkering -> tinker
# allowing -> allow
# turkle -> turkl
# workspace -> workspac
# productivity -> product
# advocates -> advoc
# conventional -> convent
# variety -> varieti
# enables -> enabl
# fully -> fulli
# tasks -> task
# successfully -> success
# served -> serv
# incorporating -> incorpor
# purposes -> purpos
# candy -> candi
# immediately -> immedi
# children's -> children'
# weapons -> weapon
# operators -> oper
# hams -> ham
# resistors -> resistor
# capacitors -> capacitor
# screws -> screw
# nuts -> nut
# bolts -> bolt
# homebrewers -> homebrew
# boxes -> box
# homebrewing -> homebrew
# keeping -> keep
# provides -> provid
# repairs -> repair
# removing -> remov
# quantities -> quantiti
# treasure -> treasur
# tracking -> track
# commercially -> commerci
# gauge -> gaug
# entered -> enter
# preferred -> prefer
# fencing -> fenc
# evolved -> evolv
# ability -> abil
# machinery -> machineri
# officially -> offici
# completed -> complet
# requires -> requir
# packaged -> packag
# addition -> addit
# saving -> save
# assemble -> assembl
# selling -> sell
# expensive -> expens
# factory -> factori
# fasteners -> fasten
# purchased -> purchas
# advantages -> advantag
# easy -> easi
# chinese -> chines
# skilled -> skill
# unskilled -> unskil
# office -> offic
# cabinets -> cabinet
# redirected -> redirect
# functional -> function
# labs -> lab
# body -> bodi
# physical -> physic
# identical -> ident
# co-creation -> co-creat
# external -> extern
# directions -> direct
# compared -> compar
# o'reilly -> o'reilli
# larry -> larri
# expression -> express
# policies -> polici
# corporation -> corpor
# simultaneously -> simultan
# title -> titl
# currently -> current
# apply -> appli
# funding -> fund
# lacking -> lack
# countries -> countri
# single -> singl
# country -> countri
# involve -> involv
# collaborate -> collabor
# collaborative -> collabor
# models -> model
# members -> member
# overcome -> overcom
# designs -> design
# quite -> quit
# flexible -> flexibl
# thingiverse -> thingivers
# printable -> printabl
# notable -> notabl
# miscellaneous -> miscellan
# motors -> motor
# territories -> territori
# alliance -> allianc
# basis -> basi
# geometrical -> geometr
# cells -> cell
# files -> file
# licensed -> licens
# initiative -> initi
# makerspace -> makerspac
# hackspace -> hackspac
# community-operated -> community-oper
# machining -> machin
# hackerspaces -> hackerspac
# mechanisms -> mechan
# men's -> men'
# sheds -> shed
# facilities -> facil
# organization -> organ
# difficulties -> difficulti
# centers -> center
# nights -> night
# shops -> shop
# participate -> particip
# physically -> physic
# located -> locat
# libraries -> librari
# founding -> found
# costs -> cost
# performer -> perform
# started -> start
# included -> includ
# middle -> middl
# opened -> open
# thereafter -> thereaft
# citizens -> citizen
# burning -> burn
# vary -> vari
# lending -> lend
# facility -> facil
# infrastructure -> infrastructur
# fabrication -> fabric
# generators -> gener
# printers -> printer
# cutters -> cutter
# promoting -> promot
# makerspaces -> makerspac
# determined -> determin
# elected -> elect
# boards -> board
# selected -> select
# standing -> stand
# policy -> polici
# administrative -> administr
# fees -> fee
# charge -> charg
# volunteer -> volunt
# internationally -> intern
# defined -> defin
# functioning -> function
# varies -> vari
# planning -> plan
# regulations -> regul
# handle -> handl
# ventilation -> ventil
# improvements -> improv
# liability -> liabil
# showed -> show
# backgrounds -> background
# dominated -> domin
# attention -> attent
# locations -> locat
# formed -> form
# assisted -> assist
# department -> depart
# aged -> age
# founded -> found
# pioneered -> pioneer
# enabled -> enabl
# october -> octob
# initiated -> initi
# prototyping -> prototyp
# meetings -> meet
# beijing -> beij
# advertise -> advertis
# response -> respons
# sees -> see
# laboratory -> laboratori
# starting -> start
# entire -> entir
# columbus -> columbu
# references -> refer
# explore -> explor
# january -> januari
# yes -> ye
# specializing -> special
# regularly -> regularli
# prototype -> prototyp
# released -> releas
# categories -> categori
# full-time -> full-tim
# announced -> announc
# acquisition -> acquisit
# official -> offici
# mobile -> mobil
# windows -> window
# registered -> regist
# prizes -> prize
# awarded -> award
# questions -> question
# trades -> trade
# woodworking -> woodwork
# cutting -> cut
# getting -> get
# jobs -> job
# plumbing -> plumb
# leaky -> leaki
# fixture -> fixtur
# estimates -> estim
# franchise -> franchis
# assessment -> assess
# options -> option
# drywall -> drywal
# remodeling -> remodel
# carpentry -> carpentri
# moulding -> mould
# substantial -> substanti
# particle -> particl
# inclined -> inclin
# reporter -> report
# try -> tri
# chains -> chain
# professionalism -> profession
# handyman's -> handyman'
# pressure -> pressur
# injury -> injuri
# installing -> instal
# steps -> step
# estimate -> estim
# part-time -> part-tim
# contractors -> contractor
# replacing -> replac
# firms -> firm
# advertising -> advertis
# owners -> owner
# trucks -> truck
# workers -> worker
# insured -> insur
# plates -> plate
# studs -> stud
# employing -> employ
# technicians -> technician
# turned -> turn
# liked -> like
# installation -> instal
# homeowner -> homeown
# basements -> basement
# movable -> movabl
# relatively -> rel
# concluded -> conclud
# licensing -> licens
# guarantee -> guarante
# weeks -> week
# holes -> hole
# ceiling -> ceil
# fixed -> fix
# carry -> carri
# transaction -> transact
# referrals -> referr
# cleaning -> clean
# tiling -> tile
# require -> requir
# connecting -> connect
# image -> imag
# handsome -> handsom
# minds -> mind
# manny -> manni
# little -> littl
# garage -> garag
# insulation -> insul
# molding -> mold
# moving -> move
# removal -> remov
# modifications -> modif
# clips -> clip
# voltage -> voltag
# synthesizers -> synthes
# switches -> switch
# potentiometers -> potentiomet
# experimental -> experiment
# innovators -> innov
# practiced -> practic
# experimenting -> experi
# inexpensive -> inexpens
# resulting -> result
# electrocution -> electrocut
# repeated -> repeat
# achieved -> achiev
# causes -> caus
# knobs -> knob
# risks -> risk
# games -> game
# cause -> caus
# serge -> serg
# experiments -> experi
# kraakdoos -> kraakdoo
# leone -> leon
# samved -> samv
# conducted -> conduct
# declared -> declar
# oman's -> oman'
# branding -> brand
# awards -> award
# honours -> honour
# mainly -> mainli
# completely -> complet
# kids -> kid
# municipality -> municip
# awareness -> awar
# conjunction -> conjunct
# conservation -> conserv
# management -> manag
# plantation -> plantat
# drives -> drive
# campaigns -> campaign
# actively -> activ
# surface -> surfac
# copying -> copi
# three-dimensional -> three-dimension
# additive -> addit
# layers -> layer
# computer-aided -> computer-aid
# heads -> head
# jetting -> jet
# directed -> direct
# deposition -> deposit
# extrusion -> extrus
# photopolymerization -> photopolymer
# modeling -> model
# finishing -> finish
# legislation -> legisl
# decade -> decad
# matured -> matur
# metalworking -> metalwork
# envelope -> envelop
# transforming -> transform
# desired -> desir
# subtractive -> subtract
# polymer -> polym
# 2010s -> 2010
# manufacturers -> manufactur
# automated -> autom
# agile -> agil
# tooling -> tool
# engine -> engin
# complementing -> complement
# casting -> cast
# stamping -> stamp
# significant -> signific
# inroads -> inroad
# effective -> effect
# injection -> inject
# institute -> institut
# controlled -> control
# scanning -> scan
# filed -> file
# stereolithography -> stereolithographi
# claimed -> claim
# fused -> fuse
# commercialized -> commerci
# sintering -> sinter
# melting -> melt
# selective -> select
# milling -> mill
# errors -> error
# timelapse -> timelaps
# reconstruction -> reconstruct
# resolution -> resolut
# thickness -> thick
# x-y -> x-i
# dots -> dot
# particles -> particl
# hours -> hour
# depending -> depend
# precision -> precis
# polymers -> polym
# abs -> ab
# improved -> improv
# chemical -> chemic
# supports -> support
# overhanging -> overhang
# substrate -> substrat
# schematic -> schemat
# representation -> represent
# deposited -> deposit
# differences -> differ
# metals -> metal
# fabricated -> fabric
# granules -> granul
# manufactures -> manufactur
# transparent -> transpar
# solidified -> solidifi
# photopolymer -> photopolym
# cured -> cure
# projected -> project
# rises -> rise
# slowly -> slowli
# defense -> defens
# medical -> medic
# robots -> robot
# threeding -> threed
# facilitate -> facilit
# turning -> turn
# foods -> food
# shoes -> shoe
# manufacture -> manufactur
# football -> footbal
# airbus -> airbu
# force -> forc
# firearms -> firearm
# distributed -> distribut
# plans -> plan
# regarding -> regard
# surgery -> surgeri
# implants -> implant
# personalized -> person
# organs -> organ
# museums -> museum
# actuators -> actuat
# interaction -> interact
# actuator -> actuat
# regimes -> regim
# patents -> patent
# laws -> law
# limitation -> limit
# exception -> except
# inventions -> invent
# tangible -> tangibl
# statue -> statu
# copyrightable -> copyright
# courts -> court
# intelligence -> intellig
# guns -> gun
# commentators -> comment
# emissions -> emiss
# minutes -> minut
# displacing -> displac
# economies -> economi
# productive -> product
# transportation -> transport
# summers -> summer
# artificial -> artifici
# vigorous -> vigor
# estate -> estat
# strengthening -> strengthen
# financial -> financi
# spence -> spenc
# powerful -> power
# marginal -> margin
# declines -> declin
# believes -> believ
# employment -> employ
# expansion -> expans
# labor-intensive -> labor-intens

# %% [markdown]
# ## 9. Computing representation power of common words.

# %%
# combine
makerness = {}
# common_words = [w[0] for w in common_words]
for w in common_words:
    # Consider only words whose charcater length is larger than 1
    if len(w) > 1:
        # Log likelihood scores are computed:
        score = log((input_freq_dist[w] / n_input) / (english_freq_dist[w] / n_english))
        makerness[w] = score

# %%
common_words
# Out:
# ['previously',
#  'marks',
#  'door',
#  'discourse',
#  'chains',
#  'even',
#  'office',
#  'fundamental',
#  'address',
#  'patents',
#  'radical',
#  'candy',
#  'carpentry',
#  'swimming',
#  'founding',
#  'far',
#  'course',
#  'economy',
#  'welcome',
#  'firms',
#  'whether',
#  'politics',
#  'fields',
#  'drawn',
#  'writing',
#  'advanced',
#  'covers',
#  'against',
#  'rig',
#  'experimentation',
#  'meets',
#  'handy',
#  'essentially',
#  'pieces',
#  'sponsored',
#  'cutters',
#  'serve',
#  'inefficient',
#  'business',
#  'traditional',
#  'code',
#  'influence',
#  'acquisition',
#  'set',
#  'scanning',
#  'opened',
#  'akin',
#  'university',
#  'fence',
#  'mess',
#  "'",
#  'giving',
#  'integrate',
#  'notes',
#  'trusting',
#  'areas',
#  'melting',
#  'smaller',
#  'essay',
#  'possess',
#  'military',
#  'journals',
#  'album',
#  'yes',
#  'matter',
#  'wider',
#  'molding',
#  'bent',
#  'primary',
#  'reconstruction',
#  'reporter',
#  'nail',
#  'simple',
#  'wages',
#  'august',
#  'unpaid',
#  'complete',
#  'cause',
#  'version',
#  'photography',
#  'teaching',
#  'discussing',
#  'assessment',
#  'application',
#  'contest',
#  'significantly',
#  'sheds',
#  'process',
#  'week',
#  'asking',
#  'branch',
#  'powder',
#  'thinking',
#  'french',
#  'jim',
#  'name',
#  'homeowners',
#  'particle',
#  'motors',
#  'awareness',
#  'fully',
#  'europe',
#  'platform',
#  'change',
#  'related',
#  'materials',
#  'sectors',
#  'data',
#  'file',
#  'sophisticated',
#  'quantities',
#  'satisfy',
#  'open',
#  'myriad',
#  'assembled',
#  'ever',
#  'paper',
#  'useful',
#  'emerged',
#  'capabilities',
#  'record',
#  'jet',
#  'real',
#  'stewart',
#  's',
#  'vary',
#  'definitions',
#  'object',
#  'guarantee',
#  'sense',
#  'began',
#  'exclusively',
#  'personalized',
#  'peer',
#  'includes',
#  'turn',
#  'drives',
#  'episode',
#  'fees',
#  'question',
#  'security',
#  'seriously',
#  'educational',
#  'store',
#  'porch',
#  'fuel',
#  'maintenance',
#  'danish',
#  'solid',
#  'creativity',
#  'behavior',
#  'ghana',
#  'translation',
#  'among',
#  'task',
#  'odd',
#  'longer',
#  'avoid',
#  'criteria',
#  'removed',
#  'pool',
#  'launched',
#  'continues',
#  'management',
#  'techniques',
#  'hours',
#  'required',
#  'damage',
#  'comes',
#  'policies',
#  'though',
#  'claim',
#  'levels',
#  'amplifier',
#  'staff',
#  'identical',
#  'orbit',
#  'especially',
#  'arts',
#  'limited',
#  'appear',
#  'fictional',
#  'installing',
#  'specialized',
#  'evolved',
#  'publishers',
#  'computers',
#  'section',
#  'finishing',
#  'took',
#  'following',
#  'identities',
#  'library',
#  'street',
#  'saturn',
#  'speaker',
#  'provides',
#  'chinese',
#  'fed',
#  'publication',
#  'programming',
#  'francisco',
#  'smart',
#  'use',
#  'condition',
#  'music',
#  'daily',
#  'journal',
#  'growth',
#  'kind',
#  'conjunction',
#  'budget',
#  'plus',
#  'advent',
#  'firearms',
#  'yet',
#  'fall',
#  'take',
#  'web',
#  'profits',
#  "company's",
#  'fit',
#  'panels',
#  'schematic',
#  'licensing',
#  'fusion',
#  'umbrella',
#  'surname',
#  'initiated',
#  'activities',
#  'experiences',
#  'organs',
#  'partial',
#  'manifold',
#  'school',
#  'tucker',
#  'color',
#  'material',
#  'classes',
#  '2d',
#  'serge',
#  'hack',
#  'rights',
#  'laboratory',
#  'difficult',
#  'therefore',
#  'repeated',
#  'position',
#  'private',
#  'courses',
#  'units',
#  'successfully',
#  'm',
#  'feelings',
#  'east',
#  'financial',
#  'jocular',
#  'cells',
#  'experiments',
#  'sets',
#  'enables',
#  'bells',
#  'traditions',
#  'experience',
#  'turns',
#  'sees',
#  'writers',
#  'activity',
#  'commercially',
#  'sex',
#  'worked',
#  'squatting',
#  'mass',
#  'collections',
#  'motivations',
#  'tooling',
#  'quickly',
#  'developed',
#  'sunset',
#  'handsome',
#  'together',
#  'intimate',
#  'days',
#  'period',
#  'seattle',
#  'science',
#  'focusing',
#  'certain',
#  'done',
#  'lynn',
#  'ask',
#  'valid',
#  'minds',
#  'experimenting',
#  'germany',
#  'part',
#  'original',
#  'novel',
#  'short',
#  'better',
#  'estimates',
#  'unlike',
#  'designers',
#  'skills',
#  'apollo',
#  'instruments',
#  'spirit',
#  'piece',
#  'chain',
#  'bottom',
#  'unusual',
#  'verification',
#  'buy',
#  'functional',
#  'function',
#  'achieved',
#  'gain',
#  'seem',
#  'bob',
#  'half',
#  'desired',
#  'interested',
#  'reported',
#  'taken',
#  'bending',
#  'follow',
#  'g',
#  'storage',
#  'company',
#  'stone',
#  'resolution',
#  'metals',
#  'thereafter',
#  'sites',
#  'first',
#  'scrap',
#  'subsequently',
#  'struggle',
#  'guns',
#  'nature',
#  'increasing',
#  'democracy',
#  'vienna',
#  'tended',
#  'folk',
#  'full',
#  'art',
#  'transaction',
#  'texts',
#  'organization',
#  'opposed',
#  'concepts',
#  'works',
#  'elected',
#  'product',
#  'work',
#  'historical',
#  'recorded',
#  'manufacture',
#  'needs',
#  'dominated',
#  'ship',
#  'standard',
#  'interaction',
#  'firm',
#  'person',
#  'characteristic',
#  'fabrication',
#  'july',
#  'dutch',
#  'gene',
#  'claimed',
#  'productive',
#  'ceiling',
#  'emergence',
#  'pro',
#  'selected',
#  'turned',
#  'toilet',
#  'formed',
#  'dots',
#  'either',
#  'paint',
#  'fiber',
#  'expensive',
#  'still',
#  'showed',
#  'intellectual',
#  'learn',
#  'particular',
#  'allows',
#  'definition',
#  'drove',
#  'operating',
#  'control',
#  'recognition',
#  '4',
#  'modifications',
#  'step',
#  'early',
#  'methods',
#  'outside',
#  'production',
#  'new',
#  'behind',
#  'existed',
#  'theoretical',
#  'place',
#  'force',
#  'item',
#  'earlier',
#  'britain',
#  'explain',
#  'sell',
#  'violence',
#  'paid',
#  'laws',
#  'forming',
#  'magazine',
#  'films',
#  'meaning',
#  'department',
#  'act',
#  'seen',
#  'voltage',
#  'discuss',
#  'specific',
#  'transportation',
#  'september',
#  'emerging',
#  'user',
#  'actually',
#  'friends',
#  'changes',
#  'cable',
#  'remove',
#  'd',
#  'creative',
#  'whose',
#  'hobbies',
#  'feature',
#  'image',
#  'cheaper',
#  'launch',
#  'low-cost',
#  'lab',
#  'major',
#  'rapid',
#  'electronics',
#  'account',
#  'transform',
#  'customer',
#  'available',
#  'applied',
#  'physical',
#  'upon',
#  'discusses',
#  'voice',
#  'form',
#  'extended',
#  'mechanical',
#  'around',
#  'artists',
#  'preparation',
#  'plantation',
#  'garage',
#  'owner',
#  'good',
#  'award',
#  'earn',
#  'do-it-yourself',
#  'design',
#  'evolutionary',
#  'prizes',
#  'overall',
#  'will',
#  'injury',
#  'spurred',
#  'bands',
#  'manufacturer',
#  'wind',
#  'board',
#  'insured',
#  'circuits',
#  'improved',
#  'facilities',
#  'carnegie',
#  'involved',
#  'simultaneously',
#  'era',
#  'surplus',
#  'child',
#  'heritage',
#  'shops',
#  'sharing',
#  'communities',
#  'tracking',
#  'impact',
#  'larry',
#  'cure',
#  'owners',
#  'called',
#  'aged',
#  'power',
#  'choices',
#  'referrals',
#  'channel',
#  'phrase',
#  'studs',
#  'apply',
#  'editor',
#  'recently',
#  'located',
#  'specializing',
#  'search',
#  'conventional',
#  'vehicles',
#  'mostly',
#  'signal',
#  'trial',
#  'computer',
#  'every',
#  'patterns',
#  'albert',
#  'class',
#  'roles',
#  'entry',
#  'franchise',
#  'initially',
#  'deliver',
#  'pitch',
#  'awards',
#  'interest',
#  'complex',
#  'pair',
#  'wrote',
#  'architectural',
#  'professor',
#  'interesting',
#  'entitled',
#  '14',
#  'eventually',
#  'across',
#  'window',
#  'verb',
#  'functioning',
#  'vincent',
#  'sometimes',
#  'primarily',
#  'see',
#  'claude',
#  'two',
#  'workshops',
#  'cameras',
#  'tasks',
#  'beam',
#  'flexible',
#  'services',
#  'precision',
#  'aspects',
#  'expected',
#  'vacuum',
#  'fun',
#  'technicians',
#  'european',
#  'screws',
#  'price',
#  'relationship',
#  'commons',
#  'insurance',
#  'inclined',
#  'comment',
#  'brazil',
#  'philip',
#  'working',
#  'make',
#  'volunteer',
#  'economics',
#  'scale',
#  'late',
#  'soft',
#  'employing',
#  'marshall',
#  'repairs',
#  'plates',
#  'diminished',
#  'furthermore',
#  'crafts',
#  'role',
#  'deposition',
#  'team',
#  'clothes',
#  'beyond',
#  'used',
#  'rising',
#  'water',
#  'emphasizing',
#  'basic',
#  'hill',
#  'problems',
#  'corporation',
#  'refers',
#  'technical',
#  'griffith',
#  'swedish',
#  'final',
#  'manufactured',
#  'try',
#  'entire',
#  'strengthening',
#  'manuals',
#  'increased',
#  'stock',
#  'mobile',
#  'disciplines',
#  'saw',
#  'air',
#  'ways',
#  'cost',
#  'associated',
#  'mechanisms',
#  'envelope',
#  'artist',
#  'electricity',
#  'rate',
#  'need',
#  'assistance',
#  'drywall',
#  'liquid',
#  'made',
#  'administration',
#  'communism',
#  'stem',
#  'director',
#  'showing',
#  'given',
#  'workshop',
#  'red',
#  'increasingly',
#  'documentation',
#  'metal',
#  'wall',
#  'scientific',
#  'john',
#  'suggested',
#  'entered',
#  'june',
#  "men's",
#  'models',
#  'added',
#  'foundation',
#  'little',
#  'women',
#  'written',
#  'h',
#  'greek',
#  'errors',
#  'features',
#  'end',
#  'properties',
#  'labels',
#  'internal',
#  'cabinets',
#  'head',
#  'share',
#  'choice',
#  'jobs',
#  'removing',
#  'pack',
#  'wants',
#  'employment',
#  'manufacturing',
#  'gear',
#  'varies',
#  'improvised',
#  'pirate',
#  'electronic',
#  'introducing',
#  'lacking',
#  'wired',
#  'lists',
#  'academic',
#  'sexual',
#  'painting',
#  'getting',
#  'portion',
#  'restricted',
#  'drums',
#  'innovation',
#  't',
#  'thin',
#  'tax',
#  'income',
#  'spaces',
#  'slightly',
#  'efforts',
#  'thing',
#  'broadened',
#  'ones',
#  'returned',
#  'mainly',
#  'feedback',
#  'output',
#  'american',
#  'reach',
#  'proof',
#  'refer',
#  'issues',
#  'followed',
#  'cooking',
#  'potential',
#  'conservation',
#  'william',
#  'reached',
#  'clumsy',
#  'crack',
#  'focused',
#  'build',
#  'fixing',
#  'identify',
#  'strategy',
#  'powerful',
#  'including',
#  'screen',
#  'tim',
#  'masters',
#  'view',
#  'april',
#  'van',
#  'completed',
#  'flat',
#  'machine',
#  'method',
#  'routine',
#  'decades',
#  'easily',
#  'tradition',
#  'seek',
#  'junk',
#  'stamping',
#  'center',
#  'general',
#  'sold',
#  'ideas',
#  'differences',
#  'paying',
#  'high',
#  'processes',
#  'noted',
#  'trends',
#  'show',
#  'connecting',
#  'eye',
#  'illustrated',
#  'anyone',
#  'changing',
#  'component',
#  'line',
#  'applying',
#  'avoids',
#  'completely',
#  'structures',
#  '-',
#  'devices',
#  'phenomena',
#  'included',
#  'hard',
#  'variation',
#  'congress',
#  'zealand',
#  'exist',
#  'conducted',
#  'tools',
#  'stage',
#  'groups',
#  'retail',
#  'union',
#  'spain',
#  'milling',
#  'able',
#  'north',
#  'u',
#  'along',
#  'inventions',
#  'museums',
#  'earliest',
#  'since',
#  'positive',
#  'remote',
#  'foods',
#  'directed',
#  'spelling',
#  'generated',
#  'interests',
#  'building',
#  "one's",
#  'bicycle',
#  'italy',
#  'association',
#  'allowed',
#  'diminutive',
#  'equivalent',
#  'institute',
#  'starting',
#  'liked',
#  'movements',
#  'war',
#  'dates',
#  'living',
#  'references',
#  'grant',
#  'game',
#  'demand',
#  'adding',
#  'everyone',
#  'growing',
#  'body',
#  'asked',
#  'groom',
#  'television',
#  'states',
#  'earth',
#  'boards',
#  'sewing',
#  'descriptions',
#  'tree',
#  'notable',
#  'unrelated',
#  'destination',
#  'digital',
#  'registered',
#  'community',
#  'games',
#  'training',
#  'different',
#  'perfect',
#  'formal',
#  'report',
#  'property',
#  'declines',
#  'neighborhood',
#  'charge',
#  'mind',
#  'prevent',
#  'really',
#  'way',
#  'car',
#  'mean',
#  'fixture',
#  'supply',
#  'packaged',
#  'characters',
#  'approach',
#  'relying',
#  'max',
#  'printer',
#  'solar',
#  'appropriate',
#  'observation',
#  'territories',
#  'additive',
#  'vigorous',
#  'repair',
#  'carolina',
#  'national',
#  'student',
#  'ability',
#  'printed',
#  'derive',
#  'rigorous',
#  'system',
#  'facility',
#  'de',
#  'whole',
#  'globe',
#  'maintained',
#  'health',
#  'typically',
#  'defined',
#  'regarding',
#  'long',
#  'meanings',
#  'risks',
#  'collage',
#  'description',
#  'involve',
#  'marketing',
#  'known',
#  'jewish',
#  'speed',
#  'fee',
#  'cross-section',
#  'wood',
#  'understanding',
#  'workers',
#  'statements',
#  'guide',
#  'brand',
#  'saving',
#  'call',
#  'full-time',
#  'language',
#  'hampshire',
#  'increase',
#  'unprecedented',
#  'meet',
#  'centers',
#  'century',
#  'spot',
#  'topics',
#  'market',
#  'three-dimensional',
#  'facilitate',
#  'anticipated',
#  'basis',
#  'gives',
#  'calls',
#  'managed',
#  'age',
#  'noise',
#  'external',
#  'parties',
#  'boxes',
#  'performer',
#  'despite',
#  'effects',
#  'reaction',
#  'december',
#  'casting',
#  'requires',
#  'diverse',
#  'origin',
#  'featuring',
#  'everyday',
#  'agency',
#  'york',
#  'vent',
#  'somewhat',
#  'hand',
#  'rock',
#  'experiment',
#  'articles',
#  'london',
#  'thickness',
#  'category',
#  'carry',
#  'means',
#  'automation',
#  'industry',
#  'movement',
#  'coined',
#  'profit',
#  'commonly',
#  'usually',
#  'overcome',
#  'forces',
#  'africa',
#  'higher',
#  'furniture',
#  'cards',
#  'professional',
#  'benjamin',
#  'november',
#  'effect',
#  'enthusiasts',
#  'subject',
#  'grade',
#  'automotive',
#  'middle',
#  'consumer',
#  'thus',
#  'automatic',
#  'large',
#  'best',
#  'last',
#  'easy',
#  'solution',
#  'k',
#  'current',
#  'constructed',
#  'polymers',
#  'boy',
#  'grow',
#  'simply',
#  'book',
#  'enabling',
#  'taxes',
#  'countries',
#  'clothing',
#  'homemade',
#  'six',
#  'information',
#  'investments',
#  'critical',
#  'perspective',
#  'negative',
#  'bring',
#  'program',
#  'right',
#  'injection',
#  ...]

# %%
# Sorting by scores:
for k,v in sorted(makerness.items(), key=lambda x:x[1], reverse=True): print(k,v)
# Out:
# additive 6.250989607578818
# printer 5.879426051146336
# printing 5.635229090634293
# digital 5.4094224219006
# franchise 5.1454568760661346
# users 5.0809183549285635
# global 5.0809183549285635
# citation 5.011925483441612
# bending 4.980834896371581
# deposition 4.829603926647658
# do-it-yourself 4.7707634266247245
# manufacturing 4.736077868636834
# homeowners 4.6754532468204
# computers 4.6754532468204
# non-profit 4.6754532468204
# template 4.6754532468204
# hardware 4.6754532468204
# evolutionary 4.675453246820399
# junk 4.675453246820399
# jargon 4.675453246820399
# layer 4.632893632401603
# fabrication 4.610914725682828
# bug 4.541921854195876
# hack 4.493131690026445
# lab 4.493131690026445
# zealand 4.493131690026445
# coined 4.493131690026445
# individualist 4.493131690026445
# portal 4.493131690026445
# computer 4.461879146522341
# media 4.461879146522341
# commons 4.387771174368618
# consumers 4.3500308463857715
# maker 4.33061276052867
# circuit 4.28079905481645
# surname 4.269988138712235
# enthusiasts 4.269988138712235
# eric 4.269988138712235
# prototype 4.269988138712235
# fused 4.269988138712235
# catalog 4.269988138712235
# user 4.205449617574664
# manuals 4.205449617574664
# drywall 4.205449617574664
# modular 4.205449617574664
# wilhelm 4.205449617574664
# aerospace 4.205449617574664
# installation 4.205449617574664
# repair 4.164627623054408
# terminology 4.136456746087712
# repairs 4.100089101916837
# saturn 3.9823060662604544
# hobbies 3.9823060662604544
# crafts 3.9823060662604544
# robots 3.9823060662604544
# advertise 3.9823060662604544
# programmer 3.9823060662604544
# sis 3.9823060662604544
# 1950s 3.9823060662604544
# pursuits 3.9823060662604544
# carpentry 3.982306066260454
# scanning 3.982306066260454
# sheds 3.982306066260454
# advent 3.982306066260454
# tooling 3.982306066260454
# discusses 3.982306066260454
# circuits 3.982306066260454
# layers 3.982306066260454
# ethic 3.982306066260454
# austria 3.982306066260454
# retrieved 3.8769455506026276
# resin 3.8645230306040705
# furniture 3.845104944746969
# innovation 3.8281553864331954
# environmental 3.8281553864331954
# usage 3.8281553864331954
# amplifier 3.7999845094664995
# web 3.7999845094664995
# modifications 3.7999845094664995
# low-cost 3.7999845094664995
# apollo 3.759162514946244
# groom 3.759162514946244
# risks 3.759162514946244
# three-dimensional 3.759162514946244
# topic 3.730991637979548
# trusting 3.694623993808673
# peer 3.694623993808673
# 2d 3.694623993808673
# verification 3.694623993808673
# texts 3.694623993808673
# architectural 3.694623993808673
# emphasizing 3.694623993808673
# feedback 3.694623993808673
# casting 3.694623993808673
# modifying 3.694623993808673
# yiddish 3.694623993808673
# toy 3.694623993808673
# internationally 3.694623993808673
# dryer 3.694623993808673
# melt 3.694623993808673
# fink 3.694623993808673
# technology 3.686841853366618
# architecture 3.6638523351419194
# term 3.5831501273455544
# personalized 3.5768409581522898
# schematic 3.5768409581522898
# emergence 3.5768409581522898
# insured 3.5768409581522898
# tracking 3.5768409581522898
# studs 3.5768409581522898
# documentation 3.5768409581522898
# labels 3.5768409581522898
# improvised 3.5768409581522898
# connecting 3.5768409581522898
# avoids 3.5768409581522898
# diminutive 3.5768409581522898
# fixture 3.5768409581522898
# printed 3.5768409581522898
# inroads 3.5768409581522898
# marketplace 3.5768409581522898
# licensed 3.5768409581522898
# glossary 3.5768409581522898
# publish 3.5768409581522898
# unskilled 3.5768409581522898
# instructional 3.5768409581522898
# pioneered 3.5768409581522898
# spacecraft 3.5768409581522898
# pioneers 3.5768409581522898
# mentality 3.5768409581522898
# fledgling 3.5768409581522898
# design 3.5635957314022693
# businesses 3.522773736882014
# tools 3.5004679793677154
# print 3.4898295811626596
# identities 3.471480442494463
# motivations 3.471480442494463
# cabinets 3.471480442494463
# stamping 3.471480442494463
# bicycle 3.471480442494463
# virtual 3.471480442494463
# access 3.443309565527767
# firearms 3.4226902783250313
# metals 3.4226902783250313
# cable 3.4226902783250313
# backgrounds 3.4226902783250313
# origins 3.4226902783250313
# distressing 3.4226902783250313
# economies 3.4226902783250313
# fix 3.4226902783250313
# sites 3.406941921356892
# typically 3.406941921356892
# opposed 0.9618811801160915
# spending 0.9618811801160915
# today's 0.9618811801160915
# teach 0.9618811801160915
# societies 0.9618811801160915
# together 0.9600067653217412
# usually 0.9570149904649186
# achieved 0.9537839698834721
# struggle 0.9537839698834721
# reduce 0.9537839698834721
# interests 0.9497598195837467
# less 0.9468953088882867
# wages 0.937783628537031
# journal 0.937783628537031
# guns 0.937783628537031
# signal 0.937783628537031
# comment 0.937783628537031
# reach 0.937783628537031
# health 0.937783628537031
# grow 0.937783628537031
# obtain 0.937783628537031
# reflected 0.937783628537031
# proposed 0.937783628537031
# limited 0.9283048845824873
# factors 0.9283048845824873
# making 0.925949170890028
# post 0.925949170890028
# results 0.9242699093703081
# easily 0.9189151442326483
# porch 0.9142531311268369
# transportation 0.9142531311268369
# philosophy 0.9142531311268369
# resulting 0.9142531311268369
# believes 0.9142531311268369
# republic 0.9142531311268369
# heads 0.9142531311268369
# lead 0.9142531311268369
# part 0.903192183767412
# fixed 0.902692308725761
# income 0.9003960964654107
# rather 0.8939409906728547
# cutting 0.8912636129021382
# declared 0.8912636129021382
# odd 0.8912636129021381
# bottom 0.8912636129021381
# recognition 0.8912636129021381
# laws 0.8912636129021381
# fun 0.8912636129021381
# mobile 0.8912636129021381
# written 0.8912636129021381
# origin 0.8912636129021381
# thickness 0.8912636129021381
# shoes 0.8912636129021381
# develop 0.8799640576482048
# control 0.8777193877943809
# teaching 0.8762257355375977
# jury 0.8762257355375977
# particular 0.8743618020995348
# africa 0.8687907570500795
# taxes 0.8687907570500795
# medium 0.8687907570500795
# support 0.8687907570500795
# purposes 0.8687907570500795
# steel 0.8687907570500795
# large 0.8660168301673543
# plans 0.8643561599822138
# starting 0.861410649752457
# quick 0.861410649752457
# practical 0.861410649752457
# higher 0.8530424000819402
# early 0.852261455098869
# although 0.8499222727456966
# levels 0.8468118503313043
# difficult 0.8468118503313043
# completed 0.8468118503313043
# panels 0.8468118503313041
# precision 0.8468118503313041
# thin 0.8468118503313041
# flight 0.8468118503313041
# system 0.8419925638953554
# view 0.8360009342270887
# calls 0.8324231128792047
# san 0.8324231128792047
# writing 0.8295700438967981
# essentially 0.8253056451103407
# patterns 0.8253056451103407
# employment 0.8253056451103407
# tradition 0.8253056451103407
# sold 0.8253056451103407
# grant 0.8253056451103407
# everyone 0.8253056451103407
# boards 0.8253056451103407
# discussion 0.8253056451103407
# thousands 0.8253056451103407
# expansion 0.8253056451103407
# manufacturers 0.8253056451103407
# window 0.8126204855830249
# points 0.8112209052286018
# sense 0.8074625115427566
# become 0.8070338788743854
# platform 0.8042522359125084
# additional 0.8042522359125084
# limit 0.8042522359125084
# mile 0.8042522359125084
# service 0.7946827848963576
# follow 0.7938894488769617
# included 0.7938894488769617
# economic 0.7918297159139512
# advantage 0.7904589137801725
# industry 0.7865526588131074
# speaker 0.7836329487097726
# incident 0.7836329487097726
# burning 0.7836329487097726
# november 0.7768532617243941
# problems 0.7755028226265226
# data 0.7749246208179882
# low 0.7749246208179882
# manner 0.7714624130895174
# effect 0.0073082616709194805
# college 0.004495320294304742
# continue 0.002624412358493115
# distance -0.006677980303820452
# language -0.015894635408744355
# deep -0.015894635408744355
# already -0.01772781649040544
# getting -0.018948072895634792
# clear -0.020471302436156275
# field -0.021384127693515942
# wish -0.025027118972016982
# speak -0.025027118972016982
# actually -0.03106943342797956
# shown -0.03106943342797956
# give -0.035363128302679
# cars -0.04304562447469538
# taken -0.046610690639191425
# program -0.04813469398216652
# hold -0.048980359994509795
# function -0.051934571891941256
# either -0.05723025946665166
# since -0.06233882740937407
# single -0.06657612188488937
# makes -0.06657612188488937
# force -0.06947888154285084
# returned -0.06947888154285084
# corner -0.06947888154285084
# slowly -0.06947888154285084
# true -0.07381728314144904
# taking -0.08386761899495032
# appear -0.08672068797735685
# account -0.08672068797735685
# europe -0.0952313776452655
# along -0.0980522539869068
# made -0.09879326921162607
# society -0.09945971375478659
# reported -0.10367024629113016
# served -0.10367024629113016
# determined -0.10367024629113016
# steps -0.10367024629113016
# found -0.1046035174741286
# line -0.10534950781085009
# attention -0.10646745091219133
# small -0.11573535784297283
# case -0.11757867633726218
# required -0.12308833214823163
# spirit -0.12308833214823163
# daily -0.12856779791285727
# feed -0.12856779791285727
# important -0.13673110855201817
# larger -0.13673110855201817
# kept -0.1448283187846375
# high -0.14684241815633883
# expected -0.15019026192602297
# thus -0.15125920911492802
# given -0.1581796519595017
# come -0.1608286601310787
# note -0.16873383963819205
# forms -0.16873383963819205
# fact -0.17434237929780164
# worked -0.17657701709921797
# longer -0.18177183397632185
# george -0.18435915754127283
# wrong -0.18435915754127283
# seems -0.18822763431919318
# cause -0.19208120363518327
# hot -0.19208120363518327
# month -0.19208120363518327
# opened -0.19974407638075223
# step -0.19974407638075223
# student -0.19974407638075223
# point -0.2048202294126128
# association -0.20734867576597157
# held -0.20734867576597157
# keep -0.20734867576597157
# money -0.21112939860587757
# mean -0.21238646979592876
# soon -0.21238646979592876
# continued -0.21489588140135454
# great -0.21489588140135454
# trial -0.2223865531305121
# summer -0.2223865531305121
# might -0.2253671812686498
# black -0.23228762411322357
# sound -0.23720163891565266
# leave -0.24209162420984456
# record -0.24452767900772568
# set -0.2518004383368053
# better -0.2518004383368053
# body -0.25180043833680543
# time -0.25870784413661635
# every -0.26822791247875327
# throughout -0.27330664355776896
# weeks -0.27330664355776896
# head -0.2756679197434488
# run -0.2756679197434488
# students -0.28037381078086143
# place -0.283888752888306
# whether -0.287391383439508
# yes -0.29436005275560145
# john -0.29990023313121683
# put -0.3058676596070812
# earlier -0.30815337488793715
# name -0.31497933995833705
# stock -0.31497933995833705
# house -0.3200684094658083
# william -0.3217590269437157
# entire -0.3284930591250599
# meet -0.3284930591250599
# second -0.3298344409492611
# times -0.33518204727585643
# voice -0.33961664434372213
# age -0.34403166255283907
# congress -0.3484272740258771
# side -0.35105539643214645
# full -0.35716095399463166
# came -0.37119248479888955
# even -0.3744027604291377
# natural -0.3744027604291377
# still -0.37696358129081137
# areas -0.38291345009704636
# reason -0.4038785785620913
# subject -0.40595111816406376
# boy -0.4080193712281228
# medical -0.4121430884119848
# indeed -0.4121430884119848
# street -0.41624987036463823
# trying -0.4182969539863631
# rest -0.4182969539863631
# now -0.42593641054432063
# interest -0.4304922270801814
# old -0.4320062319113963
# whose -0.4445345842032203
# reached -0.4544454681026743
# air -0.46815772996665606
# real -0.4720412299930537
# hours -0.4836020523941296
# report -0.4836020523941296
# inside -0.4836020523941296
# read -0.4836020523941296
# take -0.48524274185158967
# forces -0.4893327271031148
# though -0.49503074821775256
# period -0.49881147105765844
# conditions -0.5175036040698112
# return -0.5175036040698112
# car -0.5322097514595066
# east -0.5340329060210217
# week -0.5358527427380075
# half -0.5358527427380075
# really -0.5358527427380075
# basis -0.5394825107885864
# pressure -0.5449025782579255
# values -0.550293426892802
# much -0.5577921229839226
# across -0.5609887160095498
# days -0.5820421252073822
# young -0.5846429069074397
# america -0.592404912242929
# minutes -0.6026614124101181
# red -0.6077504819175892
# law -0.6195252184621228
# look -0.6203609895095189
# tax -0.6278516612386766
# york -0.6295086624463059
# good -0.6303361345663384
# two -0.6313990221774748
# hard -0.6328144505808057
# evidence -0.642666747023817
# will -0.6431122805575848
# life -0.6440663273782404
# therefore -0.6475567323180089
# matter -0.6491814280450108
# rate -0.6668810051444117
# took -0.6858389188890258
# child -0.6858389188890258
# level -0.6858389188890258
# back -0.6936331906158447
# feel -0.6998251608637658
# year -0.7151393958368082
# six -0.7181742995319623
# family -0.7212000204484992
# policy -0.7272241350518802
# department -0.7406471553840209
# something -0.7406471553840209
# ever -0.7597233024448347
# war -0.7712841248459106
# turn -0.7755852067453013
# saw -0.7827128206695334
# years -0.7947143766542967
# board -0.8010103051111114
# south -0.805185676521592
# position -0.8093436866702558
# per -0.8352837076788715
# upon -0.8359573351883457
# present -0.8513268325194471
# office -0.8658102983380269
# room -0.869724197659163
# question -0.8736228380748204
# behind -0.8775063381012181
# thought -0.8794424471280845
# probably -0.8890671605022941
# city -0.8928912569406976
# next -0.8954325543693701
# asked -0.9055336503558741
# government -0.9545630775961926
# yet -0.9569525649935741
# quite -0.9629014225133465
# act -0.9699936508228383
# far -0.9735209913408067
# enough -0.9828668537590445
# long -1.0309923452552854
# three -1.0448585297870123
# course -1.0611190506587926
# turned -1.0928677489733731
# country -1.1052902689719302
# mind -1.1083719355093382
# want -1.1175603615637444
# thing -1.1326892431600444
# say -1.1416579131428048
# children -1.1966645426550166
# said -1.2010084871375217
# felt -1.2022825349592399
# men -1.2686576039041124
# going -1.3135081700694642
# must -1.328927525554129
# right -1.3374465810076477
# nothing -1.3431399676758353
# against -1.360028185704357
# think -1.3952844811820906
# away -1.4470395626939867
# always -1.4514159372937856
# went -1.553057756770784
# go -1.7638971242796992
# last -1.840739829222565
# man -2.0149748661689677
# state -2.0178704214495493
# little -2.047176548035049

# %%
with open('makerness_diy.csv', 'w') as csvfile:
    thewriter = csv.writer(csvfile, delimiter=',')
    for k,v in sorted(makerness.items(), key=lambda x:x[1], reverse=True):
        thewriter.writerow([k,v])
