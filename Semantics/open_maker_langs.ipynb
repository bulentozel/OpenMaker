# %% [markdown]
# # Discovery and Representation of Open Making Related Terms

# %% [markdown]
# This notebook sketches the initial exercise on discovering the open making related keywords. The input text is harvested via a Web crawler that identifies and crawls semantically related wikipedia articles.

# %%
from utils import tokenizer
import nltk
from nltk import FreqDist
from math import log
import json, csv

# %% [markdown]
# ## 1. Loading a reference English language corpus

# %%
from nltk.corpus import brown
brown.categories()
# Out:
# ['adventure',
#  'belles_lettres',
#  'editorial',
#  'fiction',
#  'government',
#  'hobbies',
#  'humor',
#  'learned',
#  'lore',
#  'mystery',
#  'news',
#  'religion',
#  'reviews',
#  'romance',
#  'science_fiction']

# %% [markdown]
# ## 2. Stop words

# %% [markdown]
# ### 2.1 Standard stop words

# %%
with open("data/stopwords_standard.txt", "r") as f:
    STOP_WORDS_STANDARD = set(f.read().strip().split("\n"))
print(STOP_WORDS_STANDARD)
# Out:
# {'more', 'being', 'get', "it's", 'am', 'does', "wasn't", "i've", 'in', 'after', "doesn't", 'ourselves', 'they', 'any', 'an', 'myself', 'then', 'than', 'when', "who's", 'whom', "wouldn't", 'by', "don't", 'up', 'such', 'has', "didn't", 'to', 'their', 'would', 'while', "couldn't", "i'll", 'only', "shan't", 'i', 'him', 'but', 'can', 'further', "here's", 'no', 'this', 'not', 'doing', 'on', 'them', "haven't", 'how', "let's", 'is', 'from', 'the', 'as', 'each', 'had', 'there', 'these', 'just', 'should', 'during', "won't", 'ours ', 'same', "can't", 'are', "they're", 'until', 'herself', 'and', "we're", "hasn't", 'most', 'like', 'me', 'his', 'nor', 'all', "where's", 'what', "he's", "there's", 'which', 'above', "shouldn't", 'few', 'once', "they'd", 'r', 'she', 'here', 'were', 'with', "when's", 'do', 'over', 'who', 'yourself', 'own', 'he', "she'd", "you've", "she'll", 'between', 'com', "they've", "why's", "i'm", 'if', 'ought', 'too', 'www', "you're", "we've", 'did', "weren't", 'was', "they'll", "you'd", 'under', 'my', "you'll", 'other', 'you', 'below', 'it', 'before', 'its', 'very', 'off', 'hers', 'your', "hadn't", 'that', "aren't", 'why', "that's", 'themselves', 'where', 'into', "we'd", 'so', 'know', 'because', 'her', "isn't", "i'd", 'out', 'have', "he'll", 'theirs', 'yourselves', 'some', 'could', 'of', 'those', 'having', 'at', 'http', 'be', 'been', "she's", "we'll", 'yours', 'itself', 'our', 'again', 'down', 'about', 'cannot', 'we', 'or', "what's", 'both', "he'd", "mustn't", "how's", 'for', 'a', 'through', 'himself'}

# %% [markdown]
# ### 2.2 Open-making related stop words

# %%
with open("data/stopwords_openmaker.txt", "r") as f:
    STOP_WORDS_OPENMAKER = set(f.read().strip().split("\n"))
print(STOP_WORDS_OPENMAKER)
# Out:
# {'may', 'almost'}

# %% [markdown]
# ## 3. Removing stop words from the reference English corpus

# %%
# merging the two list together
STOP_WORDS = STOP_WORDS_STANDARD.union(STOP_WORDS_OPENMAKER)
print(STOP_WORDS)
# Out:
# {'more', 'being', 'get', "it's", "wasn't", "i've", 'after', "doesn't", 'myself', 'then', 'than', 'by', "don't", 'up', 'has', 'to', 'would', 'while', "couldn't", 'only', "shan't", 'can', 'no', 'them', "haven't", 'is', 'from', 'as', 'just', 'should', 'same', "can't", 'are', 'herself', 'and', "we're", "hasn't", 'his', 'nor', 'all', "where's", "he's", 'which', 'above', "shouldn't", 'few', 'once', "they'd", 'r', 'she', 'were', 'almost', 'with', 'who', 'own', 'between', "they've", "i'm", 'if', 'ought', 'too', "you're", "weren't", 'was', "they'll", "you'd", 'under', "you'll", 'other', 'it', 'very', 'that', "aren't", 'why', 'where', 'themselves', "we'd", 'know', 'because', "he'll", 'yourselves', 'at', 'http', "she's", 'itself', 'again', 'about', 'cannot', 'may', "mustn't", "how's", 'for', 'through', 'himself', 'am', 'does', 'in', 'ourselves', 'they', 'any', 'an', 'when', "who's", 'whom', "wouldn't", 'such', "didn't", 'their', "i'll", 'i', 'him', 'but', 'further', "here's", 'this', 'not', 'doing', 'on', 'how', "let's", 'the', 'each', 'had', 'there', 'these', 'during', "won't", 'ours ', "they're", 'until', 'most', 'like', 'me', 'what', "there's", 'here', "when's", 'do', 'over', 'yourself', 'he', "she'd", "you've", "she'll", 'com', "why's", 'www', "we've", 'did', 'my', 'you', 'below', 'before', 'its', 'off', 'hers', 'your', "hadn't", "that's", 'into', 'so', "isn't", 'her', "i'd", 'out', 'have', 'theirs', 'some', 'could', 'of', 'those', 'having', 'be', 'been', "we'll", 'yours', 'our', 'down', 'we', 'or', "what's", 'both', "he'd", 'a'}

# %%
# load english words from the Brown corpus removing stop words.
english_freq_dist = FreqDist([w.lower() for w in nltk.corpus.brown.words()
                              if w not in STOP_WORDS])

# %% [markdown]
# ## 4. Removing the rare words.

# %% [markdown]
# Below we remove rare words and get total count. The code below keeps all words with a occurance frequency above 2.

# %%
english_freq_dist = {k:v for k,v in english_freq_dist.items() if v > 2}

# %% [markdown]
# ## 5. Loading the input Open Maker corpus

# %%
# load the harvested text from wikipedia.
with open("data/wikipedia.json", "r") as f: OM_Corpus_text = f.read()
OM_Corpus = json.loads(OM_Corpus_text)

# %%
# The toatl number of wiki articles used:
print(len(OM_Corpus))
# Out:
# 152

# %%
# Column names of the the corpus.
OM_Corpus[0].keys()
# Out:
# dict_keys(['theme.id', 'title', 'url', 'depth', 'text'])

# %%
def display_pages(tid):
    meme = [page for page in OM_Corpus if page['theme.id'] == tid]
    for m in meme:
        print(m['depth'],m['title'], m['url'])

# %%
display_pages(0)
# Out:
# 0 Do it yourself https://en.wikipedia.org/wiki/Do_it_yourself
# 1 Edupunk https://en.wikipedia.org/wiki/Edupunk
# 1 Prosumer https://en.wikipedia.org/wiki/Prosumer
# 1 How-to https://en.wikipedia.org/wiki/How-to
# 1 Kludge https://en.wikipedia.org/wiki/Kludge
# 1 Bricolage https://en.wikipedia.org/wiki/Bricolage
# 1 Junk box https://en.wikipedia.org/wiki/Junk_box
# 1 Number 8 wire https://en.wikipedia.org/wiki/Number_8_wire
# 1 Ready-to-assemble furniture https://en.wikipedia.org/wiki/Ready-to-assemble_furniture
# 1 Community film https://en.wikipedia.org/wiki/Community_film
# 1 Collaborative innovation network https://en.wikipedia.org/wiki/Collaborative_innovation_network
# 1 Design thinking https://en.wikipedia.org/wiki/Design_thinking
# 1 Role-based collaboration https://en.wikipedia.org/wiki/Role-based_collaboration
# 1 Intranet portal https://en.wikipedia.org/wiki/Intranet_portal
# 1 Critical thinking https://en.wikipedia.org/wiki/Critical_thinking
# 1 Facilitation (business) https://en.wikipedia.org/wiki/Facilitation_(business)
# 1 Collaborative software https://en.wikipedia.org/wiki/Collaborative_software
# 1 Postpartisan https://en.wikipedia.org/wiki/Postpartisan
# 1 Collaborative search engine https://en.wikipedia.org/wiki/Collaborative_search_engine
# 1 Crowdsourcing https://en.wikipedia.org/wiki/Crowdsourcing
# 1 Conference call https://en.wikipedia.org/wiki/Conference_call
# 1 Collaborative leadership https://en.wikipedia.org/wiki/Collaborative_leadership
# 1 Learning circle https://en.wikipedia.org/wiki/Learning_circle
# 1 Unorganisation https://en.wikipedia.org/wiki/Unorganisation
# 1 Digital collaboration https://en.wikipedia.org/wiki/Digital_Collaboration
# 1 Collaborative translation https://en.wikipedia.org/wiki/Collaborative_translation
# 1 Classical music written in collaboration https://en.wikipedia.org/wiki/Classical_music_written_in_collaboration

# %% [markdown]
# ## 6. Analyzing a specific corpus based on a theme

# %%
# Note that theme.id: 0 corresponds to the the Do IT YOURSELF
input_text = " ".join([page['text'] for page in OM_Corpus if page['theme.id'] == 0])

# %%
# Tokenizing the input text:
tokenized = tokenizer.tokenize_words(input_text)
number_of_words = len(tokenized)
print(number_of_words),OM_Corpus[0]['title']
# Out:
# 30073
# (None, 'Do it yourself')

# %% [markdown]
# ### 6.1 Computing frequency distributions of each token, i.e word, term, pancuation, etc.

# %%
input_freq_dist = FreqDist(tokenized)

# %%
input_freq_dist.most_common(20)
# Out:
# [('\n', 3787),
#  ('the', 1257),
#  ('and', 776),
#  ('of', 771),
#  ('a', 661),
#  ('to', 642),
#  ('in', 563),
#  ('"', 429),
#  ('is', 303),
#  ('as', 276),
#  ('for', 257),
#  ('that', 224),
#  ('or', 206),
#  ('by', 186),
#  ('with', 182),
#  ('on', 156),
#  ('are', 151),
#  ('3d', 142),
#  ('from', 129),
#  ('it', 119)]

# %% [markdown]
# ### 6.2 Removing punctuation and stopwords from the input corpus

# %%
for stopword in STOP_WORDS:
    if stopword in input_freq_dist:
        del input_freq_dist[stopword]
        
for punctuation in tokenizer.CHARACTERS_TO_SPLIT:
    if punctuation in input_freq_dist:
        del input_freq_dist[punctuation]

# Re-control most common words after cleaning:
input_freq_dist.most_common(20)
# Out:
# [('3d', 142),
#  ('printing', 94),
#  ('design', 75),
#  ('used', 72),
#  ('open', 65),
#  ('also', 63),
#  ('one', 58),
#  ('new', 56),
#  ('many', 55),
#  ('kludge', 55),
#  ('term', 53),
#  ('diy', 52),
#  ('manufacturing', 51),
#  ('use', 50),
#  ('project', 49),
#  ('bricolage', 46),
#  ('often', 45),
#  ('work', 45),
#  ('hackerspaces', 44),
#  ('handyman', 43)]

# %% [markdown]
# ### 6.3 Removing rare words from input distribution

# %%
input_freq_dist = {k:v for k,v in input_freq_dist.items() if v > 1}

# %% [markdown]
# ## 7. Comparing input vs English corpus volumes

# %% [markdown]
# ### 7.1 Total words (after cleaning)

# %%
n_input = sum(input_freq_dist.values())
n_english = sum(english_freq_dist.values())
n_input, n_english
# Out:
# (12914, 685422)

# %% [markdown]
# ### 7.2 Unique words (after cleaning)

# %%
n_unique_word_input = len(input_freq_dist.items())
n_unique_word_brown = len(english_freq_dist.items())
n_unique_word_input, n_unique_word_brown
# Out:
# (2386, 20591)

# %% [markdown]
# ### 7.3 Cleaned set of input words/terms

# %% [markdown]
# List of words in the corpus in case, for a visual inspection. Such inspections will be used both to improve tokenization as well as filetring.

# %%
input_freq_dist
# Out:
# {'uses': 23,
#  'see': 29,
#  'disambiguation': 5,
#  'diy': 52,
#  'redirects': 3,
#  'article': 21,
#  'multiple': 13,
#  'issues': 10,
#  'please': 9,
#  'help': 20,
#  'improve': 15,
#  'discuss': 4,
#  'page': 2,
#  'learn': 14,
#  'remove': 11,
#  'template': 10,
#  'possibly': 4,
#  'contains': 3,
#  'original': 11,
#  'research': 17,
#  'verifying': 2,
#  'claims': 5,
#  'made': 19,
#  'adding': 11,
#  'inline': 2,
#  'citations': 7,
#  'statements': 2,
#  'consisting': 3,
#  'removed': 8,
#  'november': 3,
#  'message': 10,
#  'needs': 8,
#  'additional': 5,
#  'better': 6,
#  'verification': 3,
#  'reliable': 3,
#  'sources': 12,
#  'unsourced': 3,
#  'material': 27,
#  'challenged': 3,
#  'september': 2,
#  'part': 23,
#  'series': 11,
#  'individualism': 4,
#  'topics': 4,
#  'concepts': 2,
#  'autonomy': 2,
#  'free': 29,
#  'love': 6,
#  'freethought': 2,
#  'human': 12,
#  'rights': 8,
#  'individual': 13,
#  'reclamation': 2,
#  'liberty': 4,
#  'negative': 3,
#  'personal': 7,
#  'property': 12,
#  'positive': 4,
#  'private': 4,
#  'self-ownership': 2,
#  'mile': 2,
#  'armand': 2,
#  'albert': 2,
#  'william': 2,
#  'godwin': 2,
#  'emma': 2,
#  'goldman': 2,
#  'friedrich': 2,
#  'karl': 3,
#  'john': 5,
#  'h': 3,
#  'l': 8,
#  'michel': 3,
#  'de': 4,
#  'robert': 2,
#  'murray': 3,
#  'rothbard': 2,
#  'arthur': 2,
#  'smith': 2,
#  'spencer': 2,
#  'lysander': 2,
#  'spooner': 2,
#  'max': 2,
#  'stirner': 2,
#  'henry': 2,
#  'david': 4,
#  'thoreau': 2,
#  'benjamin': 2,
#  'tucker': 2,
#  'james': 2,
#  'josiah': 2,
#  'warren': 3,
#  'anarchism': 11,
#  'anarcho-capitalism': 2,
#  'liberalism': 2,
#  'egoist': 2,
#  'individualist': 5,
#  'feminism': 3,
#  'left-wing': 2,
#  'market': 14,
#  'libertarianism': 3,
#  'libertarian': 3,
#  'socialism': 3,
#  'right': 3,
#  'social': 29,
#  'group': 9,
#  'mentality': 2,
#  'mass': 12,
#  'society': 4,
#  'engineering': 11,
#  'tyranny': 2,
#  'majority': 3,
#  'v': 7,
#  't': 5,
#  'e': 21,
#  'boy': 3,
#  'building': 22,
#  'model': 19,
#  'texas': 2,
#  'security': 3,
#  'administration': 4,
#  'method': 9,
#  'modifying': 3,
#  'repairing': 4,
#  'things': 13,
#  'without': 15,
#  'direct': 7,
#  'aid': 5,
#  'experts': 3,
#  'professionals': 4,
#  'academic': 4,
#  'describes': 6,
#  'individuals': 8,
#  'engage': 3,
#  'raw': 4,
#  'materials': 25,
#  'component': 4,
#  'parts': 37,
#  'produce': 13,
#  'transform': 2,
#  'including': 18,
#  'drawn': 2,
#  'natural': 2,
#  'environment': 9,
#  'g': 13,
#  'landscaping': 2,
#  'behavior': 2,
#  'various': 18,
#  'motivations': 3,
#  'previously': 6,
#  'categorized': 2,
#  'marketplace': 2,
#  'economic': 10,
#  'benefits': 5,
#  'lack': 6,
#  'product': 11,
#  'availability': 4,
#  'quality': 12,
#  'need': 11,
#  'customization': 8,
#  'identity': 2,
#  'empowerment': 3,
#  'community': 21,
#  'term': 53,
#  'do-it-yourself': 11,
#  'associated': 8,
#  'consumers': 13,
#  'since': 11,
#  'least': 7,
#  'primarily': 2,
#  'domain': 3,
#  'home': 31,
#  'improvement': 13,
#  'maintenance': 7,
#  'activities': 8,
#  'phrase': 4,
#  'come': 10,
#  'common': 30,
#  'usage': 12,
#  'standard': 10,
#  'english': 7,
#  '1950s': 3,
#  'reference': 5,
#  'emergence': 2,
#  'trend': 6,
#  'people': 33,
#  'small': 9,
#  'craft': 4,
#  'construction': 8,
#  'projects': 38,
#  'activity': 4,
#  'subsequently': 2,
#  'taken': 5,
#  'broader': 3,
#  'meaning': 17,
#  'covers': 4,
#  'wide': 10,
#  'range': 12,
#  'skill': 5,
#  'sets': 5,
#  'international': 15,
#  'alternative': 10,
#  'rock': 4,
#  'punk': 11,
#  'indie': 2,
#  'music': 35,
#  'scenes': 2,
#  'indymedia': 2,
#  'networks': 2,
#  'pirate': 2,
#  'radio': 10,
#  'zine': 2,
#  'context': 3,
#  'related': 12,
#  'arts': 11,
#  'crafts': 3,
#  'movement': 22,
#  'modern': 4,
#  'consumer': 21,
#  'culture': 29,
#  "'s": 7,
#  'relying': 2,
#  'others': 10,
#  'satisfy': 3,
#  'also': 63,
#  'widely': 11,
#  'used': 72,
#  'military': 8,
#  'way': 22,
#  'teach': 2,
#  'types': 3,
#  'units': 2,
#  'take': 7,
#  'able': 5,
#  'preparation': 2,
#  'future': 7,
#  'fashion': 8,
#  'subculture': 4,
#  'groups': 10,
#  'publications': 4,
#  'bc': 3,
#  'greek': 2,
#  'structure': 7,
#  'southern': 3,
#  'italy': 2,
#  'came': 8,
#  'assembly': 6,
#  'instructions': 7,
#  'called': 13,
#  'ikea': 2,
#  'city': 3,
#  'region': 3,
#  'local': 15,
#  'along': 6,
#  'known': 14,
#  'century': 7,
#  'professor': 2,
#  'director': 2,
#  'british': 6,
#  'school': 15,
#  'rome': 2,
#  'said': 11,
#  'example': 27,
#  'yet': 3,
#  'found': 9,
#  'marks': 2,
#  'time': 23,
#  'looks': 2,
#  'someone': 6,
#  'components': 21,
#  'put': 6,
#  'together': 13,
#  'much': 10,
#  'instruction': 2,
#  'sections': 2,
#  'showing': 3,
#  'pieces': 3,
#  'date': 4,
#  'back': 9,
#  'around': 22,
#  'architectural': 6,
#  'evidence': 2,
#  'suggested': 6,
#  'decoration': 2,
#  'built': 13,
#  'shelves': 2,
#  'toy': 3,
#  'vehicle': 2,
#  'often': 45,
#  'old': 8,
#  'pattern': 3,
#  'use': 50,
#  'skills': 11,
#  'house': 8,
#  'making': 12,
#  'clothes': 2,
#  'cars': 2,
#  'computers': 10,
#  'websites': 10,
#  'living': 7,
#  'panel': 2,
#  'discussion': 4,
#  'edition': 2,
#  'san': 3,
#  'francisco': 3,
#  'reflected': 2,
#  'growing': 7,
#  'educational': 6,
#  'system': 18,
#  'nothing': 2,
#  'give': 7,
#  'us': 15,
#  'kind': 7,
#  'words': 6,
#  'make': 30,
#  'build': 18,
#  'houses': 2,
#  'fundamental': 2,
#  'life': 7,
#  'whole': 9,
#  'education': 20,
#  'children': 2,
#  'entirely': 6,
#  'terms': 12,
#  'insurance': 3,
#  'character': 3,
#  '1970s': 5,
#  'spread': 5,
#  'north': 8,
#  'american': 19,
#  'population': 3,
#  'age': 3,
#  'involved': 8,
#  'affordable': 3,
#  'older': 5,
#  'homes': 7,
#  'environmental': 6,
#  '1960s': 7,
#  'early': 16,
#  'young': 4,
#  'stewart': 2,
#  'brand': 3,
#  'working': 13,
#  'friends': 4,
#  'family': 3,
#  'initially': 2,
#  'using': 38,
#  'basic': 5,
#  'typesetting': 2,
#  'tools': 21,
#  'published': 5,
#  'first': 30,
#  'earth': 3,
#  'catalog': 4,
#  'access': 14,
#  'late': 6,
#  'fiberglass': 2,
#  'california': 5,
#  'style': 10,
#  'techniques': 18,
#  'broad': 2,
#  'definition': 6,
#  'informational': 3,
#  'books': 13,
#  'technical': 7,
#  'nature': 6,
#  'professional': 13,
#  'journals': 2,
#  'courses': 4,
#  'classes': 5,
#  'specialized': 3,
#  'designed': 7,
#  'items': 8,
#  "'": 2,
#  'welding': 4,
#  'equipment': 21,
#  'even': 15,
#  'designer': 2,
#  'j': 4,
#  'editor': 2,
#  'include': 23,
#  'writing': 5,
#  'many': 55,
#  'reviews': 2,
#  's': 8,
#  'publication': 3,
#  'emerged': 4,
#  'spurred': 3,
#  'great': 10,
#  'wave': 5,
#  'attitude': 4,
#  'cross-section': 2,
#  'america': 2,
#  'influence': 8,
#  'decades': 4,
#  'magazines': 4,
#  'popular': 17,
#  'mechanics': 2,
#  'illustrated': 5,
#  'readers': 3,
#  'keep': 4,
#  'current': 9,
#  'useful': 3,
#  'practical': 3,
#  'began': 9,
#  'created': 14,
#  'collections': 2,
#  'magazine': 16,
#  'articles': 7,
#  'extensive': 6,
#  'line': 5,
#  'how-to': 16,
#  'sunset': 2,
#  'based': 14,
#  'upon': 4,
#  'publishers': 2,
#  'soon': 3,
#  'followed': 4,
#  'electronics': 16,
#  'world': 27,
#  'assembled': 4,
#  'amplifier': 5,
#  'mid-1990s': 4,
#  'home-improvement': 2,
#  'content': 9,
#  'find': 9,
#  'onto': 8,
#  'web': 5,
#  'earliest': 6,
#  'site': 10,
#  'users': 18,
#  'share': 9,
#  'information': 14,
#  'established': 8,
#  'among': 8,
#  'sites': 9,
#  'deliver': 3,
#  'authors': 4,
#  'citation': 14,
#  'needed': 21,
#  '1990s': 3,
#  'thousands': 2,
#  'video': 10,
#  'vcrs': 2,
#  'quickly': 7,
#  'potential': 9,
#  'processes': 24,
#  'means': 9,
#  'television': 18,
#  'starring': 2,
#  'bob': 2,
#  'revolution': 9,
#  'show': 8,
#  'conditions': 2,
#  'value': 7,
#  'paying': 2,
#  'work': 45,
#  'network': 14,
#  'cable': 4,
#  'channel': 3,
#  'launched': 7,
#  'united': 19,
#  'states': 15,
#  'canada': 3,
#  'interested': 2,
#  'knitting': 2,
#  'channels': 2,
#  "one's": 5,
#  'budget': 4,
#  'achieve': 2,
#  'results': 7,
#  'design': 75,
#  'etc': 8,
#  'specifically': 2,
#  'beyond': 4,
#  'scope': 7,
#  'continues': 4,
#  'grow': 3,
#  'online': 17,
#  'mainstream': 4,
#  'media': 21,
#  'now': 16,
#  'hometalk': 2,
#  'growth': 6,
#  'independent': 11,
#  'resources': 9,
#  'number': 15,
#  'homeowners': 6,
#  'blog': 2,
#  'experiences': 3,
#  'smaller': 3,
#  'organizations': 16,
#  'amongst': 2,
#  'ideas': 12,
#  'shared': 5,
#  'youtube': 2,
#  'clothing': 4,
#  'jewellery': 2,
#  'styles': 5,
#  'distressing': 4,
#  'jeans': 2,
#  'becoming': 2,
#  'main': 10,
#  'ethic': 4,
#  'maker': 17,
#  'describe': 8,
#  'zines': 5,
#  'london': 3,
#  'self-publishing': 2,
#  'comics': 2,
#  'bands': 6,
#  'artists': 3,
#  'record': 2,
#  'labels': 2,
#  'homemade': 2,
#  'principles': 7,
#  'recycle': 2,
#  'reuse': 2,
#  'reduce': 3,
#  'movements': 4,
#  'encouraging': 2,
#  'objects': 15,
#  'simple': 6,
#  'paper': 6,
#  'sewing': 3,
#  'designing': 4,
#  'business': 15,
#  'cards': 2,
#  'creating': 12,
#  'musical': 8,
#  'merchandise': 2,
#  'recycling': 2,
#  'thrift': 2,
#  'store': 4,
#  'usually': 10,
#  'art': 12,
#  'applied': 10,
#  'screen': 3,
#  'game': 9,
#  'development': 19,
#  'contemporary': 4,
#  'paid': 5,
#  'assistance': 2,
#  'electronic': 26,
#  'circuits': 4,
#  'atari': 3,
#  'console': 3,
#  'create': 19,
#  'circuit': 31,
#  'bending': 19,
#  'noise': 4,
#  'machines': 12,
#  'toys': 4,
#  'products': 23,
#  'allow': 6,
#  'extended': 2,
#  'unintended': 2,
#  'commonly': 8,
#  'referred': 7,
#  'internet': 19,
#  'mods': 2,
#  'littlebits': 2,
#  'science': 12,
#  'open-source': 19,
#  'hardware': 22,
#  'scientific': 3,
#  'simply': 4,
#  'low-cost': 5,
#  'traditional': 11,
#  'arduino': 4,
#  'embedded': 2,
#  'systems': 14,
#  'applications': 14,
#  'robot': 4,
#  'begun': 4,
#  'instead': 10,
#  'audiences': 2,
#  'large': 16,
#  'manufacturing': 51,
#  'wider': 6,
#  'recognition': 2,
#  'gain': 2,
#  'status': 5,
#  'took': 4,
#  'significantly': 3,
#  'musicians': 6,
#  'become': 15,
#  'became': 13,
#  'one': 58,
#  'tutorial': 2,
#  'food': 12,
#  'section': 5,
#  'list': 14,
#  'format': 5,
#  'presented': 2,
#  'prose': 2,
#  'appropriate': 6,
#  'available': 18,
#  'faire': 3,
#  'focus': 7,
#  'andor': 4,
#  'crafting': 4,
#  'informal': 4,
#  'book': 17,
#  'name': 4,
#  'emphasizing': 3,
#  'focusing': 3,
#  'cheap': 2,
#  'anarchist': 6,
#  'collective': 4,
#  'destination': 2,
#  'discussing': 2,
#  'networking': 3,
#  'instructables': 18,
#  'website': 10,
#  'featuring': 2,
#  'tips': 2,
#  'array': 3,
#  'complex': 10,
#  'conferences': 3,
#  'events': 2,
#  'places': 6,
#  'sometimes': 19,
#  'sponsored': 2,
#  'publishing': 4,
#  'technology': 32,
#  'focused': 5,
#  'sustainable': 9,
#  'techshop': 4,
#  'chain': 3,
#  'workshops': 3,
#  'enabling': 3,
#  'levels': 3,
#  'industrial': 13,
#  'topic': 7,
#  'look': 4,
#  'wiktionary': 2,
#  'dictionary': 6,
#  'wikimedia': 2,
#  'commons': 6,
#  'bricolage': 46,
#  'edupunk': 21,
#  'hackerspace': 25,
#  'handyman': 43,
#  'junk': 16,
#  'box': 11,
#  'kludge': 55,
#  'wire': 17,
#  'open': 65,
#  'project': 49,
#  'greenoman': 11,
#  'prosumer': 25,
#  'ready-to-assemble': 9,
#  'furniture': 34,
#  '3d': 142,
#  'printing': 94,
#  'jim': 4,
#  'groom': 4,
#  'teaching': 3,
#  'learning': 12,
#  'practices': 2,
#  'kuntz': 2,
#  'described': 6,
#  'approach': 10,
#  'avoids': 2,
#  'aims': 5,
#  'bring': 4,
#  'classroom': 3,
#  'instructional': 2,
#  'covered': 3,
#  'less': 21,
#  'week': 3,
#  'later': 11,
#  'higher': 7,
#  'stephen': 3,
#  'downes': 3,
#  'journal': 2,
#  'distance': 2,
#  'noted': 5,
#  'concept': 19,
#  'wind': 2,
#  'spreading': 4,
#  'aspects': 8,
#  'examples': 9,
#  'notes': 6,
#  'efforts': 4,
#  'government': 3,
#  'corporate': 8,
#  'interests': 4,
#  'emerging': 4,
#  'technologies': 20,
#  'similar': 20,
#  'reaction': 3,
#  'though': 5,
#  'identified': 3,
#  'three': 4,
#  'against': 3,
#  'commercialization': 2,
#  'thinking': 3,
#  'university': 12,
#  'course': 3,
#  'wikipedia': 6,
#  'murder': 2,
#  'madness': 2,
#  'mayhem': 2,
#  'experiment': 2,
#  'ones': 3,
#  'students': 3,
#  'produced': 9,
#  'hirst': 2,
#  'uk': 2,
#  'june': 7,
#  'adopted': 4,
#  'outside': 6,
#  'set': 6,
#  'australian': 3,
#  'norm': 3,
#  'friesen': 3,
#  'identifies': 2,
#  'possible': 9,
#  'intellectual': 7,
#  'precursors': 3,
#  'hampshire': 2,
#  'college': 5,
#  'state': 2,
#  'new': 56,
#  'student': 2,
#  'voice': 3,
#  'critical': 7,
#  'b': 3,
#  'jargon': 8,
#  'green': 3,
#  'wired': 3,
#  'retrieved': 9,
#  'weblog': 2,
#  'bavatuesdays': 2,
#  '2008-05-28': 2,
#  'introducing': 2,
#  '2008-06-06': 2,
#  '2008-06-16': 2,
#  'virtual': 3,
#  'changing': 3,
#  'expectations': 2,
#  'heritage': 3,
#  'tv': 2,
#  '2009-02-23': 2,
#  'july': 5,
#  'written': 7,
#  'essay': 4,
#  'feelings': 2,
#  'encyclopedic': 2,
#  'april': 2,
#  'person': 6,
#  'produces': 2,
#  'derived': 3,
#  'prosumption': 11,
#  'era': 2,
#  'production': 33,
#  'coined': 5,
#  'futurist': 2,
#  'alvin': 2,
#  'toffler': 7,
#  'writers': 2,
#  'trade': 5,
#  'perspective': 5,
#  'high-end': 2,
#  'devices': 14,
#  'digital': 25,
#  'cameras': 4,
#  'price': 10,
#  'point': 6,
#  'definitions': 2,
#  'origins': 4,
#  'general': 10,
#  'meanings': 5,
#  'relationship': 7,
#  'producer': 8,
#  'non-corporate': 2,
#  'company': 21,
#  'impact': 9,
#  'reception': 2,
#  'adoption': 2,
#  "company's": 3,
#  'd': 12,
#  'blurring': 2,
#  'roles': 3,
#  'producers': 4,
#  'cooperative': 3,
#  'enthusiasts': 4,
#  'buy': 4,
#  'always': 2,
#  'fall': 4,
#  'grade': 2,
#  'standards': 4,
#  'complexity': 7,
#  'refers': 4,
#  'category': 5,
#  'camcorders': 3,
#  'advanced': 6,
#  'features': 9,
#  'increased': 3,
#  'customizing': 2,
#  "toffler's": 3,
#  'sense': 13,
#  'next': 3,
#  'marshall': 2,
#  'today': 7,
#  'electric': 5,
#  'third': 7,
#  'futurologist': 2,
#  'role': 6,
#  'begin': 2,
#  'merge': 2,
#  'shock': 2,
#  'highly': 5,
#  'demands': 2,
#  'continue': 2,
#  'profit': 2,
#  'businesses': 12,
#  'process': 29,
#  'customized': 4,
#  'however': 13,
#  'reach': 5,
#  'high': 8,
#  'especially': 12,
#  'requirements': 8,
#  'extension': 3,
#  'clients': 4,
#  'cases': 4,
#  'primary': 3,
#  "'prosumption": 2,
#  'architecture': 8,
#  'decentralization': 3,
#  'agency': 2,
#  "imperative'": 2,
#  'well': 25,
#  'recently': 7,
#  'works': 11,
#  'wealth': 5,
#  'fact': 7,
#  'seen': 8,
#  'felt': 2,
#  'worldwide': 2,
#  'scale': 4,
#  'global': 12,
#  'particular': 8,
#  'china': 5,
#  'gingrich': 2,
#  'c-span': 3,
#  'program': 7,
#  'mentioned': 3,
#  'second': 5,
#  'behind': 2,
#  'don': 2,
#  'tapscott': 2,
#  'economy': 5,
#  'despite': 3,
#  'several': 11,
#  'full': 3,
#  'theoretical': 2,
#  'george': 2,
#  'claim': 3,
#  'characteristic': 4,
#  'prosumers': 3,
#  'companies': 11,
#  'wages': 2,
#  'place': 8,
#  'areas': 3,
#  'industry': 7,
#  'years': 8,
#  'choices': 2,
#  'stores': 3,
#  'ways': 5,
#  'sold': 2,
#  'names': 3,
#  'giving': 3,
#  'recorded': 5,
#  'fast': 4,
#  'indeed': 2,
#  'generally': 15,
#  'going': 2,
#  'effort': 5,
#  'myriad': 2,
#  'choice': 4,
#  'producing': 4,
#  'still': 10,
#  'key': 5,
#  'area': 11,
#  'taking': 3,
#  'hobbyists': 4,
#  "today's": 2,
#  'team': 2,
#  'field': 5,
#  'energy': 14,
#  'households': 2,
#  'times': 4,
#  'surplus': 3,
#  'fuel': 3,
#  'feed': 2,
#  'national': 13,
#  'distribution': 10,
#  'consume': 2,
#  'grid': 4,
#  'done': 10,
#  'panels': 2,
#  'generating': 3,
#  'electricity': 2,
#  'gas': 2,
#  'european': 7,
#  'innovation': 6,
#  'programme': 2,
#  'leisure': 2,
#  'pursuits': 3,
#  'initial': 6,
#  'combination': 2,
#  'pair': 2,
#  'hobbies': 3,
#  'rising': 2,
#  'level': 2,
#  'amateur': 7,
#  'interest': 4,
#  'rather': 17,
#  'profession': 2,
#  'serious': 3,
#  'rise': 2,
#  'cooking': 3,
#  'creation': 5,
#  'dedicated': 5,
#  'photography': 2,
#  'trends': 6,
#  'factors': 5,
#  'disposable': 2,
#  'sectors': 5,
#  'prices': 5,
#  'ever': 3,
#  'towards': 2,
#  'amateurs': 4,
#  'beginning': 10,
#  '1980s': 3,
#  'advent': 5,
#  'desktop': 6,
#  'forums': 3,
#  'pool': 4,
#  'experience': 7,
#  'considered': 4,
#  'fence': 2,
#  'lower': 3,
#  'form': 14,
#  'bells': 2,
#  'expanded': 2,
#  'philip': 3,
#  'kotler': 3,
#  'saw': 3,
#  'challenge': 2,
#  'anticipated': 2,
#  'will': 22,
#  'want': 2,
#  'play': 7,
#  'larger': 2,
#  'certain': 7,
#  'goods': 3,
#  'services': 12,
#  'furthermore': 2,
#  'forces': 2,
#  'lead': 6,
#  'developed': 16,
#  'szymusiak': 3,
#  'two': 14,
#  'marketing': 6,
#  'politics': 4,
#  'schools': 6,
#  'thought': 4,
#  'black': 3,
#  'feminist': 3,
#  'infoanarchism': 2,
#  'philosophical': 2,
#  'theory': 3,
#  'practice': 8,
#  'class': 4,
#  'struggle': 3,
#  'democracy': 3,
#  'deep': 2,
#  'ecology': 4,
#  'power': 7,
#  'association': 2,
#  'law': 3,
#  'mutual': 2,
#  'participatory': 3,
#  'autonomous': 2,
#  'zone': 2,
#  'center': 8,
#  'spontaneous': 3,
#  'order': 10,
#  'squatting': 2,
#  'temporary': 5,
#  'union': 4,
#  'm': 5,
#  'peter': 2,
#  'colin': 2,
#  ...}

# %% [markdown]
# ### 7.4 Set of terms/words that occure in both corpus.

# %%
common_words = [w for w in input_freq_dist.keys() & english_freq_dist.keys()]
print(len(common_words))
# Out:
# 1945

# %%
for w in common_words: print(w)
# Out:
# print
# marketplace
# covered
# appeared
# notable
# manuals
# consumer
# british
# thing
# concept
# controlled
# minutes
# interest
# resource
# evolved
# paint
# french
# spurred
# diminutive
# phrase
# contact
# especially
# chip
# catalog
# hardware
# layer
# employment
# acquisition
# do-it-yourself
# knowledge
# easy
# translation
# message
# works
# damage
# topic
# done
# corner
# students
# architectural
# advertise
# opened
# sometimes
# rigorous
# asking
# computers
# assessment
# materials
# corporate
# build
# estimates
# thin
# based
# tech
# drywall
# three-dimensional
# nature
# august
# producer
# overall
# along
# drives
# biggest
# ask
# characters
# art
# dictionary
# vehicles
# company
# solving
# technician
# explain
# apollo
# texts
# quickly
# collage
# repeated
# murray
# cure
# asked
# model
# due
# danish
# flat
# tips
# majority
# refer
# will
# wanting
# filed
# meetings
# children's
# women
# studies
# presses
# leave
# leading
# thinking
# need
# motors
# sex
# grow
# price
# operators
# types
# tangible
# either
# operating
# france
# industry
# november
# firms
# volunteer
# consistent
# solve
# manner
# items
# launch
# variety
# seems
# local
# reason
# feelings
# schools
# definitions
# act
# authors
# korea
# audiences
# le
# section
# greece
# brazil
# successfully
# launched
# described
# want
# uses
# fencing
# pattern
# getting
# rapid
# jersey
# interior
# national
# different
# crown
# electronic
# requirements
# recorded
# techniques
# russian
# precision
# henry
# principles
# particles
# via
# old
# variation
# difficult
# therefore
# tree
# present
# editor
# manufacturing
# term
# areas
# earth
# door
# turns
# repairs
# company's
# middle
# earn
# offer
# place
# swedish
# job
# pressure
# date
# stephen
# perhaps
# concluded
# international
# factors
# projects
# foods
# retrieved
# image
# last
# novel
# states
# influence
# articles
# effective
# amateur
# another
# adding
# office
# generally
# function
# machines
# drill
# anticipated
# book
# negative
# address
# quoted
# clients
# electronics
# 1950s
# criteria
# design
# aerospace
# best
# tax
# initiated
# ship
# convinced
# tyranny
# campaign
# theme
# added
# additional
# origin
# injury
# sharing
# public
# september
# entry
# support
# trucks
# distressing
# marginal
# system
# believes
# real
# achieved
# efforts
# description
# language
# mentioned
# manned
# larger
# chain
# equipment
# feature
# primarily
# pioneered
# godwin
# working
# lab
# featuring
# merge
# accept
# proper
# channel
# describe
# technology
# films
# shown
# came
# everyday
# worst
# suggesting
# satisfy
# laws
# skilled
# enabled
# raw
# museum
# screws
# questions
# literature
# usage
# products
# say
# within
# australian
# dedicated
# leisure
# vienna
# physically
# one's
# law
# terminology
# circuits
# factory
# gas
# productive
# points
# tv
# pro
# enable
# connecting
# content
# publishers
# saving
# time
# 14
# prizes
# devices
# physical
# equivalent
# light
# musical
# advent
# given
# identifies
# assistance
# founded
# restricted
# series
# associated
# issues
# carnegie
# prose
# philip
# users
# paper
# entered
# definition
# plastic
# groups
# individualism
# discussing
# environment
# forming
# green
# buildings
# showed
# planning
# routine
# beginning
# components
# true
# widespread
# hobbies
# class
# key
# new
# spending
# activities
# topics
# contrast
# profits
# unlike
# broad
# management
# modifying
# us
# crafts
# learned
# bridge
# projected
# daily
# position
# countries
# future
# distribution
# encouraging
# meet
# far
# begin
# germany
# increasingly
# emphasizing
# nothing
# transform
# trial
# courts
# room
# improvements
# spread
# professional
# cards
# item
# mechanisms
# minds
# perform
# facilitate
# named
# transaction
# avoids
# plantation
# collaboration
# marketing
# mechanics
# gun
# seen
# released
# preferred
# identify
# britain
# philosophical
# least
# capabilities
# spell
# cheap
# must
# generators
# article
# problems
# u
# needs
# environmental
# cabinets
# hot
# dates
# repair
# fast
# include
# allowing
# vapor
# broader
# identity
# printed
# jury
# greek
# challenge
# market
# check
# successful
# drawn
# major
# role
# included
# finish
# toys
# replacement
# quite
# george
# portal
# status
# keeping
# every
# fix
# friends
# hill
# resolution
# goods
# personnel
# portion
# movable
# standards
# direct
# cleaning
# good
# economics
# character
# willingness
# set
# homemade
# around
# develop
# suggested
# rate
# change
# two
# registered
# today's
# rising
# dots
# whether
# licensing
# owner
# designers
# '
# shared
# returned

# %% [markdown]
# ### 7.5 Set of terms/words that occure in the sample but not in the reference corpus.

# %% [markdown]
# TO BE EXAMINED: This specific set needs to be incorporated. In fact, it may capture specifity of the content to a great extend. We need to assign a mapping score for each words in this set.

# %%
input_specifics = dict()
for w in input_freq_dist.keys() - english_freq_dist.keys():
    input_specifics[w] = input_freq_dist[w]
    print(w)
# Out:
# hridith
# edupunk
# automated
# inventora
# regimes
# uk
# lvi-strauss
# handymen
# cognitive
# marxism
# ccc
# photopolymerization
# websites
# precursors
# matured
# kuntz
# incorporating
# verifying
# commercialization
# grid
# prosumers
# uv
# libertarian
# armand
# repairing
# downes
# implants
# bavatuesdays
# left-wing
# anarcho-capitalism
# freethought
# manufactures
# nepal
# improvisation
# neuroscience
# synthesizers
# computer-aided
# c-base
# andor
# kit
# dpi
# 'kluge'
# cf
# bricoleur
# threeding
# comics
# multilingual
# high-end
# day'
# app
# bahrain
# wikihow
# xinchejian
# 2008-06-16
# hometalk
# moulding
# blurring
# abs
# redirects
# metalworking
# hackspace
# knockdown
# autodesk
# toffler's
# handyman
# actuators
# forums
# innovators
# infrastructure
# disambiguation
# matrix
# copyright
# remodeling
# youtube
# recycled
# amf
# zine
# desktop
# szymusiak
# ikea
# metalab
# amateurs
# ip
# collaborate
# commercialized
# datamation
# logo
# trash
# fix-up
# granholm
# top-down
# worldwide
# informational
# robot
# welding
# 2009-02-23
# camcorders
# recycling
# acronym
# recycle
# sprinkler
# self-correcting
# dr
# manifesto
# workspace
# hackerspace
# mainstream
# josiah
# overcomplicated
# anarchists
# transistor
# faire
# retrieve
# dhofar
# ceo
# x-y
# geometrical
# feeder
# docking
# jugaad
# autonomous
# colin
# disposable
# cad
# recombine
# turkle
# knobs
# blog
# 2010s
# copying
# pgwi
# weick
# thingiverse
# wiring
# medium-level
# arduino
# mayhem
# non-corporate
# diy
# overview
# kludges
# kludged
# how-tos
# fiberglass
# commentators
# leone
# prgrom
# mid-1990s
# jetting
# bc
# options
# mit
# knitting
# jeffrey
# unsourced
# toffler
# sudev
# costa
# customization
# ready-to-assemble
# hobbyists
# programme
# instructables
# cleanup
# manny
# spooner
# sierra
# professionalism
# spence
# littlebits
# households
# open-source
# co-creation
# sub-cultures
# friesen
# org
# handyman's
# klug
# wikipedia
# thoreau
# clod
# indie
# tutorial
# displacing
# powertrain
# wikimedia
# citations
# prosumption
# mods
# bricolage
# madness
# atari
# gemini
# g-code
# software
# etc
# futurologist
# wiki
# categorized
# agile
# emissions
# community-operated
# console
# uganda
# makerbot
# consumer-oriented
# widgets
# advocates
# kerala
# stylistic
# wiki-based
# participatory
# inline
# solidified
# modeling
# inkjet
# encyclopedic
# complementing
# photopolymer
# greenworld
# actuator
# copyrightable
# 'prosumption
# jeans
# payers
# vatakara
# oman
# openbook
# online
# website
# feminism
# internet
# labor-intensive
# pastiche
# rio20
# buyer
# sustainable
# printers
# reclamation
# workaround
# stereolithography
# overhanging
# fdm
# binder
# pronounce
# lifestylism
# kraakdoos
# reprap
# transforming
# kluhj
# sanchez-burks
# supercar
# targeted
# patio
# tmrc
# how-to
# collaborative
# word's
# foldoc
# hackerspaces
# airlock
# bender
# clips
# gingrich
# pronunciation
# contractors
# rica
# oman's
# filament
# tinker
# techshop
# fabricated
# greenoman
# self-ownership
# isbn
# michel
# knock-down
# high-tech
# jewellery
# toolroom
# homebrewing
# decentralization
# landscaping
# cnc
# reuse
# affordable
# 1990s
# commons-based
# printable
# brandtjen
# stirner
# zines
# granules
# leaky
# on-demand
# haphazard
# 3d
# unintended
# rothbard
# globalization
# tinkering
# prosumers'
# flatpack
# timelapse
# update
# basements
# greenindia
# anarchist
# slang
# hobbyist
# sws
# burling
# genetically
# hackers
# poorly-matching
# kotler
# fiona
# ii
# gutter
# wiggles
# squid
# branding
# sintering
# ghazala
# customized
# anarchism
# admiral
# electrocution
# wiktionary
# module
# sustainability
# end-users
# hacker
# handiwork
# prototyping
# punk
# polymer
# macgyver
# 1970s
# etymology
# home-improvement
# prosumer
# granholm's
# wipers
# kincheloe
# honours
# ac
# networking
# potentiometers
# woodworking
# airbus
# hams
# 2008-06-06
# friedrich
# starring
# 2008-05-28
# homebrewers
# capacitors
# inelegant
# kluges
# 1980s
# technologies
# funding
# murgatroyd
# 1960s
# vernacular
# crock
# audio
# typesetting
# pronunciations
# anthropologist
# samved
# shaji
# redirected
# kluge
# mid-1950s
# nigeria
# municipality
# klooj
# labs
# feminist
# kludge
# subculture
# self-publishing
# laptop
# open-design
# academics
# infoanarchism
# skylab
# anarcho-punk
# customizing
# fix-it
# fasteners
# lysander
# tapscott
# imperative'
# crafting
# futurist
# inc
# adjective
# taipei
# o'reilly
# goldman
# ill-assorted
# c-span
# for-profit
# empowerment
# makerspace
# video
# homeowner
# egoist
# faq
# ecology
# stl
# gel
# laser
# machining
# 's
# hirst
# genre
# atm
# phineas
# salalah
# subtractive
# step-by-step
# bolts
# libertarianism
# indymedia
# implemented
# shanghai
# extrusion
# manipulating
# makerspaces
# fab
# tiling
# beijing
# raumzeitlabor
# consume
# vcrs
# etymologies
# weblog

# %%
print(len(input_specifics))
# Out:
# 441

# %% [markdown]
# ## 8. Stemming (in case needed)

# %%
from nltk.stem.porter import PorterStemmer
stemmer = PorterStemmer()
for k,v in input_freq_dist.items():
    stemmed = stemmer.stem(k)
    if stemmed != k: print(k, "->", stemmed)
# Out:
# uses -> use
# disambiguation -> disambigu
# redirects -> redirect
# article -> articl
# multiple -> multipl
# issues -> issu
# please -> pleas
# improve -> improv
# remove -> remov
# template -> templat
# possibly -> possibl
# contains -> contain
# original -> origin
# verifying -> verifi
# claims -> claim
# adding -> ad
# inline -> inlin
# citations -> citat
# statements -> statement
# consisting -> consist
# removed -> remov
# november -> novemb
# message -> messag
# needs -> need
# additional -> addit
# verification -> verif
# reliable -> reliabl
# sources -> sourc
# unsourced -> unsourc
# material -> materi
# challenged -> challeng
# september -> septemb
# series -> seri
# individualism -> individu
# topics -> topic
# concepts -> concept
# autonomy -> autonomi
# rights -> right
# individual -> individu
# reclamation -> reclam
# liberty -> liberti
# negative -> neg
# personal -> person
# property -> properti
# positive -> posit
# private -> privat
# lysander -> lysand
# henry -> henri
# james -> jame
# anarchism -> anarch
# anarcho-capitalism -> anarcho-capit
# liberalism -> liber
# feminism -> femin
# left-wing -> left-w
# libertarianism -> libertarian
# socialism -> social
# mentality -> mental
# society -> societi
# engineering -> engin
# tyranny -> tyranni
# majority -> major
# building -> build
# texas -> texa
# security -> secur
# administration -> administr
# modifying -> modifi
# repairing -> repair
# things -> thing
# experts -> expert
# professionals -> profession
# academic -> academ
# describes -> describ
# individuals -> individu
# engage -> engag
# materials -> materi
# component -> compon
# parts -> part
# produce -> produc
# including -> includ
# natural -> natur
# environment -> environ
# landscaping -> landscap
# various -> variou
# motivations -> motiv
# previously -> previous
# categorized -> categor
# marketplace -> marketplac
# economic -> econom
# benefits -> benefit
# availability -> avail
# quality -> qualiti
# customization -> custom
# identity -> ident
# empowerment -> empower
# community -> commun
# associated -> associ
# consumers -> consum
# since -> sinc
# primarily -> primarili
# improvement -> improv
# maintenance -> mainten
# activities -> activ
# usage -> usag
# 1950s -> 1950
# reference -> refer
# emergence -> emerg
# people -> peopl
# construction -> construct
# projects -> project
# activity -> activ
# subsequently -> subsequ
# meaning -> mean
# covers -> cover
# range -> rang
# sets -> set
# international -> intern
# alternative -> altern
# indie -> indi
# scenes -> scene
# networks -> network
# pirate -> pirat
# related -> relat
# arts -> art
# crafts -> craft
# consumer -> consum
# culture -> cultur
# relying -> reli
# others -> other
# satisfy -> satisfi
# widely -> wide
# used -> use
# military -> militari
# types -> type
# units -> unit
# able -> abl
# preparation -> prepar
# future -> futur
# subculture -> subcultur
# groups -> group
# publications -> public
# structure -> structur
# italy -> itali
# assembly -> assembl
# instructions -> instruct
# called -> call
# city -> citi
# century -> centuri
# example -> exampl
# marks -> mark
# looks -> look
# someone -> someon
# components -> compon
# together -> togeth
# instruction -> instruct
# sections -> section
# showing -> show
# pieces -> piec
# architectural -> architectur
# evidence -> evid
# suggested -> suggest
# decoration -> decor
# shelves -> shelv
# vehicle -> vehicl
# skills -> skill
# house -> hous
# making -> make
# clothes -> cloth
# cars -> car
# computers -> comput
# websites -> websit
# living -> live
# discussion -> discuss
# edition -> edit
# reflected -> reflect
# growing -> grow
# educational -> educ
# nothing -> noth
# words -> word
# houses -> hous
# fundamental -> fundament
# education -> educ
# entirely -> entir
# terms -> term
# insurance -> insur
# character -> charact
# 1970s -> 1970
# population -> popul
# involved -> involv
# affordable -> afford
# homes -> home
# environmental -> environment
# 1960s -> 1960
# early -> earli
# working -> work
# friends -> friend
# family -> famili
# initially -> initi
# using -> use
# typesetting -> typeset
# tools -> tool
# published -> publish
# techniques -> techniqu
# definition -> definit
# informational -> inform
# books -> book
# technical -> technic
# nature -> natur
# professional -> profession
# journals -> journal
# courses -> cours
# classes -> class
# specialized -> special
# designed -> design
# items -> item
# welding -> weld
# equipment -> equip
# designer -> design
# include -> includ
# writing -> write
# many -> mani
# reviews -> review
# publication -> public
# emerged -> emerg
# spurred -> spur
# attitude -> attitud
# cross-section -> cross-sect
# influence -> influenc
# decades -> decad
# magazines -> magazin
# mechanics -> mechan
# illustrated -> illustr
# readers -> reader
# useful -> use
# practical -> practic
# created -> creat
# collections -> collect
# magazine -> magazin
# articles -> articl
# extensive -> extens
# based -> base
# publishers -> publish
# followed -> follow
# electronics -> electron
# assembled -> assembl
# amplifier -> amplifi
# mid-1990s -> mid-1990
# home-improvement -> home-improv
# users -> user
# information -> inform
# established -> establish
# sites -> site
# deliver -> deliv
# authors -> author
# citation -> citat
# needed -> need
# 1990s -> 1990
# thousands -> thousand
# vcrs -> vcr
# quickly -> quickli
# potential -> potenti
# processes -> process
# means -> mean
# television -> televis
# starring -> star
# revolution -> revolut
# conditions -> condit
# value -> valu
# paying -> pay
# cable -> cabl
# launched -> launch
# united -> unit
# states -> state
# interested -> interest
# knitting -> knit
# channels -> channel
# one's -> one'
# achieve -> achiev
# results -> result
# specifically -> specif
# continues -> continu
# online -> onlin
# independent -> independ
# resources -> resourc
# homeowners -> homeown
# experiences -> experi
# organizations -> organ
# ideas -> idea
# shared -> share
# youtube -> youtub
# clothing -> cloth
# jewellery -> jewelleri
# styles -> style
# distressing -> distress
# jeans -> jean
# becoming -> becom
# describe -> describ
# zines -> zine
# self-publishing -> self-publish
# comics -> comic
# bands -> band
# artists -> artist
# labels -> label
# homemade -> homemad
# principles -> principl
# recycle -> recycl
# reuse -> reus
# reduce -> reduc
# movements -> movement
# encouraging -> encourag
# objects -> object
# simple -> simpl
# sewing -> sew
# designing -> design
# business -> busi
# cards -> card
# creating -> creat
# musical -> music
# merchandise -> merchandis
# recycling -> recycl
# usually -> usual
# applied -> appli
# development -> develop
# contemporary -> contemporari
# assistance -> assist
# electronic -> electron
# circuits -> circuit
# console -> consol
# create -> creat
# bending -> bend
# noise -> nois
# machines -> machin
# toys -> toy
# products -> product
# extended -> extend
# unintended -> unintend
# commonly -> commonli
# referred -> refer
# mods -> mod
# littlebits -> littlebit
# science -> scienc
# open-source -> open-sourc
# hardware -> hardwar
# scientific -> scientif
# simply -> simpli
# traditional -> tradit
# embedded -> embed
# systems -> system
# applications -> applic
# audiences -> audienc
# large -> larg
# manufacturing -> manufactur
# recognition -> recognit
# status -> statu
# significantly -> significantli
# musicians -> musician
# become -> becom
# became -> becam
# tutorial -> tutori
# presented -> present
# appropriate -> appropri
# available -> avail
# faire -> fair
# focus -> focu
# crafting -> craft
# informal -> inform
# emphasizing -> emphas
# focusing -> focus
# collective -> collect
# destination -> destin
# discussing -> discuss
# networking -> network
# instructables -> instruct
# website -> websit
# featuring -> featur
# tips -> tip
# conferences -> confer
# events -> event
# places -> place
# sometimes -> sometim
# sponsored -> sponsor
# publishing -> publish
# technology -> technolog
# focused -> focus
# sustainable -> sustain
# workshops -> workshop
# enabling -> enabl
# levels -> level
# industrial -> industri
# wiktionary -> wiktionari
# dictionary -> dictionari
# commons -> common
# bricolage -> bricolag
# hackerspace -> hackerspac
# kludge -> kludg
# prosumer -> prosum
# ready-to-assemble -> ready-to-assembl
# furniture -> furnitur
# printing -> print
# teaching -> teach
# learning -> learn
# practices -> practic
# described -> describ
# avoids -> avoid
# aims -> aim
# instructional -> instruct
# covered -> cover
# downes -> down
# distance -> distanc
# noted -> note
# spreading -> spread
# aspects -> aspect
# examples -> exampl
# notes -> note
# efforts -> effort
# government -> govern
# corporate -> corpor
# interests -> interest
# emerging -> emerg
# technologies -> technolog
# identified -> identifi
# commercialization -> commerci
# thinking -> think
# university -> univers
# course -> cours
# madness -> mad
# experiment -> experi
# ones -> one
# students -> student
# produced -> produc
# adopted -> adopt
# outside -> outsid
# identifies -> identifi
# possible -> possibl
# intellectual -> intellectu
# precursors -> precursor
# hampshire -> hampshir
# college -> colleg
# voice -> voic
# critical -> critic
# wired -> wire
# retrieved -> retriev
# bavatuesdays -> bavatuesday
# introducing -> introduc
# changing -> chang
# expectations -> expect
# heritage -> heritag
# july -> juli
# feelings -> feel
# encyclopedic -> encycloped
# produces -> produc
# derived -> deriv
# prosumption -> prosumpt
# production -> product
# coined -> coin
# writers -> writer
# perspective -> perspect
# devices -> devic
# digital -> digit
# cameras -> camera
# definitions -> definit
# origins -> origin
# general -> gener
# meanings -> mean
# producer -> produc
# non-corporate -> non-corpor
# company -> compani
# reception -> recept
# adoption -> adopt
# company's -> company'
# blurring -> blur
# roles -> role
# producers -> produc
# cooperative -> cooper
# enthusiasts -> enthusiast
# always -> alway
# standards -> standard
# complexity -> complex
# refers -> refer
# category -> categori
# camcorders -> camcord
# advanced -> advanc
# features -> featur
# increased -> increas
# customizing -> custom
# toffler's -> toffler'
# sense -> sens
# marshall -> marshal
# electric -> electr
# merge -> merg
# highly -> highli
# demands -> demand
# continue -> continu
# businesses -> busi
# customized -> custom
# however -> howev
# especially -> especi
# requirements -> requir
# extension -> extens
# clients -> client
# cases -> case
# primary -> primari
# 'prosumption -> 'prosumpt
# architecture -> architectur
# decentralization -> decentr
# agency -> agenc
# recently -> recent
# works -> work
# worldwide -> worldwid
# mentioned -> mention
# economy -> economi
# despite -> despit
# several -> sever
# theoretical -> theoret
# george -> georg
# characteristic -> characterist
# prosumers -> prosum
# companies -> compani
# wages -> wage
# areas -> area
# industry -> industri
# years -> year
# choices -> choic
# stores -> store
# ways -> way
# names -> name
# giving -> give
# recorded -> record
# indeed -> inde
# generally -> gener
# going -> go
# choice -> choic
# producing -> produc
# taking -> take
# hobbyists -> hobbyist
# today's -> today'
# energy -> energi
# households -> household
# times -> time
# surplus -> surplu
# national -> nation
# distribution -> distribut
# consume -> consum
# panels -> panel
# generating -> gener
# electricity -> electr
# gas -> ga
# innovation -> innov
# programme -> programm
# leisure -> leisur
# pursuits -> pursuit
# initial -> initi
# combination -> combin
# hobbies -> hobbi
# rising -> rise
# profession -> profess
# serious -> seriou
# cooking -> cook
# dedicated -> dedic
# photography -> photographi
# trends -> trend
# factors -> factor
# disposable -> dispos
# sectors -> sector
# prices -> price
# towards -> toward
# amateurs -> amateur
# beginning -> begin
# 1980s -> 1980
# forums -> forum
# experience -> experi
# considered -> consid
# fence -> fenc
# bells -> bell
# expanded -> expand
# challenge -> challeng
# anticipated -> anticip
# goods -> good
# services -> servic
# furthermore -> furthermor
# forces -> forc
# developed -> develop
# marketing -> market
# politics -> polit
# schools -> school
# infoanarchism -> infoanarch
# philosophical -> philosoph
# theory -> theori
# practice -> practic
# struggle -> struggl
# democracy -> democraci
# ecology -> ecolog
# association -> associ
# participatory -> participatori
# autonomous -> autonom
# spontaneous -> spontan
# squatting -> squat
# temporary -> temporari
# lifestylism -> lifestyl
# violence -> violenc
# conference -> confer
# incident -> incid
# republic -> republ
# europe -> europ
# france -> franc
# days -> day
# triangle -> triangl
# collection -> collect
# library -> librari
# carnival -> carniv
# capital -> capit
# seattle -> seattl
# films -> film
# masters -> master
# radical -> radic
# glossary -> glossari
# economics -> econom
# really -> realli
# germany -> germani
# greece -> greec
# lists -> list
# communities -> commun
# fictional -> fiction
# characters -> charact
# anarchists -> anarchist
# communism -> commun
# thus -> thu
# profits -> profit
# reduced -> reduc
# supplying -> suppli
# consumer-oriented -> consumer-ori
# diminished -> diminish
# income -> incom
# globalization -> global
# automation -> autom
# integrate -> integr
# end-users -> end-us
# instance -> instanc
# integrated -> integr
# strengthened -> strengthen
# customer -> custom
# increasingly -> increasingli
# utilizing -> util
# parties -> parti
# allows -> allow
# software -> softwar
# update -> updat
# collaboration -> collabor
# changes -> chang
# increase -> increas
# sharing -> share
# terminology -> terminolog
# source -> sourc
# creates -> creat
# successful -> success
# operating -> oper
# capabilities -> capabl
# goals -> goal
# playing -> play
# instruments -> instrument
# listening -> listen
# creative -> creativ
# generated -> gener
# developing -> develop
# nations -> nation
# aware -> awar
# investments -> invest
# plus -> plu
# waste -> wast
# taxes -> tax
# comes -> come
# wants -> want
# supply -> suppli
# serve -> serv
# payers -> payer
# different -> differ
# locally -> local
# asking -> ask
# service -> servic
# resource -> resourc
# manipulating -> manipul
# spending -> spend
# directly -> directli
# manufacturer -> manufactur
# widgets -> widget
# customers -> custom
# important -> import
# seriously -> serious
# solve -> solv
# specific -> specif
# effects -> effect
# immediate -> immedi
# meets -> meet
# willingness -> willing
# commons-based -> commons-bas
# episode -> episod
# december -> decemb
# sustainability -> sustain
# solutions -> solut
# studying -> studi
# values -> valu
# descriptions -> descript
# wiki-based -> wiki-bas
# guides -> guid
# manuals -> manual
# description -> descript
# leave -> leav
# overall -> overal
# entitled -> entitl
# perhaps -> perhap
# genre -> genr
# carnegie -> carnegi
# existed -> exist
# tradition -> tradit
# generation -> gener
# languages -> languag
# invented -> invent
# learned -> learn
# traditions -> tradit
# eventually -> eventu
# broadened -> broaden
# forming -> form
# printed -> print
# texts -> text
# painting -> paint
# swimming -> swim
# easily -> easili
# everyone -> everyon
# consistent -> consist
# documentation -> document
# another -> anoth
# makes -> make
# necessarily -> necessarili
# how-tos -> how-to
# history -> histori
# knowledge -> knowledg
# added -> ad
# methods -> method
# imparted -> impart
# guide -> guid
# bridge -> bridg
# damage -> damag
# solution -> solut
# clumsy -> clumsi
# inelegant -> ineleg
# inefficient -> ineffici
# diverse -> divers
# fields -> field
# computer -> comput
# aerospace -> aerospac
# evolutionary -> evolutionari
# neuroscience -> neurosci
# pronunciation -> pronunci
# etymology -> etymolog
# surname -> surnam
# industries -> industri
# alternate -> altern
# pronunciations -> pronunci
# proposed -> propos
# etymologies -> etymolog
# entry -> entri
# cites -> cite
# word's -> word'
# granholm's -> granholm'
# appeared -> appear
# datamation -> datam
# invention -> invent
# ill-assorted -> ill-assort
# poorly-matching -> poorly-match
# computing -> comput
# machine -> machin
# improvised -> improvis
# poorly -> poorli
# phineas -> phinea
# burling -> burl
# wiggles -> wiggl
# multilingual -> multilingu
# according -> accord
# language -> languag
# originally -> origin
# typical -> typic
# leading -> lead
# forms -> form
# stands -> stand
# handy -> handi
# application -> applic
# anyone -> anyon
# adjective -> adject
# following -> follow
# reasons -> reason
# equivalent -> equival
# speakers -> speaker
# variation -> variat
# derive -> deriv
# engineers -> engin
# includes -> includ
# kludges -> kludg
# applying -> appli
# programmer -> programm
# maintained -> maintain
# spelling -> spell
# confused -> confus
# kludged -> kludg
# device -> devic
# programming -> program
# involves -> involv
# something -> someth
# routine -> routin
# probably -> probabl
# feature -> featur
# implemented -> implement
# reported -> report
# mid-1950s -> mid-1950
# exclusively -> exclus
# kluges -> kluge
# gives -> give
# jury -> juri
# navy -> navi
# piece -> piec
# worked -> work
# folklore -> folklor
# quarterly -> quarterli
# story -> stori
# overcomplicated -> overcompl
# dates -> date
# complete -> complet
# quoted -> quot
# wanting -> want
# ignorant -> ignor
# asked -> ask
# actually -> actual
# makers -> maker
# reached -> reach
# admiral -> admir
# returned -> return
# interesting -> interest
# condition -> condit
# hackers -> hacker
# pronounce -> pronounc
# mostly -> mostli
# restricted -> restrict
# convinced -> convinc
# named -> name
# presses -> press
# fledgling -> fledgl
# brothers -> brother
# automatic -> automat
# allowed -> allow
# continued -> continu
# active -> activ
# seems -> seem
# mechanical -> mechan
# connection -> connect
# points -> point
# likely -> like
# tended -> tend
# diminutive -> diminut
# separate -> separ
# enable -> enabl
# manufactured -> manufactur
# movie -> movi
# sws -> sw
# vehicles -> vehicl
# module -> modul
# position -> posit
# docking -> dock
# recycled -> recycl
# managed -> manag
# manned -> man
# historical -> histor
# fixing -> fix
# properties -> properti
# change -> chang
# introduced -> introduc
# essentially -> essenti
# expected -> expect
# intimate -> intim
# typically -> typic
# required -> requir
# consequence -> consequ
# slightly -> slightli
# internal -> intern
# wires -> wire
# increasing -> increas
# electrical -> electr
# translation -> translat
# inside -> insid
# particularly -> particularli
# discusses -> discuss
# cognitive -> cognit
# every -> everi
# pastiche -> pastich
# turns -> turn
# wipers -> wiper
# gets -> get
# wiring -> wire
# genetically -> genet
# unprecedented -> unpreced
# macgyver -> macgyv
# replacement -> replac
# philosophy -> philosophi
# academics -> academ
# literature -> literatur
# cultural -> cultur
# studies -> studi
# psychology -> psycholog
# improvisation -> improvis
# humming -> hum
# drums -> drum
# storage -> storag
# bicycle -> bicycl
# unusual -> unusu
# automotive -> automot
# stylistic -> stylist
# writes -> write
# sub-cultures -> sub-cultur
# experimentation -> experiment
# daily -> daili
# pioneers -> pioneer
# artistic -> artist
# limited -> limit
# remote -> remot
# financially -> financi
# commercial -> commerci
# unlike -> unlik
# necessary -> necessari
# training -> train
# creativity -> creativ
# careful -> care
# observation -> observ
# welcome -> welcom
# trusting -> trust
# self-correcting -> self-correct
# structures -> structur
# targeted -> target
# technique -> techniqu
# constructed -> construct
# collage -> collag
# strategy -> strategi
# players -> player
# spaces -> space
# designers -> design
# unique -> uniqu
# buildings -> build
# suggesting -> suggest
# identities -> ident
# safety -> safeti
# psychological -> psycholog
# problems -> problem
# unrelated -> unrel
# already -> alreadi
# sanchez-burks -> sanchez-burk
# disciplines -> disciplin
# claude -> claud
# societies -> societi
# retrieve -> retriev
# recombine -> recombin
# therefore -> therefor
# patterns -> pattern
# opposed -> oppos
# discourse -> discours
# calls -> call
# identify -> identifi
# solving -> solv
# trying -> tri
# testing -> test
# kincheloe -> kinchelo
# denote -> denot
# employed -> employ
# foundation -> foundat
# researchers -> research
# rigorous -> rigor
# provide -> provid
# sophisticated -> sophist
# understanding -> understand
# capable -> capabl
# sis -> si
# competitive -> competit
# advantage -> advantag
# tinkering -> tinker
# allowing -> allow
# turkle -> turkl
# workspace -> workspac
# productivity -> product
# advocates -> advoc
# conventional -> convent
# variety -> varieti
# enables -> enabl
# fully -> fulli
# tasks -> task
# successfully -> success
# served -> serv
# incorporating -> incorpor
# purposes -> purpos
# candy -> candi
# immediately -> immedi
# children's -> children'
# weapons -> weapon
# operators -> oper
# hams -> ham
# resistors -> resistor
# capacitors -> capacitor
# screws -> screw
# nuts -> nut
# bolts -> bolt
# homebrewers -> homebrew
# boxes -> box
# homebrewing -> homebrew
# keeping -> keep
# provides -> provid
# repairs -> repair
# removing -> remov
# quantities -> quantiti
# treasure -> treasur
# tracking -> track
# commercially -> commerci
# gauge -> gaug
# entered -> enter
# preferred -> prefer
# fencing -> fenc
# evolved -> evolv
# ability -> abil
# machinery -> machineri
# officially -> offici
# completed -> complet
# requires -> requir
# packaged -> packag
# addition -> addit
# saving -> save
# assemble -> assembl
# selling -> sell
# expensive -> expens
# factory -> factori
# fasteners -> fasten
# purchased -> purchas
# advantages -> advantag
# easy -> easi
# chinese -> chines
# skilled -> skill
# unskilled -> unskil
# office -> offic
# cabinets -> cabinet
# redirected -> redirect
# functional -> function
# labs -> lab
# body -> bodi
# physical -> physic
# identical -> ident
# co-creation -> co-creat
# external -> extern
# directions -> direct
# compared -> compar
# o'reilly -> o'reilli
# larry -> larri
# expression -> express
# policies -> polici
# corporation -> corpor
# simultaneously -> simultan
# title -> titl
# currently -> current
# apply -> appli
# funding -> fund
# lacking -> lack
# countries -> countri
# single -> singl
# country -> countri
# involve -> involv
# collaborate -> collabor
# collaborative -> collabor
# models -> model
# members -> member
# overcome -> overcom
# designs -> design
# quite -> quit
# flexible -> flexibl
# thingiverse -> thingivers
# printable -> printabl
# notable -> notabl
# miscellaneous -> miscellan
# motors -> motor
# territories -> territori
# alliance -> allianc
# basis -> basi
# geometrical -> geometr
# cells -> cell
# files -> file
# licensed -> licens
# initiative -> initi
# makerspace -> makerspac
# hackspace -> hackspac
# community-operated -> community-oper
# machining -> machin
# hackerspaces -> hackerspac
# mechanisms -> mechan
# men's -> men'
# sheds -> shed
# facilities -> facil
# organization -> organ
# difficulties -> difficulti
# centers -> center
# nights -> night
# shops -> shop
# participate -> particip
# physically -> physic
# located -> locat
# libraries -> librari
# founding -> found
# costs -> cost
# performer -> perform
# started -> start
# included -> includ
# middle -> middl
# opened -> open
# thereafter -> thereaft
# citizens -> citizen
# burning -> burn
# vary -> vari
# lending -> lend
# facility -> facil
# infrastructure -> infrastructur
# fabrication -> fabric
# generators -> gener
# printers -> printer
# cutters -> cutter
# promoting -> promot
# makerspaces -> makerspac
# determined -> determin
# elected -> elect
# boards -> board
# selected -> select
# standing -> stand
# policy -> polici
# administrative -> administr
# fees -> fee
# charge -> charg
# volunteer -> volunt
# internationally -> intern
# defined -> defin
# functioning -> function
# varies -> vari
# planning -> plan
# regulations -> regul
# handle -> handl
# ventilation -> ventil
# improvements -> improv
# liability -> liabil
# showed -> show
# backgrounds -> background
# dominated -> domin
# attention -> attent
# locations -> locat
# formed -> form
# assisted -> assist
# department -> depart
# aged -> age
# founded -> found
# pioneered -> pioneer
# enabled -> enabl
# october -> octob
# initiated -> initi
# prototyping -> prototyp
# meetings -> meet
# beijing -> beij
# advertise -> advertis
# response -> respons
# sees -> see
# laboratory -> laboratori
# starting -> start
# entire -> entir
# columbus -> columbu
# references -> refer
# explore -> explor
# january -> januari
# yes -> ye
# specializing -> special
# regularly -> regularli
# prototype -> prototyp
# released -> releas
# categories -> categori
# full-time -> full-tim
# announced -> announc
# acquisition -> acquisit
# official -> offici
# mobile -> mobil
# windows -> window
# registered -> regist
# prizes -> prize
# awarded -> award
# questions -> question
# trades -> trade
# woodworking -> woodwork
# cutting -> cut
# getting -> get
# jobs -> job
# plumbing -> plumb
# leaky -> leaki
# fixture -> fixtur
# estimates -> estim
# franchise -> franchis
# assessment -> assess
# options -> option
# drywall -> drywal
# remodeling -> remodel
# carpentry -> carpentri
# moulding -> mould
# substantial -> substanti
# particle -> particl
# inclined -> inclin
# reporter -> report
# try -> tri
# chains -> chain
# professionalism -> profession
# handyman's -> handyman'
# pressure -> pressur
# injury -> injuri
# installing -> instal
# steps -> step
# estimate -> estim
# part-time -> part-tim
# contractors -> contractor
# replacing -> replac
# firms -> firm
# advertising -> advertis
# owners -> owner
# trucks -> truck
# workers -> worker
# insured -> insur
# plates -> plate
# studs -> stud
# employing -> employ
# technicians -> technician
# turned -> turn
# liked -> like
# installation -> instal
# homeowner -> homeown
# basements -> basement
# movable -> movabl
# relatively -> rel
# concluded -> conclud
# licensing -> licens
# guarantee -> guarante
# weeks -> week
# holes -> hole
# ceiling -> ceil
# fixed -> fix
# carry -> carri
# transaction -> transact
# referrals -> referr
# cleaning -> clean
# tiling -> tile
# require -> requir
# connecting -> connect
# image -> imag
# handsome -> handsom
# minds -> mind
# manny -> manni
# little -> littl
# garage -> garag
# insulation -> insul
# molding -> mold
# moving -> move
# removal -> remov
# modifications -> modif
# clips -> clip
# voltage -> voltag
# synthesizers -> synthes
# switches -> switch
# potentiometers -> potentiomet
# experimental -> experiment
# innovators -> innov
# practiced -> practic
# experimenting -> experi
# inexpensive -> inexpens
# resulting -> result
# electrocution -> electrocut
# repeated -> repeat
# achieved -> achiev
# causes -> caus
# knobs -> knob
# risks -> risk
# games -> game
# cause -> caus
# serge -> serg
# experiments -> experi
# kraakdoos -> kraakdoo
# leone -> leon
# samved -> samv
# conducted -> conduct
# declared -> declar
# oman's -> oman'
# branding -> brand
# awards -> award
# honours -> honour
# mainly -> mainli
# completely -> complet
# kids -> kid
# municipality -> municip
# awareness -> awar
# conjunction -> conjunct
# conservation -> conserv
# management -> manag
# plantation -> plantat
# drives -> drive
# campaigns -> campaign
# actively -> activ
# surface -> surfac
# copying -> copi
# three-dimensional -> three-dimension
# additive -> addit
# layers -> layer
# computer-aided -> computer-aid
# heads -> head
# jetting -> jet
# directed -> direct
# deposition -> deposit
# extrusion -> extrus
# photopolymerization -> photopolymer
# modeling -> model
# finishing -> finish
# legislation -> legisl
# decade -> decad
# matured -> matur
# metalworking -> metalwork
# envelope -> envelop
# transforming -> transform
# desired -> desir
# subtractive -> subtract
# polymer -> polym
# 2010s -> 2010
# manufacturers -> manufactur
# automated -> autom
# agile -> agil
# tooling -> tool
# engine -> engin
# complementing -> complement
# casting -> cast
# stamping -> stamp
# significant -> signific
# inroads -> inroad
# effective -> effect
# injection -> inject
# institute -> institut
# controlled -> control
# scanning -> scan
# filed -> file
# stereolithography -> stereolithographi
# claimed -> claim
# fused -> fuse
# commercialized -> commerci
# sintering -> sinter
# melting -> melt
# selective -> select
# milling -> mill
# errors -> error
# timelapse -> timelaps
# reconstruction -> reconstruct
# resolution -> resolut
# thickness -> thick
# x-y -> x-i
# dots -> dot
# particles -> particl
# hours -> hour
# depending -> depend
# precision -> precis
# polymers -> polym
# abs -> ab
# improved -> improv
# chemical -> chemic
# supports -> support
# overhanging -> overhang
# substrate -> substrat
# schematic -> schemat
# representation -> represent
# deposited -> deposit
# differences -> differ
# metals -> metal
# fabricated -> fabric
# granules -> granul
# manufactures -> manufactur
# transparent -> transpar
# solidified -> solidifi
# photopolymer -> photopolym
# cured -> cure
# projected -> project
# rises -> rise
# slowly -> slowli
# defense -> defens
# medical -> medic
# robots -> robot
# threeding -> threed
# facilitate -> facilit
# turning -> turn
# foods -> food
# shoes -> shoe
# manufacture -> manufactur
# football -> footbal
# airbus -> airbu
# force -> forc
# firearms -> firearm
# distributed -> distribut
# plans -> plan
# regarding -> regard
# surgery -> surgeri
# implants -> implant
# personalized -> person
# organs -> organ
# museums -> museum
# actuators -> actuat
# interaction -> interact
# actuator -> actuat
# regimes -> regim
# patents -> patent
# laws -> law
# limitation -> limit
# exception -> except
# inventions -> invent
# tangible -> tangibl
# statue -> statu
# copyrightable -> copyright
# courts -> court
# intelligence -> intellig
# guns -> gun
# commentators -> comment
# emissions -> emiss
# minutes -> minut
# displacing -> displac
# economies -> economi
# productive -> product
# transportation -> transport
# summers -> summer
# artificial -> artifici
# vigorous -> vigor
# estate -> estat
# strengthening -> strengthen
# financial -> financi
# spence -> spenc
# powerful -> power
# marginal -> margin
# declines -> declin
# believes -> believ
# employment -> employ
# expansion -> expans
# labor-intensive -> labor-intens

# %% [markdown]
# ## 9. Computing representation power of common words.

# %%
# combine
makerness = {}
for w in common_words:
    # Consider only words whose charcater length is larger than 1
    if len(w) > 1:
        # Log likelihood scores are computed:
        score = log((input_freq_dist[w] / n_input) / (english_freq_dist[w] / n_english))
        makerness[w] = score

# %%
# Sorting by scores:
for k,v in sorted(makerness.items(), key=lambda x:x[1], reverse=True): print(k,v)
# Out:
# additive 6.240406254084403
# printer 5.86884269765192
# printing 5.624645737139878
# digital 5.398839068406185
# franchise 5.13487352257172
# users 5.070335001434149
# global 5.070335001434149
# citation 5.001342129947197
# bending 4.9702515428771665
# deposition 4.819020573153243
# do-it-yourself 4.760180073130309
# manufacturing 4.725494515142419
# hardware 4.664869893325984
# computers 4.664869893325984
# evolutionary 4.664869893325984
# junk 4.664869893325984
# non-profit 4.664869893325984
# homeowners 4.664869893325984
# jargon 4.664869893325984
# template 4.664869893325984
# layer 4.622310278907189
# fabrication 4.600331372188413
# bug 4.531338500701462
# lab 4.48254833653203
# individualist 4.48254833653203
# zealand 4.48254833653203
# coined 4.48254833653203
# hack 4.48254833653203
# portal 4.48254833653203
# media 4.451295793027925
# computer 4.451295793027925
# commons 4.377187820874203
# consumers 4.339447492891357
# maker 4.320029407034255
# circuit 4.270215701322035
# catalog 4.2594047852178205
# eric 4.2594047852178205
# surname 4.2594047852178205
# prototype 4.2594047852178205
# fused 4.2594047852178205
# continue -0.00795894113592171
# distance -0.017261333798235256
# language -0.026477988903159104
# deep -0.026477988903159104
# already -0.028311169984820073
# getting -0.02953142639004937
# clear -0.03105465593057085
# field -0.031967481187930524
# speak -0.03561047246643162
# wish -0.03561047246643162
# shown -0.04165278692239422
# actually -0.04165278692239422
# give -0.04594648179709364
# cars -0.053628977969109995
# taken -0.057194044133606195
# program -0.05871804747658122
# hold -0.05956371348892452
# function -0.06251792538635603
# one -0.06708483848450182
# either -0.06781361296106629
# since -0.07292218090378887
# single -0.07715947537930402
# makes -0.07715947537930402
# corner -0.08006223503726546
# slowly -0.08006223503726546
# force -0.08006223503726546
# returned -0.08006223503726546
# true -0.08440063663586363
# taking -0.094450972489365
# account -0.0973040414717716
# appear -0.0973040414717716
# europe -0.10581473113968028
# along -0.10863560748132148
# made -0.10937662270604086
# society -0.1100430672492014
# steps -0.11425359978554493
# served -0.11425359978554493
# determined -0.11425359978554493
# reported -0.11425359978554493
# found -0.11518687096854334
# line -0.11593286130526484
# attention -0.11705080440660603
# small -0.1263187113373876
# case -0.12816202983167688
# required -0.13367168564264645
# spirit -0.13367168564264645
# feed -0.13915115140727197
# daily -0.13915115140727197
# important -0.1473144620464329
# larger -0.147314462046433
# kept -0.1554116722790523
# high -0.1574257716507536
# expected -0.16077361542043758
# thus -0.16184256260934268
# given -0.16876300545391654
# come -0.17141201362549344
# forms -0.17931719313260666
# note -0.17931719313260666
# fact -0.18492573279221627
# worked -0.1871603705936326
# longer -0.1923551874707367
# wrong -0.19494251103568752
# george -0.19494251103568752
# seems -0.19881098781360795
# month -0.20266455712959794
# cause -0.20266455712959794
# hot -0.20266455712959794
# opened -0.21032742987516687
# step -0.21032742987516687
# student -0.21032742987516687
# point -0.21540358290702757
# keep -0.21793202926038627
# association -0.21793202926038627
# held -0.21793202926038627
# money -0.22171275210029226
# mean -0.22296982329034346
# soon -0.22296982329034346
# continued -0.2254792348957692
# great -0.2254792348957692
# summer -0.23296990662492675
# trial -0.23296990662492675
# might -0.23595053476306463
# black -0.24287097760763843
# sound -0.24778499241006752
# leave -0.2526749777042593
# record -0.2551110325021403
# body -0.2623837918312201
# better -0.2623837918312201
# set -0.2623837918312201
# time -0.26929119763103104
# every -0.278811265973168
# weeks -0.2838899970521837
# throughout -0.2838899970521837
# run -0.2862512732378635
# head -0.2862512732378635
# students -0.29095716427527624
# place -0.2944721063827206
# whether -0.29797473693392273
# yes -0.3049434062500161
# john -0.31048358662563147
# put -0.3164510131014958
# earlier -0.31873672838235184
# name -0.3255626934527516
# stock -0.3255626934527516
# house -0.3306517629602229
# william -0.33234238043813047
# entire -0.3390764126194746
# meet -0.3390764126194746
# second -0.3404177944436758
# times -0.34576540077027124
# voice -0.35019999783813693
# age -0.35461501604725376
# congress -0.35901062752029184
# side -0.36163874992656136
# full -0.3677443074890464
# came -0.38177583829330425
# natural -0.38498611392355253
# even -0.38498611392355253
# still -0.38754693478522606
# areas -0.39349680359146116
# reason -0.41446193205650594
# subject -0.41653447165847846
# boy -0.4186027247225375
# indeed -0.4227264419063995
# medical -0.4227264419063995
# street -0.42683322385905287
# trying -0.4288803074807778
# rest -0.4288803074807778
# now -0.4365197640387353
# interest -0.44107558057459606
# old -0.44258958540581106
# whose -0.4551179376976348
# reached -0.4650288215970889
# air -0.47874108346107086
# real -0.48262458348746856
# read -0.4941854058885445
# hours -0.4941854058885445
# inside -0.4941854058885445
# report -0.4941854058885445
# take -0.49582609534600436
# forces -0.49991608059752946
# though -0.5056141017121671
# period -0.5093948245520733
# conditions -0.5280869575642259
# return -0.5280869575642259
# car -0.5427931049539212
# east -0.5446162595154362
# half -0.5464360962324223
# really -0.5464360962324223
# week -0.5464360962324223
# basis -0.5500658642830009
# pressure -0.5554859317523403
# values -0.5608767803872167
# much -0.5683754764783373
# across -0.5715720695039647
# days -0.592625478701797
# young -0.5952262604018543
# america -0.6029882657373434
# minutes -0.6132447659045327
# red -0.6183338354120039
# law -0.6301085719565376
# look -0.6309443430039336
# tax -0.6384350147330912
# york -0.6400920159407207
# good -0.6409194880607532
# two -0.6419823756718894
# hard -0.6433978040752202
# evidence -0.653250100518232
# will -0.6536956340519995
# life -0.6546496808726552
# therefore -0.6581400858124237
# matter -0.6597647815394255
# rate -0.6774643586388265
# took -0.6964222723834406
# level -0.6964222723834406
# child -0.6964222723834406
# back -0.7042165441102594
# feel -0.7104085143581805
# year -0.7257227493312229
# six -0.728757653026377
# family -0.7317833739429139
# policy -0.7378074885462949
# department -0.7512305088784357
# something -0.7512305088784357
# ever -0.7703066559392493
# war -0.7818674783403253
# turn -0.7861685602397159
# saw -0.7932961741639482
# years -0.8052977301487114
# board -0.811593658605526
# south -0.8157690300160068
# position -0.8199270401646703
# per -0.8458670611732861
# upon -0.8465406886827604
# present -0.8619101860138618
# office -0.8763936518324416
# room -0.880307551153578
# question -0.8842061915692353
# behind -0.8880896915956328
# thought -0.8900258006224993
# probably -0.8996505139967088
# city -0.9034746104351121
# next -0.9060159078637847
# asked -0.9161170038502887
# government -0.9651464310906074
# yet -0.9675359184879888
# quite -0.9734847760077613
# act -0.9805770043172529
# far -0.9841043448352216
# enough -0.9934502072534592
# long -1.0415756987497002
# three -1.055441883281427
# course -1.0717024041532075
# turned -1.1034511024677878
# country -1.1158736224663448
# mind -1.118955289003753
# want -1.128143715058159
# thing -1.1432725966544592
# say -1.1522412666372197
# children -1.207247896149431
# said -1.2115918406319364
# felt -1.2128658884536545
# men -1.2792409573985273
# going -1.3240915235638788
# must -1.3395108790485437
# right -1.3480299345020623
# nothing -1.35372332117025
# against -1.3706115391987719
# think -1.4058678346765052
# away -1.4576229161884013
# always -1.4619992907882002
# went -1.5636411102651986
# go -1.774480477774114
# last -1.8513231827169796
# man -2.025558219663383
# state -2.0284537749439644
# little -2.0577599015294634

# %%
with open('makerness.csv', 'w') as csvfile:
    thewriter = csv.writer(csvfile, delimiter=',')
    for k,v in sorted(makerness.items(), key=lambda x:x[1], reverse=True):
        thewriter.writerow([k,v])
